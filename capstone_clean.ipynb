# %% [markdown]
# # Brainstation Capstone Project
#
# ## Data Science Bootcamp: November 2023 - February 2024
#
# Welcome to my Capstone Project for the Brainstation Data Science Bootcamp. This project represents the culmination of intensive learning and hands-on experience in data science from November 2023 to February 2024.
#
# # Project Overview
#
# ## Project Description
# This capstone project is centered around developing a predictive analysis tool in medical data science, focusing on diseases like heart failure, stroke, diabetes, and cancer. The aim is to create a model that predicts the likelihood of these health conditions based on medical and demographic data.
#
# ## Objective
# The primary goal is to leverage data science and machine learning to provide early warnings for critical health conditions, aiding in early diagnosis and improving patient outcomes.
#
# ## Key Challenges
# - **Data Quality and Reliability**: Ensuring the datasets used are accurate and reliable.
# - **Model Accuracy and Validation**: Building models that are not only accurate but also clinically valid.
# - **Handling Imbalanced Data**: Dealing with the common issue of imbalanced datasets in medical data.
# - **Ethical Considerations**: Addressing data privacy and ethical concerns in predictive healthcare analytics.
#
# ## Technologies Used
# - **Programming Languages**: Python, including libraries like Pandas, NumPy, and Scikit-learn.
# - **Data Visualization**: Using Matplotlib and Seaborn for insights visualization.
# - **Machine Learning Frameworks**: Exploring TensorFlow or PyTorch for advanced modeling.
#
# ## Expected Outcomes
# - **Project**: A robust predictive model for disease risk assessment.
# - **Personal Development**: Improved expertise in data science and machine learning, with a focus on healthcare applications.
#
# ## Why This Project?
# I am deeply interested in the convergence of data science and healthcare. This project offers the opportunity to impact patient care through predictive analytics, aligning with my passion for applying data science to solve real-world problems and enhancing my skills in this critical area.
#
#
# ---
#
# Feel free to explore the different sections of this notebook to see the progress, analysis, and results of my capstone project. I appreciate any feedback or suggestions!

# %% [markdown]
# # Masoud Arefi
#
# Welcome to my professional portfolio in Data Science. Below are links to my LinkedIn profile and GitHub repository where you can find my projects and contributions.
#
# ## Connect with Me
#
# - [LinkedIn](https://www.linkedin.com/in/masoud-arefi/)
# - [GitHub](https://github.com/MaSOouD69/capstone-repo)
#
# ### About Me
#
# I am a passionate data science professional with a keen interest in developing insightful data-driven solutions. My expertise lies in leveraging analytical tools and machine learning techniques to unravel complex data challenges.
#
# Feel free to explore my projects and reach out for collaborations or discussions!

# %% [markdown]
# # Stroke Prediction and Analysis
#
# ## Introduction
#
# Strokes significantly impact global health, with a surprising fact: 80% of strokes are preventable. This notebook explores key indicators leading to strokes, using data from diverse age groups, genders, habits, and health issues. Our visualizations aim to be intuitive, employing simple yet effective methods for conveying essential information.
#
# ## Problem Statement
#
# Our goal is to visualize the relationships between various lifestyle habits and heart stroke occurrences. We aim to predict stroke probability using optimally tuned models, providing insights for preventive health measures.
#
# ## Questions and Assumptions
#
# In this analysis, we will investigate several questions and assumptions:
#
# 1. **Impact of Age**: Does age significantly influence stroke occurrence, and what is its distribution across populations?
# 2. **BMI and Glucose Levels**: How do higher body mass index and glucose levels correlate with stroke risk?
# 3. **Smoking and Stroke Risk**: Is there a strong link between smoking and increased stroke risk?
# 4. **Heart Disease and Stroke**: How closely are existing heart diseases and stroke occurrences related?
# 5. **Workload and Blood Pressure**: Can high workload and resultant blood pressure increases lead to strokes?
# 6. **Gender-Specific Risks**: Are males more prone to strokes due to work-related stress, or do risks vary across genders?
#
# ## Methodology
#
# - **Data Analysis**: Comprehensive examination of the dataset to understand feature distribution and relationships.
# - **Visualizations**: Using plots and charts to uncover patterns and insights.
# - **Statistical Testing**: Validating assumptions and hypotheses through statistical methods.
# - **Model Building**: Developing predictive models for stroke risk estimation.
# - **Feature Importance**: Identifying key factors that significantly influence stroke risk.
# - **Feature Selection**: Enhancing model accuracy by selecting relevant features.
#
# ## Conclusion
#
# This notebook aims to provide a deeper understanding of the factors leading to strokes and their interplay, essential for developing preventive strategies and early interventions.

# %%
# libraries import
import numpy as np  # Importing NumPy for numerical operations and array handling
import pandas as pd  # Importing Pandas for data manipulation and analysis
import seaborn as sns  # Importing Seaborn for statistical data visualization
import matplotlib.pyplot as plt  # Importing Matplotlib for creating static plots


# Importing necessary libraries from scikit-learn
from sklearn.model_selection import train_test_split  # For splitting data into training and test sets
from sklearn.linear_model import LogisticRegression  # Importing Logistic Regression model for classification tasks
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score  # Importing various metrics to evaluate model performance

from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler  # Importing different scalers for data normalization and standardization

# metrics
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score  # Additional metrics for model evaluation, especially for classification problems

from sklearn.neighbors import KNeighborsClassifier  # Importing K-Nearest Neighbors classifier
from sklearn.tree import DecisionTreeClassifier  # Importing Decision Tree classifier for decision tree models

from imblearn.over_sampling import SMOTE  # Importing SMOTE for handling imbalanced datasets by oversampling

from sklearn.svm import SVC  # Importing Support Vector Machine classifier

# %%
import warnings

# Ignore all warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('healthcare-dataset-stroke-data.csv')

# %%
df.head(5)
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
# Loop through each column and plot a histogram for each numeric columns
for i in ['age','hypertension','heart_disease','avg_glucose_level','stroke']:
    plt.figure()  # Create a new figure for each plot
    df[i].plot(kind='hist')
    plt.title(f'Histogram of {i}')
    plt.show()  # Display the plot

# %% [markdown]
# From histogram of Stroke distribution it is clear that every 5 people out of 100 people are having strokes from our sampling data. Moreover,this is a highly unbalanced data distribution, and null accuracy score of this distribution it self is 95%, whcih imploys any dump model should randomly predictions of stroke could reach accuracy of 95%. So, while modeling and training data, either over sampling or under sampling has to be done to obtain best results.

# %%
# stats of categorical data
round (df.describe(exclude = ['float', 'int64']),2)
# Out:
#         gender ever_married work_type Residence_type smoking_status
# count     5110         5110      5110           5110           5110
# unique       3            2         5              2              4
# top     Female          Yes   Private          Urban   never smoked
# freq      2994         3353      2925           2596           1892

# %% [markdown]
# visulizaton for categorical columns

# %%
non_num_df = ['gender','work_type','Residence_type','smoking_status','ever_married']
for i in non_num_df:
    plt.figure()  # Create a new figure for each p
    
    # For non-numeric data, use a count plot
    sns.countplot(y=df[i], data=df)
    plt.title(f'Count Plot of {i}')

    plt.show()  # Display the plot

# %%
df[['gender','work_type','Residence_type','smoking_status','ever_married']].head()
# Out:
#    gender      work_type Residence_type   smoking_status ever_married
# 0    Male        Private          Urban  formerly smoked          Yes
# 1  Female  Self-employed          Rural     never smoked          Yes
# 2    Male        Private          Rural     never smoked          Yes
# 3  Female        Private          Urban           smokes          Yes
# 4  Female  Self-employed          Rural     never smoked          Yes

# %% [markdown]
# #### Null and Duplicate records

# %%
# look at null values
df.isna().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
# Filter the DataFrame for rows where 'bmi' is null
df_null_bmi = df[df['bmi'].isna()]
df_null_bmi.head()
# Out:
#        id  gender   age  hypertension  heart_disease ever_married  \
# 1   51676  Female  61.0             0              0          Yes
# 8   27419  Female  59.0             0              0          Yes
# 13   8213    Male  78.0             0              1          Yes
# 19  25226    Male  57.0             0              1           No
# 27  61843    Male  58.0             0              0          Yes
#
#         work_type Residence_type  avg_glucose_level  bmi smoking_status  \
# 1   Self-employed          Rural             202.21  NaN   never smoked
# 8         Private          Rural              76.15  NaN        Unknown
# 13        Private          Urban             219.84  NaN        Unknown
# 19       Govt_job          Urban             217.08  NaN        Unknown
# 27        Private          Rural             189.84  NaN        Unknown
#
#     stroke
# 1        1
# 8        1
# 13       1
# 19       1
# 27       1

# %% [markdown]
# Use visalization for null values

# %%
# Filter the DataFrame for rows where 'bmi' is null
df_null_bmi = df[df['bmi'].isna()]

# Loop through each column
for i in df_null_bmi.columns:
    plt.figure()  # Create a new figure for each plot

    # Check if the column is numeric
    if pd.api.types.is_numeric_dtype(df_null_bmi[i]):
        df_null_bmi[i].plot(kind='hist')
        plt.title(f'Histogram of {i} for Rows with Null BMI')
    else:
        # For non-numeric data, use a count plot
        sns.countplot(y=i, data=df_null_bmi)
        plt.title(f'Count Plot of {i} for Rows with Null BMI')

    plt.show()  # Display the plot

# %% [markdown]
# As we observe the visuals for both the entire DataFrame and the subset with null BMI values, the most standout feature is the 'glucose' column. Let's take a closer look at distributions.

# %%
# avg_glucose_level for whole dataframe
df_null_bmi['avg_glucose_level'].plot(kind='hist')
plt.title(f'Histogram of avg_glucose_level for Rows with Null BMI')
# Out:
# Text(0.5, 1.0, 'Histogram of avg_glucose_level for Rows with Null BMI')

# %%
    # # avg_glucose_level for whole dataframe
    df['avg_glucose_level'].plot(kind='hist')
    plt.title('Histogram of avg_glucose_level')
# Out:
# Text(0.5, 1.0, 'Histogram of avg_glucose_level')

# %% [markdown]
# The distribution of average glucose levels shows noticeable differences between the original dataset and the subset with missing BMI values. Notably, 4 percent of the data is missing, and this missingness does not appear to be random. To address this, it's advisable to retain the records with missing BMI values. However, adding a new column to indicate whether the BMI is missing could be beneficial for machine learning methods. This approach allows us to maintain data integrity while providing a clear indicator for our models to handle these missing values appropriately.

# %%
# deal with missing data
df['missing bmi'] = df['bmi'].isna()

# %%
df['bmi'].isna().sum()
# Out:
# 201

# %%
#check for duplicate rows
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There is no duplicated record in the data set

# %%
# fill missing data with median
df['bmi'] = df['bmi'].fillna(round (df['bmi'].median(), 2))

# %%
df.isna().sum()
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# missing bmi          0
# dtype: int64

# %% [markdown]
# Fianle check before data overview

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21  28.1     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke  missing bmi
# 0       1        False
# 1       1         True
# 2       1        False
# 3       1        False
# 4       1        False

# %% [markdown]
# # Dataset Overview
#
# Our dataset contains a mix of categorical and numerical features, with a focus on health-related measurements. Here's a breakdown of the features:
#
# ## Categorical Features
# - `gender`: Gender of the individual
# - `ever_married`: Marital status
# - `work_type`: Type of occupation
# - `Residence_type`: Type of residence (Urban/Rural)
# - `smoking_status`: Smoking status
#
# ## Binary Numerical Features
# - `hypertension`: Presence of hypertension (0 = No, 1 = Yes)
# - `heart_disease`: Presence of heart disease (0 = No, 1 = Yes)
# - `stroke`: Occurrence of stroke (0 = No, 1 = Yes)
#
# ## Continuous Numerical Features
# - `age`: Age of the individual
# - `avg_glucose_level`: Average glucose level in blood
# - `bmi`: Body Mass Index
#
# **Note**: The `bmi` feature has missing data that needs to be addressed. Most of our data is categorical, which will require special attention for visualization. For feature extraction, we can consider binning the continuous features (age, avg_glucose_level, and bmi) while keeping other features as they are.

# %% [markdown]
# ### Story telling with data

# %% [markdown]
# ### Data Binning Strategies
#
# In our analysis, we'll be binning several key variables to categorize our data more effectively. Below are the binning strategies for Body Mass Index (BMI), age, and average glucose levels, along with references for each categorization method.
#
# #### Body Mass Index (BMI) Binning
#
# BMI is a key health indicator used to categorize individuals into different weight statuses. The binning of BMI will be based on standard medical categories.
#
# Reference: [Body Mass Index Categories](https://www.medicalnewstoday.com/articles/323446#body-mass-index)
#
# #### Age Binning
#
# Categorizing individuals into different life stages based on age can be particularly relevant in studies where age is a significant factor.
#
# Reference: [Age and Physical Description](https://kidspicturedictionary.com/english-through-pictures/people-english-through-pictures/age-physical-description/)
#
# #### Average Glucose Level Binning
#
# Binning average glucose levels helps in categorizing individuals based on their blood sugar levels, crucial in studies related to diabetes and metabolic health.
#
# Reference: [Normal Blood Sugar Level Chart](https://agamatrix.com/blog/normal-blood-sugar-level-chart/)

# %%
# Binning continuous features for better categorization
df['age_category'] = pd.cut(df['age'], bins=[0, 18, 35, 60, 100], labels=['Child', 'Young Adult', 'Adult', 'Senior'])
df['glucose_category'] = pd.cut(df['avg_glucose_level'], bins=[0, 90, 140, 200, 500], labels=['Low', 'Normal', 'High', 'Very High'])
df['bmi_category'] = pd.cut(df['bmi'], bins=[0, 18.5, 25, 30, 100], labels=['Underweight', 'Normal', 'Overweight', 'Obese'])

# Display the first few rows of the modified DataFrame
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21  28.1     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke  missing bmi age_category glucose_category bmi_category
# 0       1        False       Senior        Very High        Obese
# 1       1         True       Senior        Very High   Overweight
# 2       1        False       Senior           Normal        Obese
# 3       1        False        Adult             High        Obese
# 4       1        False       Senior             High       Normal

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                5110 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
#  12  missing bmi        5110 non-null   bool
#  13  age_category       5110 non-null   category
#  14  glucose_category   5110 non-null   category
#  15  bmi_category       5110 non-null   category
# dtypes: bool(1), category(3), float64(3), int64(4), object(5)
# memory usage: 499.7+ KB

# %% [markdown]
# ##### take a closer look at data with ratio of stroke

# %%
# visualization for columns with object data type
for col in df.select_dtypes('object').columns:
    rate_data = df.groupby([col,'stroke'])['stroke'].count() / df.groupby(col)['stroke'].count()
    
    rate_data.unstack()[[1,0]].sort_values(1).plot(kind='barh',stacked=True)
    plt.title(f"stroke rate per {col}")
    sns.despine()
    plt.show()

# %% [markdown]
# We now have a comprehensive view of the target variable's distribution across all features, visualized using Matplotlib. This allows us to analyze standout results and patterns for each case.

# %%
col = 'Work Type'  

# Calculate the rate
rate_data = df.groupby(['work_type', 'stroke'])['stroke'].count() / df.groupby('work_type')['stroke'].count()

# Unstack and sort the data
sorted_data = rate_data.unstack().sort_values(by=1)[[1, 0]]

# Setting up the plot style and palette
plt.figure(figsize=(12, 8))  # Adjust the size as needed
sns.set_style("whitegrid")  # Set the style of the plot
palette = sns.cubehelix_palette(2, start=.5, rot=-.75)  # Advanced color palette

# Plotting
sorted_data.plot(kind='barh', stacked=True, color=palette, ax=plt.gca())

# Adding title and labels with enhanced formatting
plt.title(f"Stroke Rate per {col}", fontsize=16, fontweight='bold', color='darkred')
plt.xlabel('Rate', fontsize=14, fontweight='bold')
plt.ylabel('Work Type', fontsize=14, fontweight='bold')

# Customizing the legend
plt.legend(title='Stroke Status', labels=['Stroke', 'No Stroke'], loc='lower right', fontsize='large', title_fontsize='13')

# Customizing the ticks for better readability
plt.xticks(fontsize=12, fontweight='bold')
plt.yticks(fontsize=12, fontweight='bold')

sns.despine()  # Remove the top and right spines
plt.tight_layout()  # Adjust the layout
plt.show()

# %%
col = 'Smoking Status'

# Calculate the rate for Smoking Status
rate_data = df.groupby(['smoking_status', 'stroke'])['stroke'].count() / df.groupby('smoking_status')['stroke'].count()

# Unstack and sort the data
sorted_data = rate_data.unstack().sort_values(by=1)[[1, 0]]

# Setting up the plot style and palette
plt.figure(figsize=(12, 8))  # Adjust the size as needed
sns.set_style("whitegrid")  # Set the style of the plot
palette = sns.cubehelix_palette(2, start=.5, rot=-.75)  # Advanced color palette

# Plotting
sorted_data.plot(kind='barh', stacked=True, color=palette, ax=plt.gca())

# Adding title and labels with enhanced formatting
plt.title(f"Stroke Rate per {col}", fontsize=16, fontweight='bold', color='darkred')
plt.xlabel('Rate', fontsize=14, fontweight='bold')
plt.ylabel('Smoking Status', fontsize=14, fontweight='bold')

# Customizing the legend
plt.legend(title='Stroke Status', labels=['Stroke', 'No Stroke'], loc='lower right', fontsize='large', title_fontsize='13')

# Customizing the ticks for better readability
plt.xticks(fontsize=12, fontweight='bold')
plt.yticks(fontsize=12, fontweight='bold')

sns.despine()  # Remove the top and right spines
plt.tight_layout()  # Adjust the layout
plt.show()

# %%
col = 'Ever Married'

# Calculate the rate for Ever Married status
rate_data = df.groupby(['ever_married', 'stroke'])['stroke'].count() / df.groupby('ever_married')['stroke'].count()

# Unstack and sort the data
sorted_data = rate_data.unstack().sort_values(by=1)[[1, 0]]

# Setting up the plot style and palette
plt.figure(figsize=(12, 8))  # Adjust the size as needed
sns.set_style("whitegrid")  # Set the style of the plot
palette = sns.cubehelix_palette(2, start=.5, rot=-.75)  # Advanced color palette

# Plotting
sorted_data.plot(kind='barh', stacked=True, color=palette, ax=plt.gca())

# Adding title and labels with enhanced formatting
plt.title(f"Stroke Rate per {col}", fontsize=16, fontweight='bold', color='darkred')
plt.xlabel('Rate', fontsize=14, fontweight='bold')
plt.ylabel('Ever Married', fontsize=14, fontweight='bold')

# Customizing the legend
plt.legend(title='Stroke Status', labels=['Stroke', 'No Stroke'], loc='lower right', fontsize='large', title_fontsize='13')

# Customizing the ticks for better readability
plt.xticks(fontsize=12, fontweight='bold')
plt.yticks(fontsize=12, fontweight='bold')

sns.despine()  # Remove the top and right spines
plt.tight_layout()  # Adjust the layout
plt.show()

# %% [markdown]
# We are faced with a crucial question: Does marital status significantly impact the likelihood of a stroke? To explore this further, we will conduct an extensive exploratory data analysis (EDA) focusing on the 'marriage' and 'age category' columns to uncover deeper insights into this relationship

# %%
# Calculate the rate
rate_data = df.groupby(['ever_married', 'age_category', 'stroke']).size() / df.groupby(['ever_married', 'age_category']).size()
rate_data = rate_data.reset_index(name='rate')

# Filter for stroke cases only
stroke_rate_data = rate_data[rate_data['stroke'] == 1]

# Setting up the plot style for minimalism
sns.set_style("whitegrid")  # White background with grid for a clean look
plt.figure(figsize=(12, 8))  # Adjust the size as needed

# Plotting with age category hue
bar_plot = sns.catplot(x='ever_married', y='rate', hue='age_category', data=stroke_rate_data, kind='bar', palette='cubehelix', height=6, aspect=2)

# Adding title and labels with enhanced formatting
bar_plot.fig.suptitle("Stroke Rate by Marital Status and Age Category", fontsize=16, fontweight='bold', color='darkred')
bar_plot.set_axis_labels("Ever Married", "Stroke Rate", fontsize=14, fontweight='bold', color='black')

# Customizing the ticks for better readability
plt.xticks(fontsize=12, fontweight='bold', color='black')
plt.yticks(fontsize=12, fontweight='bold', color='black')

# Adjusting the legend for minimalism
# Remove the existing legend and use the one automatically generated by Seaborn
bar_plot._legend.remove()
bar_plot.fig.legend(title='Age Category', loc='upper right', fontsize='medium', title_fontsize='13')

sns.despine()  # Remove the top and right spines for a cleaner look
plt.tight_layout(rect=[0, 0, 1, 0.95])  # Adjust the layout
plt.show()

# %% [markdown]
# Our analysis reveals that the incidence of stroke is notably higher among seniors compared to other age groups. Furthermore, within the senior category, the rate of stroke among unmarried individuals surpasses that of their married counterparts. Conversely, in the adult age group, marital status does not appear to significantly influence the stroke rate

# %%
df['age_category'].value_counts()
# Out:
# Adult          1907
# Senior         1304
# Young Adult     983
# Child           916
# Name: age_category, dtype: int64

# %%
# plot for age category
age_category_counts = df['age_category'].value_counts()

# Setting up the plot style
sns.set_style("whitegrid")

# Creating the bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x=age_category_counts.index, y=age_category_counts.values, palette='cubehelix')

# Adding title and labels
plt.title('Distribution of Age Categories', fontsize=16, fontweight='bold')
plt.xlabel('Age Category', fontsize=14, fontweight='bold')
plt.ylabel('Count', fontsize=14, fontweight='bold')

# Customizing the ticks for better readability
plt.xticks(fontsize=12, fontweight='bold')
plt.yticks(fontsize=12, fontweight='bold')

sns.despine()  # Remove the top and right spines for a cleaner look
plt.show()

# %% [markdown]
# data set has a good verity of each age category

# %%
# Calculate the rate by age category
rate_data = df.groupby(['age_category', 'stroke']).size() / df.groupby('age_category').size()
rate_data = rate_data.reset_index(name='rate')

# Filter for stroke cases only
stroke_rate_data = rate_data[rate_data['stroke'] == 1]

# Setting up the plot style for minimalism
sns.set_style("whitegrid")  # White background with grid for a clean look
plt.figure(figsize=(12, 8))  # Adjust the size as needed

# Plotting the stroke rate by age category
bar_plot = sns.barplot(x='age_category', y='rate', data=stroke_rate_data, palette='cubehelix')

# Adding title and labels with enhanced formatting
plt.title("Stroke Rate by Age Category", fontsize=16, fontweight='bold', color='darkred')
plt.xlabel('Age Category', fontsize=14, fontweight='bold', color='black')
plt.ylabel('Stroke Rate', fontsize=14, fontweight='bold', color='black')

# Customizing the ticks for better readability
plt.xticks(fontsize=12, fontweight='bold', color='black')
plt.yticks(fontsize=12, fontweight='bold', color='black')

sns.despine()  # Remove the top and right spines for a cleaner look
plt.tight_layout()  # Adjust the layout
plt.show()

# %% [markdown]
# apperantly the age is a big factore for stroke

# %%
# Calculate the rate by age category and stroke status
rate_data = df.groupby(['age_category', 'stroke']).size() / df.groupby('age_category').size()
rate_data = rate_data.reset_index(name='rate')

# Setting up the plot style for minimalism
sns.set_style("whitegrid")  # White background with grid for a clean look
plt.figure(figsize=(12, 8))  # Adjust the size as needed

# Plotting the stroke rate by age category with stroke hue
bar_plot = sns.barplot(x='age_category', y='rate', hue='stroke', data=rate_data, palette='cubehelix')

# Adding title and labels with enhanced formatting
plt.title("Stroke Rate by Age Category", fontsize=16, fontweight='bold', color='darkred')
plt.xlabel('Age Category', fontsize=14, fontweight='bold', color='black')
plt.ylabel('Rate', fontsize=14, fontweight='bold', color='black')

# Customizing the ticks for better readability
plt.xticks(fontsize=12, fontweight='bold', color='black')
plt.yticks(fontsize=12, fontweight='bold', color='black')

# Adjusting the legend for minimalism
plt.legend(title='Stroke Status', loc='upper right', fontsize='medium', title_fontsize='13')

sns.despine()  # Remove the top and right spines for a cleaner look
plt.tight_layout()  # Adjust the layout
plt.show()

# %% [markdown]
# Following the analysis of age-related factors, we will now investigate the role of Body Mass Index (BMI) and its significance in influencing stroke occurrence.

# %%
# Calculate the stroke rate per BMI category
rate_data = df.groupby(['bmi_category', 'stroke']).size() / df.groupby('bmi_category').size()
rate_data = rate_data.reset_index(name='rate')

# Filter for stroke cases only
stroke_rate_data = rate_data[rate_data['stroke'] == 1]

# Setting up the plot style
sns.set_style("whitegrid")
plt.figure(figsize=(10, 6))

# Plotting the stroke rate by BMI category
sns.barplot(x='bmi_category', y='rate', data=stroke_rate_data, palette='cubehelix')

# Adding title and labels
plt.title('Stroke Rate by BMI Category', fontsize=16, fontweight='bold')
plt.xlabel('BMI Category', fontsize=14, fontweight='bold')
plt.ylabel('Stroke Rate', fontsize=14, fontweight='bold')

# Customizing the ticks for better readability
plt.xticks(fontsize=12, fontweight='bold')
plt.yticks(fontsize=12, fontweight='bold')

sns.despine()  # Remove the top and right spines for a cleaner look
plt.show()

# %% [markdown]
# The data indicates that individuals classified as overweight have a higher stroke incidence rate compared to those categorized as obese.

# %%
# Calculate the rate
rate_data = df.groupby(['bmi_category', 'stroke'])['stroke'].count() / df.groupby('bmi_category')['stroke'].count()

# Unstack and sort the data
sorted_data = rate_data.unstack().sort_values(by=1)[[1, 0]]

# Setting up the plot style and palette
plt.figure(figsize=(12, 8))  # Adjust the size as needed
sns.set_style("whitegrid")  # Set the style of the plot
palette = sns.cubehelix_palette(2, start=.5, rot=-.75)  # Advanced color palette

# Plotting
sorted_data.plot(kind='barh', stacked=True, color=palette, ax=plt.gca())

# Adding title and labels with enhanced formatting
plt.title("Stroke Rate per BMI Category", fontsize=16, fontweight='bold', color='darkred')
plt.xlabel('Rate', fontsize=14, fontweight='bold')
plt.ylabel('BMI Category', fontsize=14, fontweight='bold')

# Customizing the legend
plt.legend(title='Stroke Status', labels=['Stroke', 'No Stroke'], loc='lower right', fontsize='large', title_fontsize='13')

# Customizing the ticks for better readability
plt.xticks(fontsize=12, fontweight='bold')
plt.yticks(fontsize=12, fontweight='bold')

sns.despine()  # Remove the top and right spines
plt.tight_layout()  # Adjust the layout
plt.show()

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21  28.1     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke  missing bmi age_category glucose_category bmi_category
# 0       1        False       Senior        Very High        Obese
# 1       1         True       Senior        Very High   Overweight
# 2       1        False       Senior           Normal        Obese
# 3       1        False        Adult             High        Obese
# 4       1        False       Senior             High       Normal

# %% [markdown]
# ##### Now stroke ratefor numeric data

# %%
#  visaalization for columns with category data type
for col in df.select_dtypes('category').columns:
    rate_data = df.groupby([col,'stroke'])['stroke'].count() / df.groupby(col)['stroke'].count()
    
    rate_data.unstack()[[1,0]].sort_values(1).plot(kind='barh',stacked=True)
    plt.title(f"stroke rate per {col} type")
    sns.despine()
    plt.show()

# %% [markdown]
# Does marriage and glucose result in a higher incidence of stroke? Considering that children are typically unmarried, we will demonstrate analysis on adults and seniors to examine the stroke ratio in relation to marital status

# %%
# Filter the DataFrame for seniors and adults
senior_df = df[df['age_category'].isin(['Senior', 'Adult'])]

# Calculate the rate
rate_data = senior_df.groupby(['ever_married', 'stroke'])['stroke'].count() / senior_df.groupby('ever_married')['stroke'].count()

# Unstack, sort, and plot
rate_data.unstack().sort_values(by=1)[[1, 0]].plot(kind='barh', stacked=True)
plt.title("Stroke Rate per Marital Status for Seniors and adults")
sns.despine()
plt.show()

# %% [markdown]
# As the visual analysis indicates, the ratio of stroke incidence among adults and seniors appears to be similar for both married and unmarried groups.

# %%
#visualization with numeric data type (heart disease)
rate_data = df.groupby(['heart_disease','stroke'])['stroke'].count() / df.groupby('heart_disease')['stroke'].count()
    
rate_data.unstack()[[1,0]].sort_values(1).plot(kind='barh',stacked=True)
plt.title(f"stroke rate per heart_disease")
sns.despine()
plt.show()

# %% [markdown]
# The analysis demonstrates a positive comrrelation between the presence of heart disease and the incidence of stroke

# %%
#visualization with numeric data type (hypertension)
rate_data = df.groupby(['hypertension','stroke'])['stroke'].count() / df.groupby('hypertension')['stroke'].count()
    
rate_data.unstack()[[1,0]].sort_values(1).plot(kind='barh',stacked=True)
plt.title(f"stroke rate per hypertension")
sns.despine()
plt.show()

# %% [markdown]
# The data also reveals a positive correlation between hypertension and the occurrence of stroke.

# %% [markdown]
# ###### Let's examine the relationship between glucose levels and the incidence of stroke. Does a higher glucose level correlate with an increased risk of stroke?

# %%
# Plotting the data
# 'No Stroke' group
sns.kdeplot(data=df[df['stroke'] == 0], x='avg_glucose_level', alpha=1,label='No Stroke',fill=True)
# 'Stroke' group
sns.kdeplot(data=df[df['stroke'] == 1], x='avg_glucose_level',  alpha=0.8, label='Stroke',fill=True)

# Setting the title and labels
plt.title('Distribution of Average Glucose Levels by Stroke Status', fontsize=14)
plt.xlabel('Average Glucose Level', fontsize=12)
plt.ylabel('Density', fontsize=12)

# Adding a legend to show which color corresponds to which group
plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# Glucose level distribution is skewed towards left and most of the strokes can be seen people with regular glucose levels. we can NOT conclude Glucose does not have significant impact on strokes, and its unclear strokes are which group effected by strokes.
#
# avg_glucose_level : High blood glucose is found in stroke cases. A value of 126+ has been observed alot.

# %%
plt.figure()
sns.pairplot(df,hue="stroke", corner=True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Feature engineering

# %%
df_copy=df.copy()
df_copy.head(5)
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21  28.1     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke  missing bmi age_category glucose_category bmi_category
# 0       1        False       Senior        Very High        Obese
# 1       1         True       Senior        Very High   Overweight
# 2       1        False       Senior           Normal        Obese
# 3       1        False        Adult             High        Obese
# 4       1        False       Senior             High       Normal

# %%
from sklearn.preprocessing import (StandardScaler,
                                   LabelEncoder,
                                   OneHotEncoder)

# %%
df_copy.drop(columns = ['id'],inplace=True)

# %% [markdown]
# # preprocessing - label enconding and numerical value scaling
# ohe = OneHotEncoder()
# ss = StandardScaler()
# le = LabelEncoder()

# %% [markdown]
# ## label encoding of ordinal categorical features
# for col in df_copy.columns:
#     df_copy[col] = le.fit_transform(df_copy[col])

# %%
X = df_copy.drop(columns=['stroke'])
y = df_copy['stroke'].copy()

# %%
corr_df = X.corr()

mask = np.triu(corr_df)

plt.figure(figsize=(18, 18))
sns.heatmap(corr_df.round(2), mask=mask, cmap='coolwarm', annot=True)
plt.show()

# %% [markdown]
# ###### check same for standard scaler

# %% [markdown]
# cols = df_copy.columns
# ## normalizing with standard scaler of numerical features
# df_copy[cols] = ss.fit_transform(df_copy[cols])
#
# X = df_copy.drop(columns=['stroke'])
# y = df_copy['stroke'].copy()
#
# corr_df = X.corr()
#
# mask = np.triu(corr_df)
#
# plt.figure(figsize=(18, 18))
# sns.heatmap(corr_df.round(2), mask=mask, cmap='coolwarm', annot=True)
# plt.show()

# %%
df_copy.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  67.0             0              1          Yes        Private
# 1  Female  61.0             0              0          Yes  Self-employed
# 2    Male  80.0             0              1          Yes        Private
# 3  Female  49.0             0              0          Yes        Private
# 4  Female  79.0             1              0          Yes  Self-employed
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke  \
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             202.21  28.1     never smoked       1
# 2          Rural             105.92  32.5     never smoked       1
# 3          Urban             171.23  34.4           smokes       1
# 4          Rural             174.12  24.0     never smoked       1
#
#    missing bmi age_category glucose_category bmi_category
# 0        False       Senior        Very High        Obese
# 1         True       Senior        Very High   Overweight
# 2        False       Senior           Normal        Obese
# 3        False        Adult             High        Obese
# 4        False       Senior             High       Normal

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21  28.1     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke  missing bmi age_category glucose_category bmi_category
# 0       1        False       Senior        Very High        Obese
# 1       1         True       Senior        Very High   Overweight
# 2       1        False       Senior           Normal        Obese
# 3       1        False        Adult             High        Obese
# 4       1        False       Senior             High       Normal

# %%
df_copy1 = df.copy()

# %% [markdown]
# ### Now we can apply feature engineering on df_copy1

# %%
df_copy1.drop(columns = ['id'],inplace=True)

# %%
df_copy1.tail()
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 5105  Female  80.0             1              0          Yes        Private
# 5106  Female  81.0             0              0          Yes  Self-employed
# 5107  Female  35.0             0              0          Yes  Self-employed
# 5108    Male  51.0             0              0          Yes        Private
# 5109  Female  44.0             0              0          Yes       Govt_job
#
#      Residence_type  avg_glucose_level   bmi   smoking_status  stroke  \
# 5105          Urban              83.75  28.1     never smoked       0
# 5106          Urban             125.20  40.0     never smoked       0
# 5107          Rural              82.99  30.6     never smoked       0
# 5108          Rural             166.29  25.6  formerly smoked       0
# 5109          Urban              85.28  26.2          Unknown       0
#
#       missing bmi age_category glucose_category bmi_category
# 5105         True       Senior              Low   Overweight
# 5106        False       Senior           Normal        Obese
# 5107        False  Young Adult              Low        Obese
# 5108        False        Adult             High   Overweight
# 5109        False        Adult              Low   Overweight

# %% [markdown]
# Proceed to process the 'gender' column by converting its categorical data into numerical format, ensuring compatibility with our numerical analysis methods

# %%
df_copy1['gender'].value_counts()
# Out:
# Female    2994
# Male      2115
# Other        1
# Name: gender, dtype: int64

# %%
df_copy1['gender'] = df_copy1['gender'].map({'Male': 1, 'Female': 0, 'Other' : 0})

# %% [markdown]
# change the bmi category to numeric values

# %%
df_copy1['bmi_category'].value_counts()
# Out:
# Obese          1893
# Overweight     1610
# Normal         1258
# Underweight     349
# Name: bmi_category, dtype: int64

# %%
df_copy1['bmi_category'] = df_copy1['bmi_category'].map({
    'Underweight' : 1,
    'Normal' : 2,
    'Overweight' : 3,
    'Obese' : 4
            })

# %% [markdown]
# change glucose category into numeric valuses

# %%
df_copy1['glucose_category'].value_counts()
# Out:
# Low          2405
# Normal       1884
# Very High     434
# High          387
# Name: glucose_category, dtype: int64

# %%
df_copy1['glucose_category'] = df_copy1['glucose_category'].map({
'Low' : 1,
'Normal' : 2,
'High' : 3,
'Very High' : 4
})

# %% [markdown]
# cahnge age category into the numeric values

# %%
df_copy1['age_category'].value_counts()
# Out:
# Adult          1907
# Senior         1304
# Young Adult     983
# Child           916
# Name: age_category, dtype: int64

# %%
df_copy1['age_category'] = df_copy1['age_category'].map({
'Senior' : 4, 
'Adult' : 3,
'Young Adult' : 2,
'Child' : 1
})

# %% [markdown]
# dealing with amoke status base on affect to the body from lowet impact to the highest

# %%
df_copy1['smoking_status'].value_counts()
# Out:
# never smoked       1892
# Unknown            1544
# formerly smoked     885
# smokes              789
# Name: smoking_status, dtype: int64

# %%
df_copy1['smoking_status'] = df_copy1['smoking_status'].map({
'never smoked' : 1,
'Unknown' : 2,
'formerly smoked' :3,
'smokes' : 4
})

# %% [markdown]
# change residence type into boolian representer

# %%
df_copy1['Residence_type'].value_counts()
# Out:
# Urban    2596
# Rural    2514
# Name: Residence_type, dtype: int64

# %%
df_copy1['Residence_type'] = df_copy1['Residence_type'].map({'Urban': 1, 'Rural': 0})

# %% [markdown]
# define the category base on stress definition from lowest to the highest

# %%
df_copy1['work_type'].value_counts()
# Out:
# Private          2925
# Self-employed     819
# children          687
# Govt_job          657
# Never_worked       22
# Name: work_type, dtype: int64

# %% [markdown]
# 5 category in work type, never worked and child better to be a category

# %%
df_copy1['work_type'] = df_copy1['work_type'].map({
'Private' : 3,
'Self-employed' : 4,
'children' : 1,
'Govt_job' : 2,
'Never_worked' : 1
})

# %% [markdown]
# change the marriage status to the numeric shape

# %%
df_copy1['ever_married'].value_counts()
# Out:
# Yes    3353
# No     1757
# Name: ever_married, dtype: int64

# %%
df_copy1['ever_married'] = df_copy1['ever_married'].map({'Yes': 1, 'No': 0})

# %% [markdown]
# time for moving frome data type to correlation analysis

# %%
...
# Out:
# Ellipsis

# %% [markdown]
# sanity check to ensure the dataset's integrity and consistency before proceeding further with the analysis.m

# %%
df_copy1.isna().sum()
# Out:
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# missing bmi          0
# age_category         0
# glucose_category     0
# bmi_category         0
# dtype: int64

# %%
plt.figure()
sns.pairplot(df_copy1,hue="stroke", corner=True)
plt.show()

# %% [markdown]
# time to define the target feature, which in this case is stroke, for second target variable we can target the heart desease column after getting desireable model.

# %%
X = df_copy1.drop(columns=['stroke'])
y = df_copy1['stroke'].copy()

# %%
corr_df = X.corr()

mask = np.triu(corr_df)

plt.figure(figsize=(18, 18))
sns.heatmap(corr_df.round(2), mask=mask, cmap='coolwarm', annot=True)
plt.show()

# %%
# Splitting our data
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    test_size=0.2,
                                                    random_state=12345,
                                                    stratify=y)

# Check
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (4088, 14) (1022, 14) (4088,) (1022,)

# %%
#define a lis of categorical columns for smote oversampling without creating getting any null alues 
cat_indices=['age_category','glucose_category','bmi_category']

# %%
cat_indices = ['age_category', 'glucose_category', 'bmi_category']
cat_indices = [X_train.columns.get_loc(col) for col in cat_indices]
print(cat_indices)
# Out:
# [11, 12, 13]

# %% [markdown]
# Given the imbalance in the dataset, we will implement oversampling to achieve more interpretable results. Specifically, with the presence of categorical features, we will utilize the SMOTENC method to ensure the oversampling process is conducted effectively without introducing NaN values.

# %%
from imblearn.over_sampling import SMOTENC

# Assuming 'cat_indices' is the list of categorical feature indices
smote_nc = SMOTENC(categorical_features=cat_indices, random_state=0)
X_train, y_train = smote_nc.fit_resample(X_train, y_train)

# %%
# Print the shape of X_train to see the number of features
print(X_train.shape)
# Out:
# (7778, 14)

# %%
# Check
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (7778, 14) (1022, 14) (7778,) (1022,)

# %% [markdown]
# since data set is small and continues numeric columns canuse as they are we drop the categorical columns wich used to show the more cleae results on graphs

# %%
X_train.drop(columns=['age_category','glucose_category','bmi_category'],inplace=True)
X_test.drop(columns=['age_category','glucose_category','bmi_category'],inplace=True)

# %%
X_train.isna().sum()
# Out:
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# missing bmi          0
# dtype: int64

# %%
X_train.head()
# Out:
#    gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0       1  80.0             0              0             0          2
# 1       0  80.0             1              0             0          1
# 2       1  70.0             1              0             1          2
# 3       0  24.0             0              0             0          1
# 4       0  72.0             0              0             1          4
#
#    Residence_type  avg_glucose_level   bmi  smoking_status  missing bmi
# 0               0             204.17  41.3               1        False
# 1               1              66.03  35.4               3        False
# 2               1             251.60  27.1               3        False
# 3               1              65.44  23.6               3        False
# 4               0             118.22  21.9               1        False

# %%
#X_train.drop(columns=['age','avg_glucose_level','bmi'],inplace=True)
#X_test.drop(columns=['age','avg_glucose_level','bmi'],inplace=True)

# %%
corr_df = X_train.corr()

mask = np.triu(corr_df)

plt.figure(figsize=(18, 18))
sns.heatmap(corr_df.round(2), mask=mask, cmap='coolwarm', annot=True)
plt.tight_layout()
plt.show()

# %%
# Instantiate the scaler
SS = StandardScaler()

# Fit the scaler and transform both data subsets
X_train = SS.fit_transform(X_train)
X_test = SS.transform(X_test)

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (7778, 11) (1022, 11) (7778,) (1022,)

# %%
import time

# %%
start = time.time()

# Empty lists to append the training and test accuracy scores to
train_acc_ss = []
test_acc_ss = []

# The C_values to try
C_values = [0.00001, 0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 1000, 10000]
# Loop through the same C values
for C in C_values:

    # Instantiate the model
    logit=LogisticRegression(C=C, max_iter=1000, random_state=42)

    # Fit the model
    logit.fit(X_train, y_train)

    # Score the model
    train_acc_ss.append(logit.score(X_train, y_train))
    test_acc_ss.append(logit.score(X_test, y_test))

stop = time.time()
runtime_logit_ss = stop-start
print(f"Runtime: {round(runtime_logit_ss,2)} seconds")
# Out:
# Runtime: 0.1 seconds

# %%
# Plotting the train and test scores for every C value
plt.figure()
plt.plot(C_values, train_acc_ss, c='red', label='train')
plt.plot(C_values, test_acc_ss, c='blue', label='test')
plt.xscale('log')
plt.xlabel('C-values')
plt.ylabel('Accuracy score')
plt.legend()
plt.show()

# %% [markdown]
# In this instance, our best Logistic Regression model was at C equal to 0.001 We can see clearly the tell-tale elbow which indicates the bulk of learning has been completed and a point beyond which overfitting might be a concern. Let's take a look at the model's performance:

# %%
# The Logistic Regression that performed the best on the standardized data
# Instantiate the model
logit_ss = LogisticRegression(C=0.001, random_state=42)

# Fit the model
logit_ss.fit(X_train, y_train)

# Store accuracy scores
logit_ss_train = logit_ss.score(X_train, y_train)
logit_ss_test = logit_ss.score(X_test, y_test)

# Score the model
print(f"Train Accuracy: {logit_ss_train}")
print(f"Test Accuracy: {logit_ss_test}")
# Out:
# Train Accuracy: 0.8297762921059398
# Test Accuracy: 0.7808219178082192

# %%
from sklearn.metrics import classification_report
y_test_pred_logit_ss = logit_ss.predict(X_test) 

report_initial = classification_report(y_test, y_test_pred_logit_ss)
print(report_initial)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.79      0.87       972
#            1       0.12      0.58      0.21        50
#
#     accuracy                           0.78      1022
#    macro avg       0.55      0.69      0.54      1022
# weighted avg       0.93      0.78      0.84      1022

# %% [markdown]
# ##### Roc curve

# %%
from sklearn.metrics import roc_curve

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# %%
def false_positive_rate(y_true, y_pred):
    
    false_positives = (y_true == 0) & (y_pred == 1) # find all values where y is negative
                                                    # but we predicted positive
    false_positive_number = false_positives.sum()

    true_negatives = (y_true == 0) & (y_pred == 0)  # find all values where y is negative
                                                    # and we predicted negative
    true_negative_number = true_negatives.sum()

    # Finally, find the ratio of (FP) to (TN + FP)
    FPR = false_positive_number/(true_negative_number + false_positive_number)
    
    return FPR

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
y_pred_proba = model.predict_proba(X_test)
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba[:,1])

plt.plot(fpr, tpr)
plt.plot([0, 1], [0, 1], linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('1 - specificity')
plt.ylabel('sensitivity')
plt.show()

# %%
# Regenerate scores
y_proba = logit_ss.predict_proba(X_test)[:,1]
fprs, tprs, thresholds = roc_curve(y_test, y_proba)
roc_auc = roc_auc_score(y_test, y_proba)

# %%
#Get the probability for each point in the train set.
y_proba_train = logit_ss.predict_proba(X_train)[:,1]

# Compute ROC curve and AUC for for the one class
fprs_train, tprs_train, thresholds_train = roc_curve(y_train, y_proba_train)
roc_auc_train = roc_auc_score(y_train, y_proba_train)

# Plot the ROC curve.
plt.figure()
plt.plot(fprs_train, tprs_train, color='darkorange', lw=2, label='train')
plt.plot(fprs, tprs, lw=2, label='test')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC and AUC')
plt.legend(loc="best")
plt.show()
print(f"Test AUC score: {roc_auc}")
print(f"Train AUC score: {roc_auc_train}")
# Out:
# Test AUC score: 0.7834979423868313
# Train AUC score: 0.9107461419259748

# %%
# Assuming logistic_regression_model is your trained logistic regression model
coefficients = logit_ss.coef_[0]  # Extracting the coefficients

# Creating an index for each coefficient
feature_index = np.arange(len(coefficients))

# Plotting
plt.figure(figsize=(10, 6))
plt.scatter(feature_index, coefficients, color='blue')
plt.title('Scatter Plot of Logistic Regression Coefficients')
plt.xlabel('Feature Index')
plt.ylabel('Coefficient Value')
plt.grid(True)
plt.show()

# %% [markdown]
# ### as above we can see the most effective feature is age

# %%
coefficients
# Out:
# array([-0.2391074 ,  0.73949913, -0.06454229, -0.07227451, -0.06958533,
#        -0.15683266, -0.25891618,  0.23920734,  0.03380217, -0.28621618,
#         0.36786948])

# %%
logit_ss.coef_
# Out:
# array([[-0.2391074 ,  0.73949913, -0.06454229, -0.07227451, -0.06958533,
#         -0.15683266, -0.25891618,  0.23920734,  0.03380217, -0.28621618,
#          0.36786948]])

# %%
df_copy1.columns
# Out:
# Index(['gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke', 'missing bmi', 'age_category',
#        'glucose_category', 'bmi_category'],
#       dtype='object')

# %%
X_columns = ['gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
       'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
       'smoking_status', 'missing bmi']

# %%
coefficients = logit_ss.coef_[0]  # Extracting the coefficients

coef_df = pd.DataFrame(coefficients, X_columns, columns=['Coefficient'])

# %%
coef_df = coef_df.sort_values(by='Coefficient', ascending=False)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.barh(coef_df.index, coef_df['Coefficient'])
plt.xlabel('Coefficient Value')
plt.ylabel('Features')
plt.title('Feature Coefficients')
plt.show()

# %%
# class distribution
display(y_test.value_counts())

# predict classification
y_test_pred_logit_ss = logit_ss.predict(X_test) # USING THE UNSAMPLED BUT SCALED TEST DATA



report_initial = classification_report(y_test, y_test_pred_logit_ss)
print(report_initial)
# Out:
# 0    972
# 1     50
# Name: stroke, dtype: int64
#               precision    recall  f1-score   support
#
#            0       0.97      0.79      0.87       972
#            1       0.12      0.58      0.21        50
#
#     accuracy                           0.78      1022
#    macro avg       0.55      0.69      0.54      1022
# weighted avg       0.93      0.78      0.84      1022

# %%
# Compute confusion matrix
conf_matrix_logit_ss = confusion_matrix(y_test, y_test_pred_logit_ss)

# Plot confusion matrix
sns.heatmap(conf_matrix_logit_ss, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
df_copy1.head()
# Out:
#    gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0       1  67.0             0              1             1          1
# 1       0  61.0             0              0             1          2
# 2       1  80.0             0              1             1          1
# 3       0  49.0             0              0             1          1
# 4       0  79.0             1              0             1          2
#
#    Residence_type  avg_glucose_level   bmi  smoking_status  stroke  \
# 0               1             228.69  36.6               1       1
# 1               0             202.21  28.1               3       1
# 2               0             105.92  32.5               3       1
# 3               1             171.23  34.4               2       1
# 4               0             174.12  24.0               3       1
#
#    missing bmi age_category glucose_category bmi_category
# 0        False            4                4            4
# 1         True            4                4            3
# 2        False            4                2            4
# 3        False            3                3            4
# 4        False            4                3            2

# %% [markdown]
# ### KNN

# %%
start = time.time()

# The different K values to try out and save to 'neighbors'
neighbors = range(1, 55, 2)

# Empty lists to append the accuracies to
train_acc_mm = []
test_acc_mm = []

# Loop through neighbors
for K in neighbors:

    # Instantiate the model
    knn = KNeighborsClassifier(n_neighbors=K)

    # Fit the model
    knn.fit(X_train, y_train)

    # Score the model
    train_acc_mm.append(knn.score(X_train, y_train))
    test_acc_mm.append(knn.score(X_test, y_test))

stop = time.time()
runtime_knn_mm = stop-start
print(f"Runtime: {round(runtime_knn_mm,2)} seconds")
# Out:
# Runtime: 26.66 seconds

# %%
# Plot the accuracies
plt.figure(figsize=(16,8))
plt.plot(neighbors, train_acc_mm, c='red', label='train')
plt.plot(neighbors, test_acc_mm, c='blue', label='test')
plt.xlabel("n_neighbors")
plt.ylabel("Accuracy score")
plt.legend()
plt.show()

# %% [markdown]
# These plots are quite choppy so conclusions will be somewhat subjective. However, the gap between the two plots is at its narrowest at around n_neighbors = 7 and 19

# %%
# KNN with n_neighbors=13
# Instantiate the model
knn_mm = KNeighborsClassifier(n_neighbors=13)

# Fit the model
knn_mm.fit(X_train, y_train)

# Store accuracy scores
knn_mm_train = knn_mm.score(X_train, y_train)
knn_mm_test = knn_mm.score(X_test, y_test)

# Score the model
print(f"Train Accuracy: {knn_mm_train}")
print(f"Test Accuracy: {knn_mm_test}")
# Out:
# Train Accuracy: 0.8846747235793263
# Test Accuracy: 0.7896281800391389

# %%
# class distribution
display(y_test.value_counts())

# predict classification
y_test_pred_knn_mmk7 = knn_mm.predict(X_test) # USING THE UNSAMPLED BUT SCALED TEST DATA



print(f'Recall score: {recall_score(y_test, y_test_pred_knn_mmk7)*100:0.1f}%')
print(f'Precision score: {precision_score(y_test, y_test_pred_knn_mmk7)*100:0.1f}%')
print(f'F1 score: {f1_score(y_test, y_test_pred_knn_mmk7)*100:0.1f}%')
# Out:
# 0    972
# 1     50
# Name: stroke, dtype: int64
# Recall score: 62.0%
# Precision score: 13.7%
# F1 score: 22.4%

# %%
# predict classificatin
report_initial = classification_report(y_test, y_test_pred_knn_mmk7)
print(report_initial)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.80      0.88       972
#            1       0.14      0.62      0.22        50
#
#     accuracy                           0.79      1022
#    macro avg       0.56      0.71      0.55      1022
# weighted avg       0.94      0.79      0.85      1022

# %%
# Compute confusion matrix
conf_matrix_knn_mmk7 = confusion_matrix(y_test, y_test_pred_knn_mmk7)

# Plot confusion matrix
sns.heatmap(conf_matrix_knn_mmk7, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
# KNN with n_neighbors=19
# Instantiate the model
knn_mm = KNeighborsClassifier(n_neighbors=19)

# Fit the model
knn_mm.fit(X_train, y_train)

# Store accuracy scores
knn_mm_train = knn_mm.score(X_train, y_train)
knn_mm_test = knn_mm.score(X_test, y_test)

# Score the model
print(f"Train Accuracy: {knn_mm_train}")
print(f"Test Accuracy: {knn_mm_test}")
# Out:
# Train Accuracy: 0.8758035484700437
# Test Accuracy: 0.7886497064579256

# %%
# class distribution
display(y_test.value_counts())

# predict classification
y_test_pred_knn_mm19 = knn_mm.predict(X_test) # USING THE UNSAMPLED BUT SCALED TEST DATA



print(f'Recall score: {recall_score(y_test, y_test_pred_knn_mm19)*100:0.1f}%')
print(f'Precision score: {precision_score(y_test, y_test_pred_knn_mm19)*100:0.1f}%')
print(f'F1 score: {f1_score(y_test, y_test_pred_knn_mm19)*100:0.1f}%')
# Out:
# 0    972
# 1     50
# Name: stroke, dtype: int64
# Recall score: 60.0%
# Precision score: 13.3%
# F1 score: 21.7%

# %%
# predict classification
y_test_pred_knn_mm19 = knn_mm.predict(X_test) # USING THE UNSAMPLED BUT SCALED TEST DATA



report_initial = classification_report(y_test, y_test_pred_knn_mm19)
print(report_initial)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.80      0.88       972
#            1       0.13      0.60      0.22        50
#
#     accuracy                           0.79      1022
#    macro avg       0.55      0.70      0.55      1022
# weighted avg       0.93      0.79      0.85      1022

# %%
# Compute confusion matrix
conf_matrix_knn_mmk19 = confusion_matrix(y_test, y_test_pred_knn_mm19)

# Plot confusion matrix
sns.heatmap(conf_matrix_knn_mmk19, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %% [markdown]
# ### Decision Tree

# %%
# number of rows
X_train.shape[0]
# Out:
# 7778

# %%
# indicating range of max_depth values
range(1, int(np.sqrt(X_train.shape[0])))
# Out:
# range(1, 88)

# %%
start = time.time()

# A list of the maximum depths to try out and save to 'depths'
depths = range(1, int(np.sqrt(X_train.shape[0])))

# Empty lists to append to
train_acc_ss = []
test_acc_ss = []

# Loop through the depths
for max_depth in depths:

    # Instantiate the model
    dt = DecisionTreeClassifier(max_depth=max_depth, random_state=42)

    # Fit the model
    dt.fit(X_train, y_train)

    # Score the model
    train_acc_ss.append(dt.score(X_train, y_train))
    test_acc_ss.append(dt.score(X_test, y_test))

stop = time.time()
runtime_dt_mm = stop-start
print(f"Runtime: {round(runtime_dt_mm,2)} seconds")
# Out:
# Runtime: 2.05 seconds

# %%
# Plot the accuracies
plt.figure(figsize=(16,8))
plt.plot(depths, train_acc_ss, c='red', label='train')
plt.plot(depths, test_acc_ss, c='blue', label='test')
plt.xlabel("max_depth")
plt.ylabel("Accuracy score")
plt.title("DecisionTreeClassifier")
plt.legend()
plt.show()

# %% [markdown]
# max_depth=4 and 6 appears to be optimal.

# %%
# Best Decision Tree Classifier on standardized data and max_depth=3
# Instantiate the model
dt_ss = DecisionTreeClassifier(max_depth=4, random_state=42)

# Fit the model
dt_ss.fit(X_train, y_train)

# Store accuracy scores
dt_ss_train = dt_ss.score(X_train, y_train)
dt_ss_test = dt_ss.score(X_test, y_test)

# Score the model
print(f"Train Accuracy: {dt_ss_train}")
print(f"Test Accuracy: {dt_ss_test}")
# Out:
# Train Accuracy: 0.8200051427102083
# Test Accuracy: 0.7759295499021527

# %%
# class distribution
display(y_test.value_counts())

# predict classification
y_test_pred_dt_ss = dt_ss.predict(X_test) # USING THE UNSAMPLED BUT SCALED TEST DATA


print(f'Recall score: {recall_score(y_test, y_test_pred_dt_ss)*100:0.1f}%')
print(f'Precision score: {precision_score(y_test, y_test_pred_dt_ss)*100:0.1f}%')
print(f'F1 score: {f1_score(y_test, y_test_pred_dt_ss)*100:0.1f}%')
# Out:
# 0    972
# 1     50
# Name: stroke, dtype: int64
# Recall score: 74.0%
# Precision score: 14.6%
# F1 score: 24.4%

# %%
report_initial = classification_report(y_test, y_test_pred_dt_ss)
print(report_initial)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.78      0.87       972
#            1       0.15      0.74      0.24        50
#
#     accuracy                           0.78      1022
#    macro avg       0.56      0.76      0.56      1022
# weighted avg       0.94      0.78      0.84      1022

# %%
# Compute confusion matrix
conf_matrix_dt_ss = confusion_matrix(y_test, y_test_pred_dt_ss)

# Plot confusion matrix
sns.heatmap(conf_matrix_dt_ss, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
# Best Decision Tree Classifier on standardized data 
# Instantiate the model
dt_ssn = DecisionTreeClassifier(max_depth=2, random_state=42)

# Fit the model
dt_ssn.fit(X_train, y_train)

# Store accuracy scores
dt_ss_train = dt_ssn.score(X_train, y_train)
dt_ss_test = dt_ssn.score(X_test, y_test)

# Score the model
print(f"Train Accuracy: {dt_ss_train}")
print(f"Test Accuracy: {dt_ss_test}")
# Out:
# Train Accuracy: 0.7666495242993058
# Test Accuracy: 0.6086105675146771

# %%
# class distribution
display(y_test.value_counts())

# predict classification
y_test_pred_dt_ssn = dt_ssn.predict(X_test) # USING THE UNSAMPLED BUT SCALED TEST DATA


print(f'Recall score: {recall_score(y_test, y_test_pred_dt_ssn)*100:0.1f}%')
print(f'Precision score: {precision_score(y_test, y_test_pred_dt_ssn)*100:0.1f}%')
print(f'F1 score: {f1_score(y_test, y_test_pred_dt_ssn)*100:0.1f}%')
# Out:
# 0    972
# 1     50
# Name: stroke, dtype: int64
# Recall score: 92.0%
# Precision score: 10.4%
# F1 score: 18.7%

# %%
report_initial = classification_report(y_test, y_test_pred_dt_ssn)
print(report_initial)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.59      0.74       972
#            1       0.10      0.92      0.19        50
#
#     accuracy                           0.61      1022
#    macro avg       0.55      0.76      0.46      1022
# weighted avg       0.95      0.61      0.72      1022

# %%
# Compute confusion matrix
conf_matrix_dt_ssn = confusion_matrix(y_test, y_test_pred_dt_ssn)

# Plot confusion matrix
sns.heatmap(conf_matrix_dt_ssn, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
# to do checkk for optimize one factor

# %%
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# #### Pipe line for decision Tree

# %%
# Define the model
dt = DecisionTreeClassifier()

# Define the parameter grid
param_grid = {
    'criterion': ['gini', 'entropy'],
    'max_depth': [2, 3, 4, 6, 10 ,12],
    'min_samples_split': [1, 2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_leaf_nodes': [10, 20, 30, None]  # 'None' means unlimited
}

# %%
# Initialize GridSearchCV
gs = GridSearchCV(dt, param_grid, scoring='recall', cv=5)

# %%
# Fit GridSearchCV
gs.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 3, 4, 6, 10, 12],
#                          'max_leaf_nodes': [10, 20, 30, None],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [1, 2, 5, 10]},
#              scoring='recall')

# %%
# Best parameters
print("Best Parameters:", gs.best_params_)

# Best F1 score
print("Best F1 Score:", gs.best_score_)

# Best model
best_model = gs.best_estimator_

# Predictions with the best model
y_pred_dt_best = best_model.predict(X_test)

# Classification report
print(classification_report(y_test, y_pred_dt_best))
# Out:
# Best Parameters: {'criterion': 'gini', 'max_depth': 12, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Best F1 Score: 0.9406047251805607
#               precision    recall  f1-score   support
#
#            0       0.96      0.86      0.91       972
#            1       0.11      0.32      0.16        50
#
#     accuracy                           0.84      1022
#    macro avg       0.53      0.59      0.54      1022
# weighted avg       0.92      0.84      0.87      1022

# %%
# Compute confusion matrix
conf_matrix_dt_ss_best = confusion_matrix(y_test, y_pred_dt_best)

# Plot confusion matrix
sns.heatmap(conf_matrix_dt_ss_best, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %% [markdown]
# ### Support Vector Machines

# %%
from sklearn.svm import LinearSVC

# %%
C_values = [0.00001,0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 1000,10000]
training_scores = []
test_scores = []

for c in C_values:
    SVM_model = LinearSVC(C=c, max_iter=1000,dual=False)
    SVM_model.fit(X_train, y_train)
    training_scores.append(SVM_model.score(X_train, y_train))
    test_scores.append(SVM_model.score(X_test, y_test))

# Plotting the training scores
plt.plot(C_values, training_scores, marker='o',label='train')
plt.plot(C_values, test_scores, marker='.',label="test")
plt.xscale('log')  # Since C_values vary on a logarithmic scale
plt.xlabel('C value')
plt.ylabel('Training Accuracy')
plt.title('Training Accuracy for different C values in LinearSVC')
plt.legend()
plt.show()
training_scores
# Out:
# [0.8104911288248907,
#  0.8299048598611468,
#  0.8371046541527385,
#  0.8360761121110826,
#  0.8364618153767035,
#  0.8362046798662895,
#  0.8362046798662895,
#  0.8362046798662895,
#  0.8362046798662895,
#  0.8362046798662895]

# %%
# Instantiate the model
SVM_model = LinearSVC(C=0.01,max_iter=100000,dual=False)

# Fit the model
SVM_model.fit(X_train, y_train)

# Store accuracy scores
SVM_model_train = SVM_model.score(X_train, y_train)
SVM_model_test = SVM_model.score(X_test, y_test)

# Score the model
print(f"Train Accuracy: {SVM_model_train}")
print(f"Test Accuracy: {SVM_model_test}")
# Out:
# Train Accuracy: 0.8360761121110826
# Test Accuracy: 0.7974559686888454

# %%
# class distribution
display(y_test.value_counts())

# predict classification
y_test_pred_SVM_model = SVM_model.predict(X_test) # USING THE UNSAMPLED BUT SCALED TEST DATA



print(f'Recall score: {recall_score(y_test, y_test_pred_SVM_model)*100:0.1f}%')
print(f'Precision score: {precision_score(y_test, y_test_pred_SVM_model)*100:0.1f}%')
print(f'F1 score: {f1_score(y_test, y_test_pred_SVM_model)*100:0.1f}%')
# Out:
# 0    972
# 1     50
# Name: stroke, dtype: int64
# Recall score: 50.0%
# Precision score: 12.1%
# F1 score: 19.5%

# %%
report_initial = classification_report(y_test, y_test_pred_SVM_model)
print(report_initial)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.81      0.88       972
#            1       0.12      0.50      0.19        50
#
#     accuracy                           0.80      1022
#    macro avg       0.55      0.66      0.54      1022
# weighted avg       0.93      0.80      0.85      1022

# %%
# Compute confusion matrix
conf_matrix_SVM_model = confusion_matrix(y_test, y_test_pred_SVM_model)

# Plot confusion matrix
sns.heatmap(conf_matrix_SVM_model, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
from sklearn.decomposition import PCA

# %%
my_PCA = PCA()
my_PCA.fit(X_train)

# transform data 
X_train_PCA = my_PCA.transform(X_train)
X_test_PCA = my_PCA.transform(X_test)

# %%
print(f"Variance captured by PC1: {my_PCA.explained_variance_[0]: 0.3f}")
print(f"Variance captured by PC2: {my_PCA.explained_variance_[1]: 0.3f}")

print(f"Proportion of variance captured by PC1: {my_PCA.explained_variance_ratio_[0]: 0.3f}")
print(f"Proportion of variance captured by PC2: {my_PCA.explained_variance_ratio_[1]: 0.3f}")
# Out:
# Variance captured by PC1:  2.266
# Variance captured by PC2:  1.217
# Proportion of variance captured by PC1:  0.206
# Proportion of variance captured by PC2:  0.111

# %%
my_PCA.explained_variance_ratio_
# Out:
# array([0.20598384, 0.11060501, 0.10014622, 0.09077205, 0.08822488,
#        0.0824581 , 0.07748345, 0.07636705, 0.06496501, 0.06176318,
#        0.0412312 ])

# %%
expl_var = my_PCA.explained_variance_ratio_

# %%
plt.figure()
plt.plot(range(1,12),expl_var,marker='.')
plt.xlabel('Number of PCs')
plt.ylabel('Proportion of Variance Explained')
plt.xticks(range(1,12,2))
plt.show()

# %%
# Pull out the explained variance ratio
expl_var = my_PCA.explained_variance_ratio_

# Calculate the cumulative sum of this array using the 
cumulative_sum = np.cumsum(expl_var)

cumulative_sum
# Out:
# array([0.20598384, 0.31658885, 0.41673507, 0.50750712, 0.595732  ,
#        0.6781901 , 0.75567355, 0.83204061, 0.89700562, 0.9587688 ,
#        1.        ])

# %%
# Plot out the cumulative sum graph

plt.figure()
plt.plot(range(1,12), cumulative_sum, marker='.')
plt.axhline(0.9, c='r', linestyle='--')
plt.xlabel('Number of PCs')
plt.ylabel('Cumulative Sum of Explained Variance')
plt.xticks(range(1,12,2))
plt.show()

# %%
# Instantiate and fit
my_PCA = PCA(n_components = 9)
my_PCA.fit(X_train)

# Transform train and test
X_train_PCA = my_PCA.transform(X_train)
X_test_PCA = my_PCA.transform(X_test)

# %%
print(f'Original: {X_train.shape}')
print(f'PCA Transformed: {X_train_PCA.shape}')
# Out:
# Original: (7778, 11)
# PCA Transformed: (7778, 9)

# %%
# Instantiate and fit
my_PCA = PCA(n_components = 0.90)
my_PCA.fit(X_train)

# Transform train and test
X_train_PCA = my_PCA.transform(X_train)
X_test_PCA = my_PCA.transform(X_test)

# %%
print(f'Original: {X_train.shape}')
print(f'PCA Transformed: {X_train_PCA.shape}')
# Out:
# Original: (7778, 11)
# PCA Transformed: (7778, 10)

# %%
# Do the same but fit on the PCA transformed data
my_logreg_PCA = LogisticRegression(C=1, random_state=42,max_iter=100000)

# Fitting to PCA data
my_logreg_PCA.fit(X_train_PCA,y_train)

# Scoring on PCA train and test sets
print(f'Train Score: {my_logreg_PCA.score(X_train_PCA, y_train)}')
print(f'Test Score: {my_logreg_PCA.score(X_test_PCA, y_test)}')
# Out:
# Train Score: 0.805476986371818
# Test Score: 0.7759295499021527

# %%
# class distribution
display(y_test.value_counts())

# predict classification
y_test_pred_PCA = my_logreg_PCA.predict(X_test_PCA) # USING THE UNSAMPLED BUT SCALED TEST DATA


print(f'Recall score: {recall_score(y_test, y_test_pred_PCA)*100:0.1f}%')
print(f'Precision score: {precision_score(y_test, y_test_pred_PCA)*100:0.1f}%')
print(f'F1 score: {f1_score(y_test, y_test_pred_PCA)*100:0.1f}%')
# Out:
# 0    972
# 1     50
# Name: stroke, dtype: int64
# Recall score: 50.0%
# Precision score: 10.9%
# F1 score: 17.9%

# %% [markdown]
# Since the number of columns are not significant, PCA is not a good method for feature enginering

# %%
from sklearn.metrics import classification_report

report_initial = classification_report(y_test, y_test_pred_PCA)
print(report_initial)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.79      0.87       972
#            1       0.11      0.50      0.18        50
#
#     accuracy                           0.78      1022
#    macro avg       0.54      0.65      0.52      1022
# weighted avg       0.93      0.78      0.84      1022

# %%
# Compute confusion matrix
conf_matrix_PCA = confusion_matrix(y_test, y_test_pred_PCA)

# Plot confusion matrix
sns.heatmap(conf_matrix_PCA, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %% [markdown]
# 💡 Recommendation: The goal should be to minimize false negatives as much as possible to avoid under-predicting the 'Stroke' class, while also reducing false positives to avoid over-predicting the 'Stroke' class. This could potentially be achieved by further tuning the model's parameters, exploring different algorithms, or engineering new features.

# %%
# check the Logestic model performance with Statsmodels 
import statsmodels.api as sm

# Add a constant to the predictor variable set to include an intercept in the model
X_with_cons = sm.add_constant(X_train)

# Fit the logistic regression model
model = sm.Logit(y_train, X_with_cons).fit()

# Get the summary of the model
summary = model.summary2().tables[1] 

# Convert summary to DataFrame
summary_df = pd.DataFrame(summary)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.365442
#          Iterations 7

# %%
model.summary2()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                          Results: Logit
# ================================================================
# Model:              Logit            Pseudo R-squared: 0.473
# Dependent Variable: stroke           AIC:              5708.8229
# Date:               2024-02-04 16:51 BIC:              5792.3316
# No. Observations:   7778             Log-Likelihood:   -2842.4
# Df Model:           11               LL-Null:          -5391.3
# Df Residuals:       7766             LLR p-value:      0.0000
# Converged:          1.0000           Scale:            1.0000
# No. Iterations:     7.0000
# ------------------------------------------------------------------
#          Coef.    Std.Err.      z       P>|z|     [0.025    0.975]
# ------------------------------------------------------------------
# const   -0.1945     0.0377    -5.1667   0.0000   -0.2683   -0.1207
# x1      -0.4817     0.0342   -14.0903   0.0000   -0.5488   -0.4147
# x2       2.0000     0.0547    36.5890   0.0000    1.8929    2.1072
# x3      -0.2624     0.0316    -8.3014   0.0000   -0.3243   -0.2004
# x4      -0.2451     0.0296    -8.2717   0.0000   -0.3032   -0.1870
# x5      -0.5129     0.0422   -12.1409   0.0000   -0.5957   -0.4301
# x6      -0.3120     0.0355    -8.7924   0.0000   -0.3816   -0.2425
# x7      -0.6189     0.0348   -17.7869   0.0000   -0.6871   -0.5507
# x8       0.3706     0.0360    10.2951   0.0000    0.3001    0.4412
# x9       0.1517     0.0368     4.1242   0.0000    0.0796    0.2237
# x10     -0.5909     0.0365   -16.1930   0.0000   -0.6624   -0.5194
# x11      0.7941     0.0451    17.6045   0.0000    0.7057    0.8825
# ================================================================
#
# """

# %%
# get accuracies for model
X_test_const = sm.add_constant(X_test)
# Predict probabilities
y_pred_prob = model.predict(X_test_const)

# Convert probabilities to class labels (0 or 1) based on a threshold (e.g., 0.5)
y_pred_sm = (y_pred_prob > 0.3).astype(int)

# %%
# Calculate F1 score
f1 = f1_score(y_test, y_pred_sm)
print("F1 Score:", f1)

# Calculate recall
recall = recall_score(y_test, y_pred_sm)
print("Recall:", recall)

# Calculate precision
precision = precision_score(y_test, y_pred_sm)
print("Precision:", precision)
# Out:
# F1 Score: 0.18229166666666666
# Recall: 0.7
# Precision: 0.10479041916167664

# %%
# Compute confusion matrix
conf_matrix_sm = confusion_matrix(y_test, y_pred_sm)

# Plot confusion matrix
sns.heatmap(conf_matrix_sm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

random_forest_model = RandomForestClassifier(n_estimators=50) # setting max features is not needed here as our dataset only has 2 features.
random_forest_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=50)

# %%
# Instantiate lists to save scores in
decision_tree_train_scores = []
decision_tree_test_scores = []

# For each tree, score on train and test
for sub_tree in random_forest_model.estimators_:
    decision_tree_train_scores.append(sub_tree.score(X_train, y_train))
    decision_tree_test_scores.append(sub_tree.score(X_test, y_test))

# Rather than many separate print() statements, we can combine them into one using triple quotes.
print(f"""
Performance on fitted data:
best Decision Tree: {np.max(decision_tree_train_scores)}
Random Forest: {random_forest_model.score(X_train, y_train)}
----------------
Performance on test data:
best Decision Tree: {np.max(decision_tree_test_scores)}
Random Forest: {random_forest_model.score(X_test, y_test)}
""")
# Out:
# Performance on fitted data:
# best Decision Tree: 0.9678580611982515
# Random Forest: 1.0
# ----------------
# Performance on test data:
# best Decision Tree: 0.860078277886497
# Random Forest: 0.8943248532289628

# %%
# Q1
train_scores = []
test_scores = []
n_range = range(1, 50,2)

for n in n_range:
    RF_model = RandomForestClassifier(n_estimators=n)
    RF_model.fit(X_train, y_train)
    train_scores.append(RF_model.score(X_train, y_train))
    test_scores.append(RF_model.score(X_test, y_test))
    
plt.plot(n_range, train_scores, label = 'Train')
plt.plot(n_range, test_scores, label = 'Test')
plt.xlabel("Number of estimators")
plt.ylabel("Accuracy")
plt.title("RandomForestClassifier")
plt.legend();

# %%
RF_model = RandomForestClassifier(n_estimators=19)
RF_model.fit(X_train, y_train)
print(RF_model.score(X_train, y_train))
print(RF_model.score(X_test, y_test))
# Out:
# 0.9996142967343791
# 0.8904109589041096

# %%
# class distribution
display(y_test.value_counts())

# predict classification
y_pred_RF_model = RF_model.predict(X_test)


print(f'Recall score: {recall_score(y_test, y_pred_RF_model)*100:0.1f}%')
print(f'Precision score: {precision_score(y_test, y_pred_RF_model)*100:0.1f}%')
print(f'F1 score: {f1_score(y_test, y_pred_RF_model)*100:0.1f}%')


report_initial_dt_ss = classification_report(y_test, y_pred_RF_model)
print(report_initial_dt_ss)
# Out:
# 0    972
# 1     50
# Name: stroke, dtype: int64
# Recall score: 24.0%
# Precision score: 14.0%
# F1 score: 17.6%
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94       972
#            1       0.14      0.24      0.18        50
#
#     accuracy                           0.89      1022
#    macro avg       0.55      0.58      0.56      1022
# weighted avg       0.92      0.89      0.90      1022

# %%
# Compute confusion matrix
conf_matrix_RF_model = confusion_matrix(y_test, y_pred_RF_model)

# Plot confusion matrix
sns.heatmap(conf_matrix_RF_model, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
confusion_matrix
# Out:
# <function sklearn.metrics._classification.confusion_matrix(y_true, y_pred, *, labels=None, sample_weight=None, normalize=None)>

# %% [markdown]
# #### GradientBoostingClassifier

# %%
from sklearn.ensemble import GradientBoostingClassifier

g_b_model = GradientBoostingClassifier(random_state=42)

g_b_model.fit(X_train, y_train)

y_pred_g_b_model = g_b_model.predict(X_test)

# %%
g_b_model.score(X_test, y_test)
# Out:
# 0.8424657534246576

# %%
report_initial_g_b_model= classification_report(y_test, y_pred_g_b_model)
print(report_initial_g_b_model)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.86      0.91       972
#            1       0.16      0.50      0.24        50
#
#     accuracy                           0.84      1022
#    macro avg       0.56      0.68      0.57      1022
# weighted avg       0.93      0.84      0.88      1022

# %%
# Compute confusion matrix
conf_matrix_g_b_model = confusion_matrix(y_test, y_pred_g_b_model)

# Plot confusion matrix
sns.heatmap(conf_matrix_g_b_model, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %% [markdown]
# #### NN tensorflow

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
# Define the model
model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(X_train.shape[1],)))

model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))  # Sigmoid for binary classification

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the model
history = model.fit(X_train, y_train, epochs=1000, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/1000
# 195/195 [==============================] - 1s 3ms/step - loss: 0.4350 - accuracy: 0.7970 - val_loss: 0.4158 - val_accuracy: 0.8136
# Epoch 2/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3505 - accuracy: 0.8409 - val_loss: 0.3540 - val_accuracy: 0.8805
# Epoch 3/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3372 - accuracy: 0.8496 - val_loss: 0.3112 - val_accuracy: 0.8882
# Epoch 4/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3257 - accuracy: 0.8534 - val_loss: 0.3858 - val_accuracy: 0.8329
# Epoch 5/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3177 - accuracy: 0.8570 - val_loss: 0.4108 - val_accuracy: 0.8226
# Epoch 6/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3105 - accuracy: 0.8623 - val_loss: 0.3488 - val_accuracy: 0.8599
# Epoch 7/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3041 - accuracy: 0.8674 - val_loss: 0.3709 - val_accuracy: 0.8445
# Epoch 8/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.2999 - accuracy: 0.8684 - val_loss: 0.3360 - val_accuracy: 0.8715
# Epoch 9/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.2933 - accuracy: 0.8722 - val_loss: 0.3036 - val_accuracy: 0.8875
# Epoch 10/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.2892 - accuracy: 0.8751 - val_loss: 0.2718 - val_accuracy: 0.9004
# Epoch 11/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.2849 - accuracy: 0.8770 - val_loss: 0.2973 - val_accuracy: 0.8740
# Epoch 12/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.2801 - accuracy: 0.8806 - val_loss: 0.2637 - val_accuracy: 0.8991
# Epoch 13/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.2749 - accuracy: 0.8806 - val_loss: 0.3151 - val_accuracy: 0.8618
# Epoch 14/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.2705 - accuracy: 0.8857 - val_loss: 0.2997 - val_accuracy: 0.8843
# Epoch 15/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.2667 - accuracy: 0.8864 - val_loss: 0.2392 - val_accuracy: 0.9242
# Epoch 16/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.2631 - accuracy: 0.8885 - val_loss: 0.2602 - val_accuracy: 0.8927
# Epoch 17/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.2598 - accuracy: 0.8888 - val_loss: 0.2683 - val_accuracy: 0.9042
# Epoch 18/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.2563 - accuracy: 0.8904 - val_loss: 0.2432 - val_accuracy: 0.9152
# Epoch 19/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.2514 - accuracy: 0.8915 - val_loss: 0.2745 - val_accuracy: 0.9023
# Epoch 20/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.2518 - accuracy: 0.8923 - val_loss: 0.3485 - val_accuracy: 0.8445
# Epoch 21/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.2458 - accuracy: 0.8965 - val_loss: 0.2651 - val_accuracy: 0.9100
# Epoch 22/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.2426 - accuracy: 0.8962 - val_loss: 0.2367 - val_accuracy: 0.9203
# Epoch 23/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.2396 - accuracy: 0.8978 - val_loss: 0.2202 - val_accuracy: 0.9332
# Epoch 24/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.2380 - accuracy: 0.8984 - val_loss: 0.2113 - val_accuracy: 0.9428
# Epoch 25/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.2351 - accuracy: 0.9005 - val_loss: 0.2768 - val_accuracy: 0.9087
# Epoch 26/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.2321 - accuracy: 0.9018 - val_loss: 0.2377 - val_accuracy: 0.9222
# Epoch 27/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.2282 - accuracy: 0.9060 - val_loss: 0.2179 - val_accuracy: 0.9338
# Epoch 28/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.2276 - accuracy: 0.9044 - val_loss: 0.1703 - val_accuracy: 0.9550
# Epoch 29/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.2231 - accuracy: 0.9089 - val_loss: 0.2589 - val_accuracy: 0.9132
# Epoch 30/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.2242 - accuracy: 0.9086 - val_loss: 0.2011 - val_accuracy: 0.9447
# Epoch 31/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.2237 - accuracy: 0.9071 - val_loss: 0.2115 - val_accuracy: 0.9357
# Epoch 32/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.2205 - accuracy: 0.9103 - val_loss: 0.2011 - val_accuracy: 0.9428
# Epoch 33/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.2167 - accuracy: 0.9092 - val_loss: 0.2799 - val_accuracy: 0.8952
# Epoch 34/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.2157 - accuracy: 0.9116 - val_loss: 0.1845 - val_accuracy: 0.9454
# Epoch 35/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.2125 - accuracy: 0.9139 - val_loss: 0.2340 - val_accuracy: 0.9312
# Epoch 36/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.2109 - accuracy: 0.9147 - val_loss: 0.1960 - val_accuracy: 0.9524
# Epoch 37/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.2112 - accuracy: 0.9113 - val_loss: 0.1951 - val_accuracy: 0.9486
# Epoch 38/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.2086 - accuracy: 0.9158 - val_loss: 0.2766 - val_accuracy: 0.9113
# Epoch 39/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.2052 - accuracy: 0.9153 - val_loss: 0.2749 - val_accuracy: 0.9081
# Epoch 40/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.2059 - accuracy: 0.9161 - val_loss: 0.2141 - val_accuracy: 0.9267
# Epoch 41/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.2030 - accuracy: 0.9171 - val_loss: 0.1969 - val_accuracy: 0.9402
# Epoch 42/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.2007 - accuracy: 0.9196 - val_loss: 0.1977 - val_accuracy: 0.9454
# Epoch 43/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1993 - accuracy: 0.9190 - val_loss: 0.2233 - val_accuracy: 0.9280
# Epoch 44/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1999 - accuracy: 0.9185 - val_loss: 0.2410 - val_accuracy: 0.9274
# Epoch 45/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1973 - accuracy: 0.9184 - val_loss: 0.1506 - val_accuracy: 0.9621
# Epoch 46/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1963 - accuracy: 0.9203 - val_loss: 0.2467 - val_accuracy: 0.9158
# Epoch 47/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1961 - accuracy: 0.9180 - val_loss: 0.2105 - val_accuracy: 0.9389
# Epoch 48/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1932 - accuracy: 0.9230 - val_loss: 0.2064 - val_accuracy: 0.9364
# Epoch 49/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1910 - accuracy: 0.9245 - val_loss: 0.2077 - val_accuracy: 0.9454
# Epoch 50/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1909 - accuracy: 0.9214 - val_loss: 0.2376 - val_accuracy: 0.9165
# Epoch 51/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1901 - accuracy: 0.9200 - val_loss: 0.2610 - val_accuracy: 0.9094
# Epoch 52/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1885 - accuracy: 0.9227 - val_loss: 0.1897 - val_accuracy: 0.9409
# Epoch 53/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1839 - accuracy: 0.9253 - val_loss: 0.2085 - val_accuracy: 0.9332
# Epoch 54/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1864 - accuracy: 0.9248 - val_loss: 0.1675 - val_accuracy: 0.9595
# Epoch 55/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1844 - accuracy: 0.9245 - val_loss: 0.2096 - val_accuracy: 0.9396
# Epoch 56/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1809 - accuracy: 0.9275 - val_loss: 0.1833 - val_accuracy: 0.9550
# Epoch 57/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1841 - accuracy: 0.9248 - val_loss: 0.1658 - val_accuracy: 0.9550
# Epoch 58/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1820 - accuracy: 0.9248 - val_loss: 0.2370 - val_accuracy: 0.9222
# Epoch 59/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1802 - accuracy: 0.9298 - val_loss: 0.1874 - val_accuracy: 0.9505
# Epoch 60/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1794 - accuracy: 0.9262 - val_loss: 0.1953 - val_accuracy: 0.9383
# Epoch 61/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1768 - accuracy: 0.9278 - val_loss: 0.2073 - val_accuracy: 0.9357
# Epoch 62/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1770 - accuracy: 0.9286 - val_loss: 0.2309 - val_accuracy: 0.9222
# Epoch 63/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1760 - accuracy: 0.9278 - val_loss: 0.1869 - val_accuracy: 0.9505
# Epoch 64/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1762 - accuracy: 0.9299 - val_loss: 0.1745 - val_accuracy: 0.9512
# Epoch 65/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1744 - accuracy: 0.9286 - val_loss: 0.2205 - val_accuracy: 0.9338
# Epoch 66/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1730 - accuracy: 0.9286 - val_loss: 0.1412 - val_accuracy: 0.9653
# Epoch 67/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1718 - accuracy: 0.9290 - val_loss: 0.1897 - val_accuracy: 0.9499
# Epoch 68/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1704 - accuracy: 0.9309 - val_loss: 0.2311 - val_accuracy: 0.9177
# Epoch 69/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1673 - accuracy: 0.9330 - val_loss: 0.2013 - val_accuracy: 0.9338
# Epoch 70/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1730 - accuracy: 0.9298 - val_loss: 0.1679 - val_accuracy: 0.9505
# Epoch 71/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1682 - accuracy: 0.9346 - val_loss: 0.1522 - val_accuracy: 0.9602
# Epoch 72/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1668 - accuracy: 0.9312 - val_loss: 0.2641 - val_accuracy: 0.8959
# Epoch 73/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1673 - accuracy: 0.9320 - val_loss: 0.1603 - val_accuracy: 0.9582
# Epoch 74/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1651 - accuracy: 0.9336 - val_loss: 0.2352 - val_accuracy: 0.9113
# Epoch 75/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1635 - accuracy: 0.9359 - val_loss: 0.2805 - val_accuracy: 0.8946
# Epoch 76/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1637 - accuracy: 0.9336 - val_loss: 0.1316 - val_accuracy: 0.9711
# Epoch 77/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1610 - accuracy: 0.9375 - val_loss: 0.1006 - val_accuracy: 0.9737
# Epoch 78/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1605 - accuracy: 0.9343 - val_loss: 0.1629 - val_accuracy: 0.9492
# Epoch 79/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1631 - accuracy: 0.9344 - val_loss: 0.1521 - val_accuracy: 0.9582
# Epoch 80/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1591 - accuracy: 0.9373 - val_loss: 0.1647 - val_accuracy: 0.9557
# Epoch 81/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1589 - accuracy: 0.9320 - val_loss: 0.1793 - val_accuracy: 0.9512
# Epoch 82/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1577 - accuracy: 0.9378 - val_loss: 0.1429 - val_accuracy: 0.9640
# Epoch 83/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1575 - accuracy: 0.9349 - val_loss: 0.2309 - val_accuracy: 0.9242
# Epoch 84/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1564 - accuracy: 0.9394 - val_loss: 0.2470 - val_accuracy: 0.9113
# Epoch 85/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1572 - accuracy: 0.9336 - val_loss: 0.2442 - val_accuracy: 0.9107
# Epoch 86/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1562 - accuracy: 0.9344 - val_loss: 0.2191 - val_accuracy: 0.9280
# Epoch 87/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1531 - accuracy: 0.9396 - val_loss: 0.1766 - val_accuracy: 0.9479
# Epoch 88/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1552 - accuracy: 0.9380 - val_loss: 0.1658 - val_accuracy: 0.9544
# Epoch 89/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1529 - accuracy: 0.9370 - val_loss: 0.1745 - val_accuracy: 0.9518
# Epoch 90/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1548 - accuracy: 0.9354 - val_loss: 0.1770 - val_accuracy: 0.9467
# Epoch 91/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1492 - accuracy: 0.9410 - val_loss: 0.1498 - val_accuracy: 0.9653
# Epoch 92/1000
# 195/195 [==============================] - 0s 2ms/step - loss: 0.1513 - accuracy: 0.9376 - val_loss: 0.1549 - val_accuracy: 0.9531
# Epoch 93/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1499 - accuracy: 0.9389 - val_loss: 0.1948 - val_accuracy: 0.9422
# Epoch 94/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1496 - accuracy: 0.9389 - val_loss: 0.1640 - val_accuracy: 0.9524
# Epoch 95/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1502 - accuracy: 0.9391 - val_loss: 0.1975 - val_accuracy: 0.9396
# Epoch 96/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1486 - accuracy: 0.9392 - val_loss: 0.1772 - val_accuracy: 0.9467
# Epoch 97/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1491 - accuracy: 0.9378 - val_loss: 0.2299 - val_accuracy: 0.9242
# Epoch 98/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1477 - accuracy: 0.9420 - val_loss: 0.1734 - val_accuracy: 0.9447
# Epoch 99/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1477 - accuracy: 0.9431 - val_loss: 0.1676 - val_accuracy: 0.9467
# Epoch 100/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1443 - accuracy: 0.9429 - val_loss: 0.1558 - val_accuracy: 0.9544
# Epoch 101/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1424 - accuracy: 0.9426 - val_loss: 0.1544 - val_accuracy: 0.9576
# Epoch 102/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1421 - accuracy: 0.9444 - val_loss: 0.1496 - val_accuracy: 0.9595
# Epoch 103/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1426 - accuracy: 0.9417 - val_loss: 0.1374 - val_accuracy: 0.9595
# Epoch 104/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1401 - accuracy: 0.9442 - val_loss: 0.1553 - val_accuracy: 0.9544
# Epoch 105/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1441 - accuracy: 0.9402 - val_loss: 0.2039 - val_accuracy: 0.9402
# Epoch 106/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1411 - accuracy: 0.9442 - val_loss: 0.1423 - val_accuracy: 0.9589
# Epoch 107/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1408 - accuracy: 0.9446 - val_loss: 0.1851 - val_accuracy: 0.9396
# Epoch 108/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1368 - accuracy: 0.9444 - val_loss: 0.2174 - val_accuracy: 0.9299
# Epoch 109/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1399 - accuracy: 0.9413 - val_loss: 0.1680 - val_accuracy: 0.9512
# Epoch 110/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1369 - accuracy: 0.9452 - val_loss: 0.1756 - val_accuracy: 0.9479
# Epoch 111/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1379 - accuracy: 0.9431 - val_loss: 0.2029 - val_accuracy: 0.9383
# Epoch 112/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1382 - accuracy: 0.9423 - val_loss: 0.0837 - val_accuracy: 0.9756
# Epoch 113/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1368 - accuracy: 0.9463 - val_loss: 0.2232 - val_accuracy: 0.9242
# Epoch 114/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1346 - accuracy: 0.9478 - val_loss: 0.1358 - val_accuracy: 0.9653
# Epoch 115/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1355 - accuracy: 0.9442 - val_loss: 0.1756 - val_accuracy: 0.9544
# Epoch 116/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1331 - accuracy: 0.9463 - val_loss: 0.1472 - val_accuracy: 0.9569
# Epoch 117/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1339 - accuracy: 0.9473 - val_loss: 0.2600 - val_accuracy: 0.9030
# Epoch 118/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1319 - accuracy: 0.9478 - val_loss: 0.1862 - val_accuracy: 0.9364
# Epoch 119/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1329 - accuracy: 0.9492 - val_loss: 0.1854 - val_accuracy: 0.9396
# Epoch 120/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1299 - accuracy: 0.9497 - val_loss: 0.1471 - val_accuracy: 0.9563
# Epoch 121/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1339 - accuracy: 0.9436 - val_loss: 0.1297 - val_accuracy: 0.9679
# Epoch 122/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1332 - accuracy: 0.9479 - val_loss: 0.1955 - val_accuracy: 0.9299
# Epoch 123/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1312 - accuracy: 0.9466 - val_loss: 0.1795 - val_accuracy: 0.9434
# Epoch 124/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1298 - accuracy: 0.9486 - val_loss: 0.1713 - val_accuracy: 0.9415
# Epoch 125/1000
# 195/195 [==============================] - 0s 2ms/step - loss: 0.1319 - accuracy: 0.9474 - val_loss: 0.1484 - val_accuracy: 0.9557
# Epoch 126/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1289 - accuracy: 0.9484 - val_loss: 0.1242 - val_accuracy: 0.9685
# Epoch 127/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1272 - accuracy: 0.9473 - val_loss: 0.1245 - val_accuracy: 0.9640
# Epoch 128/1000
# 195/195 [==============================] - 0s 2ms/step - loss: 0.1287 - accuracy: 0.9492 - val_loss: 0.2582 - val_accuracy: 0.9042
# Epoch 129/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1305 - accuracy: 0.9492 - val_loss: 0.1519 - val_accuracy: 0.9563
# Epoch 130/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1291 - accuracy: 0.9442 - val_loss: 0.1868 - val_accuracy: 0.9422
# Epoch 131/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1262 - accuracy: 0.9494 - val_loss: 0.1474 - val_accuracy: 0.9524
# Epoch 132/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1268 - accuracy: 0.9465 - val_loss: 0.1991 - val_accuracy: 0.9171
# Epoch 133/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1270 - accuracy: 0.9502 - val_loss: 0.1599 - val_accuracy: 0.9544
# Epoch 134/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1281 - accuracy: 0.9479 - val_loss: 0.1139 - val_accuracy: 0.9666
# Epoch 135/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1254 - accuracy: 0.9494 - val_loss: 0.1229 - val_accuracy: 0.9640
# Epoch 136/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1251 - accuracy: 0.9484 - val_loss: 0.1982 - val_accuracy: 0.9357
# Epoch 137/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1258 - accuracy: 0.9508 - val_loss: 0.2312 - val_accuracy: 0.9145
# Epoch 138/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1237 - accuracy: 0.9510 - val_loss: 0.2219 - val_accuracy: 0.9287
# Epoch 139/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1223 - accuracy: 0.9523 - val_loss: 0.1469 - val_accuracy: 0.9550
# Epoch 140/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1220 - accuracy: 0.9519 - val_loss: 0.1895 - val_accuracy: 0.9370
# Epoch 141/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1231 - accuracy: 0.9503 - val_loss: 0.1960 - val_accuracy: 0.9312
# Epoch 142/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1224 - accuracy: 0.9503 - val_loss: 0.1177 - val_accuracy: 0.9692
# Epoch 143/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1195 - accuracy: 0.9516 - val_loss: 0.1612 - val_accuracy: 0.9492
# Epoch 144/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1225 - accuracy: 0.9508 - val_loss: 0.2113 - val_accuracy: 0.9254
# Epoch 145/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1219 - accuracy: 0.9515 - val_loss: 0.1806 - val_accuracy: 0.9492
# Epoch 146/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1184 - accuracy: 0.9531 - val_loss: 0.2095 - val_accuracy: 0.9306
# Epoch 147/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1201 - accuracy: 0.9516 - val_loss: 0.1729 - val_accuracy: 0.9479
# Epoch 148/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1185 - accuracy: 0.9529 - val_loss: 0.1572 - val_accuracy: 0.9582
# Epoch 149/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1204 - accuracy: 0.9507 - val_loss: 0.1820 - val_accuracy: 0.9377
# Epoch 150/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1175 - accuracy: 0.9550 - val_loss: 0.1409 - val_accuracy: 0.9563
# Epoch 151/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1215 - accuracy: 0.9511 - val_loss: 0.1738 - val_accuracy: 0.9422
# Epoch 152/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1162 - accuracy: 0.9552 - val_loss: 0.1438 - val_accuracy: 0.9595
# Epoch 153/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1197 - accuracy: 0.9500 - val_loss: 0.1589 - val_accuracy: 0.9512
# Epoch 154/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1155 - accuracy: 0.9545 - val_loss: 0.1505 - val_accuracy: 0.9621
# Epoch 155/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1168 - accuracy: 0.9511 - val_loss: 0.1331 - val_accuracy: 0.9608
# Epoch 156/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1145 - accuracy: 0.9550 - val_loss: 0.1890 - val_accuracy: 0.9370
# Epoch 157/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1181 - accuracy: 0.9526 - val_loss: 0.1394 - val_accuracy: 0.9569
# Epoch 158/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1145 - accuracy: 0.9521 - val_loss: 0.1474 - val_accuracy: 0.9576
# Epoch 159/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1143 - accuracy: 0.9536 - val_loss: 0.1987 - val_accuracy: 0.9351
# Epoch 160/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1133 - accuracy: 0.9555 - val_loss: 0.1158 - val_accuracy: 0.9679
# Epoch 161/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1172 - accuracy: 0.9523 - val_loss: 0.1699 - val_accuracy: 0.9467
# Epoch 162/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1151 - accuracy: 0.9553 - val_loss: 0.1361 - val_accuracy: 0.9524
# Epoch 163/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1139 - accuracy: 0.9563 - val_loss: 0.1269 - val_accuracy: 0.9589
# Epoch 164/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1107 - accuracy: 0.9550 - val_loss: 0.1444 - val_accuracy: 0.9531
# Epoch 165/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1137 - accuracy: 0.9540 - val_loss: 0.1709 - val_accuracy: 0.9473
# Epoch 166/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1125 - accuracy: 0.9556 - val_loss: 0.1304 - val_accuracy: 0.9659
# Epoch 167/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1144 - accuracy: 0.9548 - val_loss: 0.1333 - val_accuracy: 0.9602
# Epoch 168/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1109 - accuracy: 0.9542 - val_loss: 0.1600 - val_accuracy: 0.9524
# Epoch 169/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1101 - accuracy: 0.9574 - val_loss: 0.1792 - val_accuracy: 0.9415
# Epoch 170/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1088 - accuracy: 0.9560 - val_loss: 0.1351 - val_accuracy: 0.9557
# Epoch 171/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1100 - accuracy: 0.9547 - val_loss: 0.1594 - val_accuracy: 0.9499
# Epoch 172/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1141 - accuracy: 0.9563 - val_loss: 0.1784 - val_accuracy: 0.9357
# Epoch 173/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1101 - accuracy: 0.9568 - val_loss: 0.1351 - val_accuracy: 0.9621
# Epoch 174/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1071 - accuracy: 0.9574 - val_loss: 0.1038 - val_accuracy: 0.9685
# Epoch 175/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1105 - accuracy: 0.9539 - val_loss: 0.1236 - val_accuracy: 0.9634
# Epoch 176/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1093 - accuracy: 0.9577 - val_loss: 0.1083 - val_accuracy: 0.9685
# Epoch 177/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1137 - accuracy: 0.9569 - val_loss: 0.0829 - val_accuracy: 0.9762
# Epoch 178/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1098 - accuracy: 0.9550 - val_loss: 0.1293 - val_accuracy: 0.9634
# Epoch 179/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1055 - accuracy: 0.9585 - val_loss: 0.2126 - val_accuracy: 0.9287
# Epoch 180/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1073 - accuracy: 0.9569 - val_loss: 0.1586 - val_accuracy: 0.9492
# Epoch 181/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1077 - accuracy: 0.9585 - val_loss: 0.2334 - val_accuracy: 0.9100
# Epoch 182/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1074 - accuracy: 0.9566 - val_loss: 0.1638 - val_accuracy: 0.9441
# Epoch 183/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1051 - accuracy: 0.9579 - val_loss: 0.1444 - val_accuracy: 0.9544
# Epoch 184/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1046 - accuracy: 0.9585 - val_loss: 0.1530 - val_accuracy: 0.9524
# Epoch 185/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1087 - accuracy: 0.9577 - val_loss: 0.1330 - val_accuracy: 0.9589
# Epoch 186/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1026 - accuracy: 0.9587 - val_loss: 0.1636 - val_accuracy: 0.9479
# Epoch 187/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1046 - accuracy: 0.9581 - val_loss: 0.1025 - val_accuracy: 0.9704
# Epoch 188/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1042 - accuracy: 0.9606 - val_loss: 0.2594 - val_accuracy: 0.8933
# Epoch 189/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1089 - accuracy: 0.9545 - val_loss: 0.1630 - val_accuracy: 0.9454
# Epoch 190/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1028 - accuracy: 0.9619 - val_loss: 0.1569 - val_accuracy: 0.9518
# Epoch 191/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1037 - accuracy: 0.9566 - val_loss: 0.2078 - val_accuracy: 0.9280
# Epoch 192/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1013 - accuracy: 0.9600 - val_loss: 0.1621 - val_accuracy: 0.9499
# Epoch 193/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1029 - accuracy: 0.9597 - val_loss: 0.1281 - val_accuracy: 0.9640
# Epoch 194/1000
# 195/195 [==============================] - 0s 2ms/step - loss: 0.1019 - accuracy: 0.9600 - val_loss: 0.1269 - val_accuracy: 0.9640
# Epoch 195/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0990 - accuracy: 0.9622 - val_loss: 0.1325 - val_accuracy: 0.9576
# Epoch 196/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1047 - accuracy: 0.9585 - val_loss: 0.1503 - val_accuracy: 0.9486
# Epoch 197/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1012 - accuracy: 0.9619 - val_loss: 0.1057 - val_accuracy: 0.9724
# Epoch 198/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1015 - accuracy: 0.9584 - val_loss: 0.1131 - val_accuracy: 0.9704
# Epoch 199/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0982 - accuracy: 0.9629 - val_loss: 0.1295 - val_accuracy: 0.9634
# Epoch 200/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1018 - accuracy: 0.9611 - val_loss: 0.1671 - val_accuracy: 0.9460
# Epoch 201/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1017 - accuracy: 0.9590 - val_loss: 0.1069 - val_accuracy: 0.9704
# Epoch 202/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1025 - accuracy: 0.9589 - val_loss: 0.1572 - val_accuracy: 0.9550
# Epoch 203/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0997 - accuracy: 0.9601 - val_loss: 0.1959 - val_accuracy: 0.9338
# Epoch 204/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.1032 - accuracy: 0.9593 - val_loss: 0.1777 - val_accuracy: 0.9306
# Epoch 205/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0987 - accuracy: 0.9613 - val_loss: 0.1955 - val_accuracy: 0.9306
# Epoch 206/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0976 - accuracy: 0.9626 - val_loss: 0.1695 - val_accuracy: 0.9467
# Epoch 207/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0983 - accuracy: 0.9634 - val_loss: 0.1101 - val_accuracy: 0.9647
# Epoch 208/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0952 - accuracy: 0.9611 - val_loss: 0.1301 - val_accuracy: 0.9589
# Epoch 209/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0956 - accuracy: 0.9635 - val_loss: 0.1453 - val_accuracy: 0.9512
# Epoch 210/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0969 - accuracy: 0.9605 - val_loss: 0.1304 - val_accuracy: 0.9569
# Epoch 211/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0984 - accuracy: 0.9605 - val_loss: 0.1410 - val_accuracy: 0.9505
# Epoch 212/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0992 - accuracy: 0.9592 - val_loss: 0.1231 - val_accuracy: 0.9647
# Epoch 213/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0957 - accuracy: 0.9621 - val_loss: 0.1138 - val_accuracy: 0.9627
# Epoch 214/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0968 - accuracy: 0.9606 - val_loss: 0.0799 - val_accuracy: 0.9807
# Epoch 215/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0978 - accuracy: 0.9619 - val_loss: 0.2247 - val_accuracy: 0.9152
# Epoch 216/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0982 - accuracy: 0.9611 - val_loss: 0.1215 - val_accuracy: 0.9608
# Epoch 217/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0947 - accuracy: 0.9629 - val_loss: 0.1412 - val_accuracy: 0.9602
# Epoch 218/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0956 - accuracy: 0.9608 - val_loss: 0.1676 - val_accuracy: 0.9383
# Epoch 219/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0990 - accuracy: 0.9627 - val_loss: 0.1807 - val_accuracy: 0.9409
# Epoch 220/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0965 - accuracy: 0.9605 - val_loss: 0.1481 - val_accuracy: 0.9512
# Epoch 221/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0927 - accuracy: 0.9635 - val_loss: 0.1743 - val_accuracy: 0.9428
# Epoch 222/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0958 - accuracy: 0.9624 - val_loss: 0.1398 - val_accuracy: 0.9537
# Epoch 223/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0991 - accuracy: 0.9621 - val_loss: 0.0892 - val_accuracy: 0.9724
# Epoch 224/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0954 - accuracy: 0.9626 - val_loss: 0.1341 - val_accuracy: 0.9621
# Epoch 225/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0927 - accuracy: 0.9654 - val_loss: 0.1230 - val_accuracy: 0.9659
# Epoch 226/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0897 - accuracy: 0.9674 - val_loss: 0.1834 - val_accuracy: 0.9377
# Epoch 227/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0946 - accuracy: 0.9626 - val_loss: 0.1756 - val_accuracy: 0.9389
# Epoch 228/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0931 - accuracy: 0.9656 - val_loss: 0.1513 - val_accuracy: 0.9499
# Epoch 229/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0954 - accuracy: 0.9617 - val_loss: 0.1561 - val_accuracy: 0.9441
# Epoch 230/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0944 - accuracy: 0.9646 - val_loss: 0.1709 - val_accuracy: 0.9396
# Epoch 231/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0878 - accuracy: 0.9680 - val_loss: 0.2033 - val_accuracy: 0.9235
# Epoch 232/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0925 - accuracy: 0.9653 - val_loss: 0.1625 - val_accuracy: 0.9512
# Epoch 233/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0942 - accuracy: 0.9638 - val_loss: 0.1459 - val_accuracy: 0.9569
# Epoch 234/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0942 - accuracy: 0.9626 - val_loss: 0.1962 - val_accuracy: 0.9344
# Epoch 235/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0910 - accuracy: 0.9659 - val_loss: 0.1442 - val_accuracy: 0.9550
# Epoch 236/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0897 - accuracy: 0.9664 - val_loss: 0.1838 - val_accuracy: 0.9364
# Epoch 237/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0921 - accuracy: 0.9638 - val_loss: 0.1050 - val_accuracy: 0.9672
# Epoch 238/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0902 - accuracy: 0.9653 - val_loss: 0.2114 - val_accuracy: 0.9222
# Epoch 239/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0935 - accuracy: 0.9645 - val_loss: 0.1386 - val_accuracy: 0.9569
# Epoch 240/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0920 - accuracy: 0.9654 - val_loss: 0.1280 - val_accuracy: 0.9608
# Epoch 241/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0893 - accuracy: 0.9671 - val_loss: 0.1641 - val_accuracy: 0.9434
# Epoch 242/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0903 - accuracy: 0.9638 - val_loss: 0.1153 - val_accuracy: 0.9666
# Epoch 243/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0905 - accuracy: 0.9669 - val_loss: 0.2321 - val_accuracy: 0.9158
# Epoch 244/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0927 - accuracy: 0.9617 - val_loss: 0.1801 - val_accuracy: 0.9383
# Epoch 245/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0885 - accuracy: 0.9656 - val_loss: 0.1766 - val_accuracy: 0.9389
# Epoch 246/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0892 - accuracy: 0.9653 - val_loss: 0.0984 - val_accuracy: 0.9704
# Epoch 247/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0919 - accuracy: 0.9627 - val_loss: 0.1200 - val_accuracy: 0.9659
# Epoch 248/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0905 - accuracy: 0.9650 - val_loss: 0.2149 - val_accuracy: 0.9287
# Epoch 249/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0920 - accuracy: 0.9642 - val_loss: 0.0826 - val_accuracy: 0.9769
# Epoch 250/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0886 - accuracy: 0.9667 - val_loss: 0.1483 - val_accuracy: 0.9512
# Epoch 251/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0908 - accuracy: 0.9651 - val_loss: 0.0983 - val_accuracy: 0.9711
# Epoch 252/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0888 - accuracy: 0.9671 - val_loss: 0.1954 - val_accuracy: 0.9261
# Epoch 253/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0872 - accuracy: 0.9677 - val_loss: 0.1641 - val_accuracy: 0.9486
# Epoch 254/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0907 - accuracy: 0.9653 - val_loss: 0.1006 - val_accuracy: 0.9692
# Epoch 255/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0868 - accuracy: 0.9683 - val_loss: 0.1358 - val_accuracy: 0.9505
# Epoch 256/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0842 - accuracy: 0.9688 - val_loss: 0.1600 - val_accuracy: 0.9409
# Epoch 257/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0887 - accuracy: 0.9669 - val_loss: 0.2298 - val_accuracy: 0.9152
# Epoch 258/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0889 - accuracy: 0.9669 - val_loss: 0.1362 - val_accuracy: 0.9518
# Epoch 259/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0880 - accuracy: 0.9661 - val_loss: 0.0734 - val_accuracy: 0.9807
# Epoch 260/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0864 - accuracy: 0.9667 - val_loss: 0.2479 - val_accuracy: 0.8978
# Epoch 261/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0866 - accuracy: 0.9683 - val_loss: 0.1699 - val_accuracy: 0.9486
# Epoch 262/1000
# 195/195 [==============================] - 0s 2ms/step - loss: 0.0857 - accuracy: 0.9683 - val_loss: 0.2016 - val_accuracy: 0.9299
# Epoch 263/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0875 - accuracy: 0.9659 - val_loss: 0.2377 - val_accuracy: 0.9152
# Epoch 264/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0864 - accuracy: 0.9664 - val_loss: 0.1372 - val_accuracy: 0.9595
# Epoch 265/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0886 - accuracy: 0.9661 - val_loss: 0.1160 - val_accuracy: 0.9647
# Epoch 266/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0861 - accuracy: 0.9674 - val_loss: 0.1913 - val_accuracy: 0.9312
# Epoch 267/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0826 - accuracy: 0.9683 - val_loss: 0.1383 - val_accuracy: 0.9544
# Epoch 268/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0897 - accuracy: 0.9656 - val_loss: 0.1683 - val_accuracy: 0.9422
# Epoch 269/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0919 - accuracy: 0.9650 - val_loss: 0.1062 - val_accuracy: 0.9685
# Epoch 270/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0859 - accuracy: 0.9674 - val_loss: 0.1208 - val_accuracy: 0.9679
# Epoch 271/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0827 - accuracy: 0.9698 - val_loss: 0.1208 - val_accuracy: 0.9666
# Epoch 272/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0824 - accuracy: 0.9691 - val_loss: 0.1990 - val_accuracy: 0.9319
# Epoch 273/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0817 - accuracy: 0.9699 - val_loss: 0.1147 - val_accuracy: 0.9595
# Epoch 274/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0848 - accuracy: 0.9666 - val_loss: 0.1073 - val_accuracy: 0.9730
# Epoch 275/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0837 - accuracy: 0.9698 - val_loss: 0.1459 - val_accuracy: 0.9569
# Epoch 276/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0833 - accuracy: 0.9674 - val_loss: 0.1625 - val_accuracy: 0.9467
# Epoch 277/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0853 - accuracy: 0.9669 - val_loss: 0.0997 - val_accuracy: 0.9717
# Epoch 278/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0825 - accuracy: 0.9675 - val_loss: 0.1480 - val_accuracy: 0.9524
# Epoch 279/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0848 - accuracy: 0.9682 - val_loss: 0.0983 - val_accuracy: 0.9692
# Epoch 280/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0855 - accuracy: 0.9683 - val_loss: 0.1491 - val_accuracy: 0.9492
# Epoch 281/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0840 - accuracy: 0.9703 - val_loss: 0.1154 - val_accuracy: 0.9640
# Epoch 282/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0808 - accuracy: 0.9677 - val_loss: 0.1331 - val_accuracy: 0.9627
# Epoch 283/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0817 - accuracy: 0.9690 - val_loss: 0.1113 - val_accuracy: 0.9647
# Epoch 284/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0853 - accuracy: 0.9671 - val_loss: 0.1181 - val_accuracy: 0.9685
# Epoch 285/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0842 - accuracy: 0.9682 - val_loss: 0.1370 - val_accuracy: 0.9627
# Epoch 286/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0804 - accuracy: 0.9719 - val_loss: 0.1645 - val_accuracy: 0.9479
# Epoch 287/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0806 - accuracy: 0.9698 - val_loss: 0.0773 - val_accuracy: 0.9801
# Epoch 288/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0781 - accuracy: 0.9701 - val_loss: 0.1595 - val_accuracy: 0.9447
# Epoch 289/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0815 - accuracy: 0.9706 - val_loss: 0.1290 - val_accuracy: 0.9666
# Epoch 290/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0830 - accuracy: 0.9679 - val_loss: 0.0638 - val_accuracy: 0.9801
# Epoch 291/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0822 - accuracy: 0.9698 - val_loss: 0.2324 - val_accuracy: 0.9145
# Epoch 292/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0841 - accuracy: 0.9675 - val_loss: 0.1719 - val_accuracy: 0.9434
# Epoch 293/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0833 - accuracy: 0.9680 - val_loss: 0.1935 - val_accuracy: 0.9338
# Epoch 294/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0817 - accuracy: 0.9672 - val_loss: 0.1225 - val_accuracy: 0.9672
# Epoch 295/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0798 - accuracy: 0.9732 - val_loss: 0.1404 - val_accuracy: 0.9582
# Epoch 296/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0807 - accuracy: 0.9685 - val_loss: 0.0930 - val_accuracy: 0.9769
# Epoch 297/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0823 - accuracy: 0.9699 - val_loss: 0.0913 - val_accuracy: 0.9762
# Epoch 298/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0774 - accuracy: 0.9724 - val_loss: 0.1943 - val_accuracy: 0.9383
# Epoch 299/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0785 - accuracy: 0.9724 - val_loss: 0.2356 - val_accuracy: 0.9184
# Epoch 300/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0803 - accuracy: 0.9712 - val_loss: 0.1621 - val_accuracy: 0.9479
# Epoch 301/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0815 - accuracy: 0.9685 - val_loss: 0.1091 - val_accuracy: 0.9692
# Epoch 302/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0785 - accuracy: 0.9687 - val_loss: 0.1110 - val_accuracy: 0.9704
# Epoch 303/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0781 - accuracy: 0.9711 - val_loss: 0.1186 - val_accuracy: 0.9672
# Epoch 304/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0783 - accuracy: 0.9693 - val_loss: 0.2468 - val_accuracy: 0.9062
# Epoch 305/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0798 - accuracy: 0.9683 - val_loss: 0.1506 - val_accuracy: 0.9563
# Epoch 306/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0765 - accuracy: 0.9740 - val_loss: 0.1421 - val_accuracy: 0.9576
# Epoch 307/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0775 - accuracy: 0.9704 - val_loss: 0.1753 - val_accuracy: 0.9447
# Epoch 308/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0769 - accuracy: 0.9712 - val_loss: 0.1515 - val_accuracy: 0.9460
# Epoch 309/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0752 - accuracy: 0.9725 - val_loss: 0.2543 - val_accuracy: 0.9030
# Epoch 310/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0838 - accuracy: 0.9688 - val_loss: 0.2610 - val_accuracy: 0.9113
# Epoch 311/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0802 - accuracy: 0.9704 - val_loss: 0.1368 - val_accuracy: 0.9569
# Epoch 312/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0790 - accuracy: 0.9719 - val_loss: 0.1657 - val_accuracy: 0.9492
# Epoch 313/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0758 - accuracy: 0.9735 - val_loss: 0.1236 - val_accuracy: 0.9685
# Epoch 314/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0776 - accuracy: 0.9711 - val_loss: 0.1487 - val_accuracy: 0.9550
# Epoch 315/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0785 - accuracy: 0.9699 - val_loss: 0.1048 - val_accuracy: 0.9737
# Epoch 316/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0780 - accuracy: 0.9701 - val_loss: 0.1622 - val_accuracy: 0.9441
# Epoch 317/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0760 - accuracy: 0.9724 - val_loss: 0.1358 - val_accuracy: 0.9640
# Epoch 318/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0788 - accuracy: 0.9696 - val_loss: 0.1359 - val_accuracy: 0.9589
# Epoch 319/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0769 - accuracy: 0.9706 - val_loss: 0.1196 - val_accuracy: 0.9672
# Epoch 320/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0745 - accuracy: 0.9733 - val_loss: 0.1381 - val_accuracy: 0.9576
# Epoch 321/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0729 - accuracy: 0.9722 - val_loss: 0.1837 - val_accuracy: 0.9434
# Epoch 322/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0712 - accuracy: 0.9738 - val_loss: 0.1338 - val_accuracy: 0.9563
# Epoch 323/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0759 - accuracy: 0.9716 - val_loss: 0.0938 - val_accuracy: 0.9737
# Epoch 324/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0777 - accuracy: 0.9709 - val_loss: 0.1866 - val_accuracy: 0.9344
# Epoch 325/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0747 - accuracy: 0.9714 - val_loss: 0.1001 - val_accuracy: 0.9717
# Epoch 326/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0760 - accuracy: 0.9711 - val_loss: 0.1363 - val_accuracy: 0.9550
# Epoch 327/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0716 - accuracy: 0.9743 - val_loss: 0.1543 - val_accuracy: 0.9505
# Epoch 328/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0757 - accuracy: 0.9707 - val_loss: 0.1679 - val_accuracy: 0.9492
# Epoch 329/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0745 - accuracy: 0.9752 - val_loss: 0.1987 - val_accuracy: 0.9377
# Epoch 330/1000
# ...
# Epoch 892/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0374 - accuracy: 0.9870 - val_loss: 0.2529 - val_accuracy: 0.9447
# Epoch 893/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0356 - accuracy: 0.9868 - val_loss: 0.1568 - val_accuracy: 0.9659
# Epoch 894/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0451 - accuracy: 0.9834 - val_loss: 0.2688 - val_accuracy: 0.9364
# Epoch 895/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0409 - accuracy: 0.9857 - val_loss: 0.1541 - val_accuracy: 0.9647
# Epoch 896/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0395 - accuracy: 0.9855 - val_loss: 0.2078 - val_accuracy: 0.9550
# Epoch 897/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0433 - accuracy: 0.9842 - val_loss: 0.2655 - val_accuracy: 0.9434
# Epoch 898/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0379 - accuracy: 0.9857 - val_loss: 0.3321 - val_accuracy: 0.9229
# Epoch 899/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0378 - accuracy: 0.9876 - val_loss: 0.2215 - val_accuracy: 0.9512
# Epoch 900/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0300 - accuracy: 0.9883 - val_loss: 0.2744 - val_accuracy: 0.9274
# Epoch 901/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0428 - accuracy: 0.9839 - val_loss: 0.2565 - val_accuracy: 0.9383
# Epoch 902/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0365 - accuracy: 0.9862 - val_loss: 0.1788 - val_accuracy: 0.9653
# Epoch 903/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0392 - accuracy: 0.9876 - val_loss: 0.1846 - val_accuracy: 0.9614
# Epoch 904/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0320 - accuracy: 0.9892 - val_loss: 0.1632 - val_accuracy: 0.9685
# Epoch 905/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0338 - accuracy: 0.9894 - val_loss: 0.3104 - val_accuracy: 0.9396
# Epoch 906/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0405 - accuracy: 0.9878 - val_loss: 0.2425 - val_accuracy: 0.9409
# Epoch 907/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0346 - accuracy: 0.9879 - val_loss: 0.2543 - val_accuracy: 0.9319
# Epoch 908/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0460 - accuracy: 0.9841 - val_loss: 0.1410 - val_accuracy: 0.9704
# Epoch 909/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0349 - accuracy: 0.9889 - val_loss: 0.2680 - val_accuracy: 0.9409
# Epoch 910/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0500 - accuracy: 0.9823 - val_loss: 0.1763 - val_accuracy: 0.9595
# Epoch 911/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0381 - accuracy: 0.9873 - val_loss: 0.2089 - val_accuracy: 0.9512
# Epoch 912/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0371 - accuracy: 0.9860 - val_loss: 0.3400 - val_accuracy: 0.9312
# Epoch 913/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0453 - accuracy: 0.9851 - val_loss: 0.1757 - val_accuracy: 0.9653
# Epoch 914/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0382 - accuracy: 0.9862 - val_loss: 0.2992 - val_accuracy: 0.9312
# Epoch 915/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0350 - accuracy: 0.9867 - val_loss: 0.2153 - val_accuracy: 0.9537
# Epoch 916/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0349 - accuracy: 0.9892 - val_loss: 0.1830 - val_accuracy: 0.9647
# Epoch 917/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0385 - accuracy: 0.9860 - val_loss: 0.2292 - val_accuracy: 0.9505
# Epoch 918/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0334 - accuracy: 0.9886 - val_loss: 0.2601 - val_accuracy: 0.9454
# Epoch 919/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0363 - accuracy: 0.9876 - val_loss: 0.2249 - val_accuracy: 0.9518
# Epoch 920/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0412 - accuracy: 0.9854 - val_loss: 0.2119 - val_accuracy: 0.9595
# Epoch 921/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0467 - accuracy: 0.9836 - val_loss: 0.1461 - val_accuracy: 0.9698
# Epoch 922/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0436 - accuracy: 0.9833 - val_loss: 0.2425 - val_accuracy: 0.9492
# Epoch 923/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0382 - accuracy: 0.9862 - val_loss: 0.2249 - val_accuracy: 0.9512
# Epoch 924/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0416 - accuracy: 0.9851 - val_loss: 0.2901 - val_accuracy: 0.9319
# Epoch 925/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0355 - accuracy: 0.9870 - val_loss: 0.2261 - val_accuracy: 0.9460
# Epoch 926/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0370 - accuracy: 0.9870 - val_loss: 0.2093 - val_accuracy: 0.9595
# Epoch 927/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0380 - accuracy: 0.9871 - val_loss: 0.1963 - val_accuracy: 0.9640
# Epoch 928/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0411 - accuracy: 0.9865 - val_loss: 0.1994 - val_accuracy: 0.9576
# Epoch 929/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0473 - accuracy: 0.9825 - val_loss: 0.2702 - val_accuracy: 0.9428
# Epoch 930/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0365 - accuracy: 0.9876 - val_loss: 0.2545 - val_accuracy: 0.9479
# Epoch 931/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0359 - accuracy: 0.9892 - val_loss: 0.2795 - val_accuracy: 0.9389
# Epoch 932/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0388 - accuracy: 0.9868 - val_loss: 0.2256 - val_accuracy: 0.9524
# Epoch 933/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0393 - accuracy: 0.9857 - val_loss: 0.2803 - val_accuracy: 0.9293
# Epoch 934/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0450 - accuracy: 0.9841 - val_loss: 0.3398 - val_accuracy: 0.9184
# Epoch 935/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0412 - accuracy: 0.9847 - val_loss: 0.2439 - val_accuracy: 0.9454
# Epoch 936/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0407 - accuracy: 0.9852 - val_loss: 0.1527 - val_accuracy: 0.9685
# Epoch 937/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0383 - accuracy: 0.9859 - val_loss: 0.2792 - val_accuracy: 0.9486
# Epoch 938/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0378 - accuracy: 0.9855 - val_loss: 0.1905 - val_accuracy: 0.9634
# Epoch 939/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0342 - accuracy: 0.9875 - val_loss: 0.2301 - val_accuracy: 0.9518
# Epoch 940/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0385 - accuracy: 0.9863 - val_loss: 0.2183 - val_accuracy: 0.9544
# Epoch 941/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0348 - accuracy: 0.9884 - val_loss: 0.1576 - val_accuracy: 0.9653
# Epoch 942/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0369 - accuracy: 0.9871 - val_loss: 0.2226 - val_accuracy: 0.9512
# Epoch 943/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0349 - accuracy: 0.9884 - val_loss: 0.2551 - val_accuracy: 0.9441
# Epoch 944/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0356 - accuracy: 0.9881 - val_loss: 0.2471 - val_accuracy: 0.9537
# Epoch 945/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0374 - accuracy: 0.9870 - val_loss: 0.1283 - val_accuracy: 0.9711
# Epoch 946/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0372 - accuracy: 0.9883 - val_loss: 0.1941 - val_accuracy: 0.9569
# Epoch 947/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0422 - accuracy: 0.9842 - val_loss: 0.3236 - val_accuracy: 0.9377
# Epoch 948/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0384 - accuracy: 0.9868 - val_loss: 0.3362 - val_accuracy: 0.9274
# Epoch 949/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0320 - accuracy: 0.9886 - val_loss: 0.1718 - val_accuracy: 0.9602
# Epoch 950/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0342 - accuracy: 0.9889 - val_loss: 0.2204 - val_accuracy: 0.9544
# Epoch 951/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0365 - accuracy: 0.9867 - val_loss: 0.2439 - val_accuracy: 0.9409
# Epoch 952/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0390 - accuracy: 0.9859 - val_loss: 0.2133 - val_accuracy: 0.9492
# Epoch 953/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0393 - accuracy: 0.9868 - val_loss: 0.2110 - val_accuracy: 0.9589
# Epoch 954/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0382 - accuracy: 0.9873 - val_loss: 0.1997 - val_accuracy: 0.9640
# Epoch 955/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0360 - accuracy: 0.9881 - val_loss: 0.1716 - val_accuracy: 0.9647
# Epoch 956/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0416 - accuracy: 0.9854 - val_loss: 0.2603 - val_accuracy: 0.9473
# Epoch 957/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0351 - accuracy: 0.9868 - val_loss: 0.2699 - val_accuracy: 0.9486
# Epoch 958/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0395 - accuracy: 0.9857 - val_loss: 0.1810 - val_accuracy: 0.9582
# Epoch 959/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0383 - accuracy: 0.9863 - val_loss: 0.3344 - val_accuracy: 0.9280
# Epoch 960/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0369 - accuracy: 0.9865 - val_loss: 0.2037 - val_accuracy: 0.9602
# Epoch 961/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0356 - accuracy: 0.9873 - val_loss: 0.2150 - val_accuracy: 0.9589
# Epoch 962/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0366 - accuracy: 0.9873 - val_loss: 0.3083 - val_accuracy: 0.9261
# Epoch 963/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0396 - accuracy: 0.9862 - val_loss: 0.2528 - val_accuracy: 0.9467
# Epoch 964/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0384 - accuracy: 0.9868 - val_loss: 0.2923 - val_accuracy: 0.9402
# Epoch 965/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0364 - accuracy: 0.9889 - val_loss: 0.2120 - val_accuracy: 0.9589
# Epoch 966/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0339 - accuracy: 0.9879 - val_loss: 0.2517 - val_accuracy: 0.9512
# Epoch 967/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0335 - accuracy: 0.9889 - val_loss: 0.2552 - val_accuracy: 0.9460
# Epoch 968/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0330 - accuracy: 0.9889 - val_loss: 0.2028 - val_accuracy: 0.9557
# Epoch 969/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0332 - accuracy: 0.9881 - val_loss: 0.1356 - val_accuracy: 0.9730
# Epoch 970/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0406 - accuracy: 0.9846 - val_loss: 0.1863 - val_accuracy: 0.9653
# Epoch 971/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0385 - accuracy: 0.9878 - val_loss: 0.2395 - val_accuracy: 0.9499
# Epoch 972/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0352 - accuracy: 0.9876 - val_loss: 0.1809 - val_accuracy: 0.9634
# Epoch 973/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0383 - accuracy: 0.9881 - val_loss: 0.1846 - val_accuracy: 0.9621
# Epoch 974/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0378 - accuracy: 0.9860 - val_loss: 0.2468 - val_accuracy: 0.9499
# Epoch 975/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0388 - accuracy: 0.9867 - val_loss: 0.2092 - val_accuracy: 0.9576
# Epoch 976/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0371 - accuracy: 0.9884 - val_loss: 0.2743 - val_accuracy: 0.9389
# Epoch 977/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0381 - accuracy: 0.9868 - val_loss: 0.2611 - val_accuracy: 0.9473
# Epoch 978/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0336 - accuracy: 0.9873 - val_loss: 0.1585 - val_accuracy: 0.9692
# Epoch 979/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0388 - accuracy: 0.9865 - val_loss: 0.1730 - val_accuracy: 0.9653
# Epoch 980/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0358 - accuracy: 0.9873 - val_loss: 0.2368 - val_accuracy: 0.9518
# Epoch 981/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0394 - accuracy: 0.9862 - val_loss: 0.1829 - val_accuracy: 0.9614
# Epoch 982/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0354 - accuracy: 0.9886 - val_loss: 0.1974 - val_accuracy: 0.9608
# Epoch 983/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0396 - accuracy: 0.9873 - val_loss: 0.1953 - val_accuracy: 0.9557
# Epoch 984/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0362 - accuracy: 0.9879 - val_loss: 0.2575 - val_accuracy: 0.9460
# Epoch 985/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0405 - accuracy: 0.9838 - val_loss: 0.2584 - val_accuracy: 0.9428
# Epoch 986/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0362 - accuracy: 0.9886 - val_loss: 0.3828 - val_accuracy: 0.9036
# Epoch 987/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0348 - accuracy: 0.9878 - val_loss: 0.1992 - val_accuracy: 0.9602
# Epoch 988/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0406 - accuracy: 0.9857 - val_loss: 0.1649 - val_accuracy: 0.9672
# Epoch 989/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0360 - accuracy: 0.9886 - val_loss: 0.3379 - val_accuracy: 0.9248
# Epoch 990/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0335 - accuracy: 0.9884 - val_loss: 0.3146 - val_accuracy: 0.9235
# Epoch 991/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0315 - accuracy: 0.9894 - val_loss: 0.1968 - val_accuracy: 0.9576
# Epoch 992/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0396 - accuracy: 0.9855 - val_loss: 0.3469 - val_accuracy: 0.9139
# Epoch 993/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0408 - accuracy: 0.9867 - val_loss: 0.2546 - val_accuracy: 0.9479
# Epoch 994/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0358 - accuracy: 0.9883 - val_loss: 0.3003 - val_accuracy: 0.9383
# Epoch 995/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0343 - accuracy: 0.9884 - val_loss: 0.1811 - val_accuracy: 0.9589
# Epoch 996/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0394 - accuracy: 0.9859 - val_loss: 0.2688 - val_accuracy: 0.9486
# Epoch 997/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0336 - accuracy: 0.9894 - val_loss: 0.2810 - val_accuracy: 0.9357
# Epoch 998/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0313 - accuracy: 0.9891 - val_loss: 0.2457 - val_accuracy: 0.9524
# Epoch 999/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0316 - accuracy: 0.9892 - val_loss: 0.2960 - val_accuracy: 0.9428
# Epoch 1000/1000
# 195/195 [==============================] - 0s 1ms/step - loss: 0.0392 - accuracy: 0.9867 - val_loss: 0.1845 - val_accuracy: 0.9659

# %%
# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy*100:.2f}%")
# Out:
# 32/32 [==============================] - 0s 937us/step - loss: 1.6193 - accuracy: 0.8542
# Test Accuracy: 85.42%

# %%
# Make predictions
y_pred_NN = model.predict(X_test)
y_pred_NN = (y_pred_NN > 0.5).astype("int32")  # Convert probabilities to binary outputs

# Calculate precision, recall, and F1 score
precision = precision_score(y_test, y_pred_NN)
recall = recall_score(y_test, y_pred_NN)
f1 = f1_score(y_test, y_pred_NN)

print(f"Precision: {precision}, Recall: {recall}, F1 Score: {f1}")
# Out:
# Precision: 0.0975609756097561, Recall: 0.24, F1 Score: 0.13872832369942198

# %%
report_initial_NN_model = classification_report(y_test, y_pred_NN)
print(report_initial_NN_model)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.89      0.92       972
#            1       0.10      0.24      0.14        50
#
#     accuracy                           0.85      1022
#    macro avg       0.53      0.56      0.53      1022
# weighted avg       0.92      0.85      0.88      1022

# %%
# Compute confusion matrix
conf_matrix_NN_model = confusion_matrix(y_test, y_pred_NN)

# Plot confusion matrix
sns.heatmap(conf_matrix_NN_model, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
#### plot confusion matrices for all models

# %%
#  actual confusion matrix objects
confusion_matrices = [conf_matrix_sm,
conf_matrix_logit_ss,
conf_matrix_knn_mmk7,
conf_matrix_knn_mmk19,
conf_matrix_dt_ssn,
conf_matrix_SVM_model,
conf_matrix_PCA,
conf_matrix_RF_model,
conf_matrix_g_b_model,
conf_matrix_NN_model]
titles = ['Logistic Regression (SM)', 
'Logistic Regression (SS)', 
'KNN with 13N',
'KNN with 19N',
'Decision Tree',
'SVM',
'PCA',
'Random Forest', 
'Gradient Boosting', 
'Neural Network']

# %%
# Create a figure and a set of subplots
fig, axes = plt.subplots(2, 5, figsize=(16, 9))  # Adjust the figure size as needed
axes = axes.flatten()  # Flatten the array of axes

# Loop through each confusion matrix
for i, (model, title) in enumerate(zip(confusion_matrices, titles)):
    ax = axes[i]
    sns.heatmap(model, annot=True, fmt='d', ax=ax, cmap='Blues')  # Using 'Blues' colormap
    ax.set_title(title)
    ax.set_xlabel('Predicted')
    ax.set_ylabel('True')

plt.tight_layout()
plt.show()

# %%
# List of predictions from different models
predictions = [y_pred_sm, y_test_pred_logit_ss, y_test_pred_knn_mmk7, y_test_pred_knn_mm19, y_test_pred_dt_ssn,
               y_test_pred_SVM_model, y_test_pred_PCA, y_pred_RF_model, y_pred_g_b_model, y_pred_NN]
titles = ['Logistic Regression (SM)', 
'Logistic Regression (SS)', 
'KNN with 13N',
'KNN with 19N',
'Decision Tree',
'SVM',
'PCA',
'Random Forest', 
'Gradient Boosting', 
'Neural Network']
# Loop through each model's predictions and print the classification report
for y_pred, name in zip(predictions, titles):
    print(f"Classification Report for {name}:")
    print(classification_report(y_test, y_pred))
    print("\n")
# Out:
# Classification Report for Logistic Regression (SM):
#               precision    recall  f1-score   support
#
#            0       0.98      0.69      0.81       972
#            1       0.10      0.70      0.18        50
#
#     accuracy                           0.69      1022
#    macro avg       0.54      0.70      0.50      1022
# weighted avg       0.94      0.69      0.78      1022
#
#
#
# Classification Report for Logistic Regression (SS):
#               precision    recall  f1-score   support
#
#            0       0.97      0.79      0.87       972
#            1       0.12      0.58      0.21        50
#
#     accuracy                           0.78      1022
#    macro avg       0.55      0.69      0.54      1022
# weighted avg       0.93      0.78      0.84      1022
#
#
#
# Classification Report for KNN with 13N:
#               precision    recall  f1-score   support
#
#            0       0.98      0.80      0.88       972
#            1       0.14      0.62      0.22        50
#
#     accuracy                           0.79      1022
#    macro avg       0.56      0.71      0.55      1022
# weighted avg       0.94      0.79      0.85      1022
#
#
#
# Classification Report for KNN with 19N:
#               precision    recall  f1-score   support
#
#            0       0.97      0.80      0.88       972
#            1       0.13      0.60      0.22        50
#
#     accuracy                           0.79      1022
#    macro avg       0.55      0.70      0.55      1022
# weighted avg       0.93      0.79      0.85      1022
#
#
#
# Classification Report for Decision Tree:
#               precision    recall  f1-score   support
#
#            0       0.99      0.59      0.74       972
#            1       0.10      0.92      0.19        50
#
#     accuracy                           0.61      1022
#    macro avg       0.55      0.76      0.46      1022
# weighted avg       0.95      0.61      0.72      1022
#
#
#
# Classification Report for SVM:
#               precision    recall  f1-score   support
#
#            0       0.97      0.81      0.88       972
#            1       0.12      0.50      0.19        50
#
#     accuracy                           0.80      1022
#    macro avg       0.55      0.66      0.54      1022
# weighted avg       0.93      0.80      0.85      1022
#
#
#
# Classification Report for PCA:
#               precision    recall  f1-score   support
#
#            0       0.97      0.79      0.87       972
#            1       0.11      0.50      0.18        50
#
#     accuracy                           0.78      1022
#    macro avg       0.54      0.65      0.52      1022
# weighted avg       0.93      0.78      0.84      1022
#
#
#
# Classification Report for Random Forest:
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94       972
#            1       0.14      0.24      0.18        50
#
#     accuracy                           0.89      1022
#    macro avg       0.55      0.58      0.56      1022
# weighted avg       0.92      0.89      0.90      1022
#
#
#
# Classification Report for Gradient Boosting:
#               precision    recall  f1-score   support
#
#            0       0.97      0.86      0.91       972
#            1       0.16      0.50      0.24        50
#
#     accuracy                           0.84      1022
#    macro avg       0.56      0.68      0.57      1022
# weighted avg       0.93      0.84      0.88      1022
#
#
#
# Classification Report for Neural Network:
#               precision    recall  f1-score   support
#
#            0       0.96      0.89      0.92       972
#            1       0.10      0.24      0.14        50
#
#     accuracy                           0.85      1022
#    macro avg       0.53      0.56      0.53      1022
# weighted avg       0.92      0.85      0.88      1022

# %%
# Initialize lists to store metrics
accuracies = []
precisions = []
recalls = []
f1_scores = []

# Loop through each model's predictions and calculate metrics
for y_pred in predictions:
    accuracies.append(accuracy_score(y_test, y_pred))
    precisions.append(precision_score(y_test, y_pred))
    recalls.append(recall_score(y_test, y_pred))
    f1_scores.append(f1_score(y_test, y_pred))

# %%
# Create a DataFrame with the metrics
metrics_df = pd.DataFrame({
    'Model': titles,
    'Accuracy': accuracies,
    'Precision': precisions,
    'Recall': recalls,
    'F1 Score': f1_scores
})

# %%
plt.figure(figsize=(24, 16))  
ax = metrics_df.set_index('Model').plot(kind='bar', rot=75)
plt.title('Classification Metrics for Different Models')
plt.ylabel('Score')
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))  # Move legend to the side

plt.show()

# %% [markdown]
# the machine learning model perfp

# %% [markdown]
# The results indicate that the Decision Tree model has the highest recall, followed closely by the Logistic Regression model. Given our objective to maximize recall, it would be prudent to opt for Logistic Regression for further tuning. This choice is also supported by the model's superior interpretability and ease of examination
