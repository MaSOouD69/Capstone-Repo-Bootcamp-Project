# %% [markdown]
# # Brainstation Capstone Project
#
# ## Data Science Bootcamp: November 2023 - February 2024
#
# Welcome to my Capstone Project for the Brainstation Data Science Bootcamp. This project represents the culmination of intensive learning and hands-on experience in data science from November 2023 to February 2024.
#
# # Project Overview
#
# ## Project Description
# This capstone project is centered around developing a predictive analysis tool in medical data science, focusing on diseases like heart failure, stroke, diabetes, and cancer. The aim is to create a model that predicts the likelihood of these health conditions based on medical and demographic data.
#
# ## Objective
# The primary goal is to leverage data science and machine learning to provide early warnings for critical health conditions, aiding in early diagnosis and improving patient outcomes.
#
# ## Key Challenges
# - **Data Quality and Reliability**: Ensuring the datasets used are accurate and reliable.
# - **Model Accuracy and Validation**: Building models that are not only accurate but also clinically valid.
# - **Handling Imbalanced Data**: Dealing with the common issue of imbalanced datasets in medical data.
# - **Ethical Considerations**: Addressing data privacy and ethical concerns in predictive healthcare analytics.
#
# ## Technologies Used
# - **Programming Languages**: Python, including libraries like Pandas, NumPy, and Scikit-learn.
# - **Data Visualization**: Using Matplotlib and Seaborn for insights visualization.
# - **Machine Learning Frameworks**: Exploring TensorFlow or PyTorch for advanced modeling.
#
# ## Expected Outcomes
# - **Project**: A robust predictive model for disease risk assessment.
# - **Personal Development**: Improved expertise in data science and machine learning, with a focus on healthcare applications.
#
# ## Why This Project?
# I am deeply interested in the convergence of data science and healthcare. This project offers the opportunity to impact patient care through predictive analytics, aligning with my passion for applying data science to solve real-world problems and enhancing my skills in this critical area.
#
#
# ---
#
# Feel free to explore the different sections of this notebook to see the progress, analysis, and results of my capstone project. I appreciate any feedback or suggestions!

# %% [markdown]
# # Masoud Arefi
#
# Welcome to my professional portfolio in Data Science. Below are links to my LinkedIn profile and GitHub repository where you can find my projects and contributions.
#
# ## Connect with Me
#
# - [LinkedIn](https://www.linkedin.com/in/masoud-arefi/)
# - [GitHub](https://github.com/MaSOouD69/capstone-repo)
#
# ### About Me
#
# I am a passionate data science professional with a keen interest in developing insightful data-driven solutions. My expertise lies in leveraging analytical tools and machine learning techniques to unravel complex data challenges.
#
# Feel free to explore my projects and reach out for collaborations or discussions!

# %% [markdown]
# # First Data set
# # Stroke Prediction and Analysis
#
# ## Introduction
#
# Strokes significantly impact global health, with a surprising fact: 80% of strokes are preventable. This notebook explores key indicators leading to strokes, using data from diverse age groups, genders, habits, and health issues. Our visualizations aim to be intuitive, employing simple yet effective methods for conveying essential information.
#
# ## Problem Statement
#
# Our goal is to visualize the relationships between various lifestyle habits and heart stroke occurrences. We aim to predict stroke probability using optimally tuned models, providing insights for preventive health measures.
#
# ## Questions and Assumptions
#
# In this analysis, we will investigate several questions and assumptions:
#
# 1. **Impact of Age**: Does age significantly influence stroke occurrence, and what is its distribution across populations?
# 2. **BMI and Glucose Levels**: How do higher body mass index and glucose levels correlate with stroke risk?
# 3. **Smoking and Stroke Risk**: Is there a strong link between smoking and increased stroke risk?
# 4. **Heart Disease and Stroke**: How closely are existing heart diseases and stroke occurrences related?
# 5. **Workload and Blood Pressure**: Can high workload and resultant blood pressure increases lead to strokes?
# 6. **Gender-Specific Risks**: Are males more prone to strokes due to work-related stress, or do risks vary across genders?
#
# ## Methodology
#
# - **Data Analysis**: Comprehensive examination of the dataset to understand feature distribution and relationships.
# - **Visualizations**: Using plots and charts to uncover patterns and insights.
# - **Statistical Testing**: Validating assumptions and hypotheses through statistical methods.
# - **Model Building**: Developing predictive models for stroke risk estimation.
# - **Feature Importance**: Identifying key factors that significantly influence stroke risk.
# - **Feature Selection**: Enhancing model accuracy by selecting relevant features.
#
# ## Conclusion
#
# This notebook aims to provide a deeper understanding of the factors leading to strokes and their interplay, essential for developing preventive strategies and early interventions.

# %%
# libraries import
import numpy as np  # Importing NumPy for numerical operations and array handling
import pandas as pd  # Importing Pandas for data manipulation and analysis
import seaborn as sns  # Importing Seaborn for statistical data visualization
import matplotlib.pyplot as plt  # Importing Matplotlib for creating static plots


# Importing necessary libraries from scikit-learn
from sklearn.model_selection import train_test_split  # For splitting data into training and test sets
from sklearn.linear_model import LogisticRegression  # Importing Logistic Regression model for classification tasks
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score  # Importing various metrics to evaluate model performance

from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler  # Importing different scalers for data normalization and standardization

# metrics
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score  # Additional metrics for model evaluation, especially for classification problems

from sklearn.neighbors import KNeighborsClassifier  # Importing K-Nearest Neighbors classifier
from sklearn.tree import DecisionTreeClassifier  # Importing Decision Tree classifier for decision tree models

from imblearn.over_sampling import SMOTE  # Importing SMOTE for handling imbalanced datasets by oversampling

from sklearn.svm import SVC  # Importing Support Vector Machine classifier

# %%
import warnings

# Ignore all warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('healthcare-dataset-stroke-data.csv')

# %%
df.head(5)
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
# Loop through each column and plot a histogram for each numeric columns
for i in ['age','hypertension','heart_disease','avg_glucose_level','stroke']:
    plt.figure()  # Create a new figure for each plot
    df[i].plot(kind='hist')
    plt.title(f'Histogram of {i}')
    plt.show()  # Display the plot

# %% [markdown]
# From histogramof Stroke distribution it is clear that every 5 people out of 100 people are having strokes from our sampling data. Moreover,this is a highly unbalanced data distribution, and null accuracy score of this distribution it self is 95%, whcih imploys any dump model should randomly predictions of stroke could reach accuracy of 95%. So, while modeling and training data, either over sampling or under sampling has to be done to obtain best results.

# %%
# stats of categorical data
round (df.describe(exclude = ['float', 'int64']),2)
# Out:
#         gender ever_married work_type Residence_type smoking_status
# count     5110         5110      5110           5110           5110
# unique       3            2         5              2              4
# top     Female          Yes   Private          Urban   never smoked
# freq      2994         3353      2925           2596           1892

# %%
non_num_df = ['gender','work_type','Residence_type','smoking_status','ever_married']
for i in non_num_df:
    plt.figure()  # Create a new figure for each p
    
    # For non-numeric data, use a count plot
    sns.countplot(y=df[i], data=df)
    plt.title(f'Count Plot of {i}')

    plt.show()  # Display the plot

# %%
df[['gender','work_type','Residence_type','smoking_status','ever_married']].head()
# Out:
#    gender      work_type Residence_type   smoking_status ever_married
# 0    Male        Private          Urban  formerly smoked          Yes
# 1  Female  Self-employed          Rural     never smoked          Yes
# 2    Male        Private          Rural     never smoked          Yes
# 3  Female        Private          Urban           smokes          Yes
# 4  Female  Self-employed          Rural     never smoked          Yes

# %%
# look at null values
df.isna().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
# Filter the DataFrame for rows where 'bmi' is null
df_null_bmi = df[df['bmi'].isna()]
df_null_bmi.head()
# Out:
#        id  gender   age  hypertension  heart_disease ever_married  \
# 1   51676  Female  61.0             0              0          Yes
# 8   27419  Female  59.0             0              0          Yes
# 13   8213    Male  78.0             0              1          Yes
# 19  25226    Male  57.0             0              1           No
# 27  61843    Male  58.0             0              0          Yes
#
#         work_type Residence_type  avg_glucose_level  bmi smoking_status  \
# 1   Self-employed          Rural             202.21  NaN   never smoked
# 8         Private          Rural              76.15  NaN        Unknown
# 13        Private          Urban             219.84  NaN        Unknown
# 19       Govt_job          Urban             217.08  NaN        Unknown
# 27        Private          Rural             189.84  NaN        Unknown
#
#     stroke
# 1        1
# 8        1
# 13       1
# 19       1
# 27       1

# %% [markdown]
# Use visalization for null values

# %%
# Filter the DataFrame for rows where 'bmi' is null
df_null_bmi = df[df['bmi'].isna()]

# Loop through each column
for i in df_null_bmi.columns:
    plt.figure()  # Create a new figure for each plot

    # Check if the column is numeric
    if pd.api.types.is_numeric_dtype(df_null_bmi[i]):
        df_null_bmi[i].plot(kind='hist')
        plt.title(f'Histogram of {i} for Rows with Null BMI')
    else:
        # For non-numeric data, use a count plot
        sns.countplot(y=i, data=df_null_bmi)
        plt.title(f'Count Plot of {i} for Rows with Null BMI')

    plt.show()  # Display the plot

# %% [markdown]
# As we observe the visuals for both the entire DataFrame and the subset with null BMI values, the most standout feature is the 'glucose' column. Let's take a closer look at distributions.

# %%
# avg_glucose_level for whole dataframe
df_null_bmi['avg_glucose_level'].plot(kind='hist')
plt.title(f'Histogram of avg_glucose_level for Rows with Null BMI')
# Out:
# Text(0.5, 1.0, 'Histogram of avg_glucose_level for Rows with Null BMI')

# %%
    # # avg_glucose_level for whole dataframe
    df['avg_glucose_level'].plot(kind='hist')
    plt.title('Histogram of avg_glucose_level')
# Out:
# Text(0.5, 1.0, 'Histogram of avg_glucose_level')

# %% [markdown]
# The distribution of average glucose levels shows noticeable differences between the original dataset and the subset with missing BMI values. Notably, 4 percent of the data is missing, and this missingness does not appear to be random. To address this, it's advisable to retain the records with missing BMI values. However, adding a new column to indicate whether the BMI is missing could be beneficial for machine learning methods. This approach allows us to maintain data integrity while providing a clear indicator for our models to handle these missing values appropriately.

# %%
# deal with missing data
df['missing bmi'] = df['bmi'].isna()

# %%
df['bmi'].isna().sum()
# Out:
# 201

# %%
#check for duplicate rows
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There is no duplicated record in the data set

# %%
# fill missing data with median
df['bmi'] = df['bmi'].fillna(round (df['bmi'].median(), 2))

# %%
df.isna().sum()
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# missing bmi          0
# dtype: int64

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21  28.1     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke  missing bmi
# 0       1        False
# 1       1         True
# 2       1        False
# 3       1        False
# 4       1        False

# %% [markdown]
# # Dataset Overview
#
# Our dataset contains a mix of categorical and numerical features, with a focus on health-related measurements. Here's a breakdown of the features:
#
# ## Categorical Features
# - `gender`: Gender of the individual
# - `ever_married`: Marital status
# - `work_type`: Type of occupation
# - `Residence_type`: Type of residence (Urban/Rural)
# - `smoking_status`: Smoking status
#
# ## Binary Numerical Features
# - `hypertension`: Presence of hypertension (0 = No, 1 = Yes)
# - `heart_disease`: Presence of heart disease (0 = No, 1 = Yes)
# - `stroke`: Occurrence of stroke (0 = No, 1 = Yes)
#
# ## Continuous Numerical Features
# - `age`: Age of the individual
# - `avg_glucose_level`: Average glucose level in blood
# - `bmi`: Body Mass Index
#
# **Note**: The `bmi` feature has missing data that needs to be addressed. Most of our data is categorical, which will require special attention for visualization. For feature extraction, we can consider binning the continuous features (age, avg_glucose_level, and bmi) while keeping other features as they are.

# %% [markdown]
# ### Story telling with data

# %% [markdown]
# ### Data Binning Strategies
#
# In our analysis, we'll be binning several key variables to categorize our data more effectively. Below are the binning strategies for Body Mass Index (BMI), age, and average glucose levels, along with references for each categorization method.
#
# #### Body Mass Index (BMI) Binning
#
# BMI is a key health indicator used to categorize individuals into different weight statuses. The binning of BMI will be based on standard medical categories.
#
# Reference: [Body Mass Index Categories](https://www.medicalnewstoday.com/articles/323446#body-mass-index)
#
# #### Age Binning
#
# Categorizing individuals into different life stages based on age can be particularly relevant in studies where age is a significant factor.
#
# Reference: [Age and Physical Description](https://kidspicturedictionary.com/english-through-pictures/people-english-through-pictures/age-physical-description/)
#
# #### Average Glucose Level Binning
#
# Binning average glucose levels helps in categorizing individuals based on their blood sugar levels, crucial in studies related to diabetes and metabolic health.
#
# Reference: [Normal Blood Sugar Level Chart](https://agamatrix.com/blog/normal-blood-sugar-level-chart/)

# %%
# Binning continuous features for better categorization
df['age_category'] = pd.cut(df['age'], bins=[0, 18, 35, 60, 100], labels=['Child', 'Young Adult', 'Adult', 'Senior'])
df['glucose_category'] = pd.cut(df['avg_glucose_level'], bins=[0, 90, 140, 200, 500], labels=['Low', 'Normal', 'High', 'Very High'])
df['bmi_category'] = pd.cut(df['bmi'], bins=[0, 18.5, 25, 30, 100], labels=['Underweight', 'Normal', 'Overweight', 'Obese'])

# Display the first few rows of the modified DataFrame
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21  28.1     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke  missing bmi age_category glucose_category bmi_category
# 0       1        False       Senior        Very High        Obese
# 1       1         True       Senior        Very High   Overweight
# 2       1        False       Senior           Normal        Obese
# 3       1        False        Adult             High        Obese
# 4       1        False       Senior             High       Normal

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                5110 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
#  12  missing bmi        5110 non-null   bool
#  13  age_category       5110 non-null   category
#  14  glucose_category   5110 non-null   category
#  15  bmi_category       5110 non-null   category
# dtypes: bool(1), category(3), float64(3), int64(4), object(5)
# memory usage: 499.7+ KB

# %% [markdown]
# ##### take a closer look at data with ratio of stroke

# %%
# visualization for columns with object data type
for col in df.select_dtypes('object').columns:
    rate_data = df.groupby([col,'stroke'])['stroke'].count() / df.groupby(col)['stroke'].count()
    
    rate_data.unstack()[[1,0]].sort_values(1).plot(kind='barh',stacked=True)
    plt.title(f"stroke rate per {col}")
    sns.despine()
    plt.show()

# %%
col = 'Work Type'  # Replace with the actual column name if different

# Calculate the rate
rate_data = df.groupby(['work_type', 'stroke'])['stroke'].count() / df.groupby('work_type')['stroke'].count()

# Unstack and sort the data
sorted_data = rate_data.unstack().sort_values(by=1)[[1, 0]]

# Setting up the plot style and palette
plt.figure(figsize=(12, 8))  # Adjust the size as needed
sns.set_style("whitegrid")  # Set the style of the plot
palette = sns.cubehelix_palette(2, start=.5, rot=-.75)  # Advanced color palette

# Plotting
sorted_data.plot(kind='barh', stacked=True, color=palette, ax=plt.gca())

# Adding title and labels with enhanced formatting
plt.title(f"Stroke Rate per {col}", fontsize=16, fontweight='bold', color='darkred')
plt.xlabel('Rate', fontsize=14, fontweight='bold')
plt.ylabel('Work Type', fontsize=14, fontweight='bold')

# Customizing the legend
plt.legend(title='Stroke Status', labels=['Stroke', 'No Stroke'], loc='lower right', fontsize='large', title_fontsize='13')

# Customizing the ticks for better readability
plt.xticks(fontsize=12, fontweight='bold')
plt.yticks(fontsize=12, fontweight='bold')

sns.despine()  # Remove the top and right spines
plt.tight_layout()  # Adjust the layout
plt.show()

# %%
col = 'Smoking Status'

# Calculate the rate for Smoking Status
rate_data = df.groupby(['smoking_status', 'stroke'])['stroke'].count() / df.groupby('smoking_status')['stroke'].count()

# Unstack and sort the data
sorted_data = rate_data.unstack().sort_values(by=1)[[1, 0]]

# Setting up the plot style and palette
plt.figure(figsize=(12, 8))  # Adjust the size as needed
sns.set_style("whitegrid")  # Set the style of the plot
palette = sns.cubehelix_palette(2, start=.5, rot=-.75)  # Advanced color palette

# Plotting
sorted_data.plot(kind='barh', stacked=True, color=palette, ax=plt.gca())

# Adding title and labels with enhanced formatting
plt.title(f"Stroke Rate per {col}", fontsize=16, fontweight='bold', color='darkred')
plt.xlabel('Rate', fontsize=14, fontweight='bold')
plt.ylabel('Smoking Status', fontsize=14, fontweight='bold')

# Customizing the legend
plt.legend(title='Stroke Status', labels=['Stroke', 'No Stroke'], loc='lower right', fontsize='large', title_fontsize='13')

# Customizing the ticks for better readability
plt.xticks(fontsize=12, fontweight='bold')
plt.yticks(fontsize=12, fontweight='bold')

sns.despine()  # Remove the top and right spines
plt.tight_layout()  # Adjust the layout
plt.show()

# %%
col = 'Ever Married'

# Calculate the rate for Ever Married status
rate_data = df.groupby(['ever_married', 'stroke'])['stroke'].count() / df.groupby('ever_married')['stroke'].count()

# Unstack and sort the data
sorted_data = rate_data.unstack().sort_values(by=1)[[1, 0]]

# Setting up the plot style and palette
plt.figure(figsize=(12, 8))  # Adjust the size as needed
sns.set_style("whitegrid")  # Set the style of the plot
palette = sns.cubehelix_palette(2, start=.5, rot=-.75)  # Advanced color palette

# Plotting
sorted_data.plot(kind='barh', stacked=True, color=palette, ax=plt.gca())

# Adding title and labels with enhanced formatting
plt.title(f"Stroke Rate per {col}", fontsize=16, fontweight='bold', color='darkred')
plt.xlabel('Rate', fontsize=14, fontweight='bold')
plt.ylabel('Ever Married', fontsize=14, fontweight='bold')

# Customizing the legend
plt.legend(title='Stroke Status', labels=['Stroke', 'No Stroke'], loc='lower right', fontsize='large', title_fontsize='13')

# Customizing the ticks for better readability
plt.xticks(fontsize=12, fontweight='bold')
plt.yticks(fontsize=12, fontweight='bold')

sns.despine()  # Remove the top and right spines
plt.tight_layout()  # Adjust the layout
plt.show()

# %%
# Calculate the rate
rate_data = df.groupby(['ever_married', 'age_category', 'stroke']).size() / df.groupby(['ever_married', 'age_category']).size()
rate_data = rate_data.reset_index(name='rate')

# Filter for stroke cases only
stroke_rate_data = rate_data[rate_data['stroke'] == 1]

# Setting up the plot style for minimalism
sns.set_style("whitegrid")  # White background with grid for a clean look
plt.figure(figsize=(12, 8))  # Adjust the size as needed

# Plotting with age category hue
bar_plot = sns.catplot(x='ever_married', y='rate', hue='age_category', data=stroke_rate_data, kind='bar', palette='cubehelix', height=6, aspect=2)

# Adding title and labels with enhanced formatting
bar_plot.fig.suptitle("Stroke Rate by Marital Status and Age Category", fontsize=16, fontweight='bold', color='darkred')
bar_plot.set_axis_labels("Ever Married", "Stroke Rate", fontsize=14, fontweight='bold', color='black')

# Customizing the ticks for better readability
plt.xticks(fontsize=12, fontweight='bold', color='black')
plt.yticks(fontsize=12, fontweight='bold', color='black')

# Adjusting the legend for minimalism
# Remove the existing legend and use the one automatically generated by Seaborn
bar_plot._legend.remove()
bar_plot.fig.legend(title='Age Category', loc='upper right', fontsize='medium', title_fontsize='13')

sns.despine()  # Remove the top and right spines for a cleaner look
plt.tight_layout(rect=[0, 0, 1, 0.95])  # Adjust the layout
plt.show()

# %%
df['age_category'].value_counts()
# Out:
# Adult          1907
# Senior         1304
# Young Adult     983
# Child           916
# Name: age_category, dtype: int64

# %%
age_category_counts = df['age_category'].value_counts()

# Setting up the plot style
sns.set_style("whitegrid")

# Creating the bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x=age_category_counts.index, y=age_category_counts.values, palette='cubehelix')

# Adding title and labels
plt.title('Distribution of Age Categories', fontsize=16, fontweight='bold')
plt.xlabel('Age Category', fontsize=14, fontweight='bold')
plt.ylabel('Count', fontsize=14, fontweight='bold')

# Customizing the ticks for better readability
plt.xticks(fontsize=12, fontweight='bold')
plt.yticks(fontsize=12, fontweight='bold')

sns.despine()  # Remove the top and right spines for a cleaner look
plt.show()

# %%
# Calculate the rate by age category
rate_data = df.groupby(['age_category', 'stroke']).size() / df.groupby('age_category').size()
rate_data = rate_data.reset_index(name='rate')

# Filter for stroke cases only
stroke_rate_data = rate_data[rate_data['stroke'] == 1]

# Setting up the plot style for minimalism
sns.set_style("whitegrid")  # White background with grid for a clean look
plt.figure(figsize=(12, 8))  # Adjust the size as needed

# Plotting the stroke rate by age category
bar_plot = sns.barplot(x='age_category', y='rate', data=stroke_rate_data, palette='cubehelix')

# Adding title and labels with enhanced formatting
plt.title("Stroke Rate by Age Category", fontsize=16, fontweight='bold', color='darkred')
plt.xlabel('Age Category', fontsize=14, fontweight='bold', color='black')
plt.ylabel('Stroke Rate', fontsize=14, fontweight='bold', color='black')

# Customizing the ticks for better readability
plt.xticks(fontsize=12, fontweight='bold', color='black')
plt.yticks(fontsize=12, fontweight='bold', color='black')

sns.despine()  # Remove the top and right spines for a cleaner look
plt.tight_layout()  # Adjust the layout
plt.show()

# %%
# Calculate the rate by age category and stroke status
rate_data = df.groupby(['age_category', 'stroke']).size() / df.groupby('age_category').size()
rate_data = rate_data.reset_index(name='rate')

# Setting up the plot style for minimalism
sns.set_style("whitegrid")  # White background with grid for a clean look
plt.figure(figsize=(12, 8))  # Adjust the size as needed

# Plotting the stroke rate by age category with stroke hue
bar_plot = sns.barplot(x='age_category', y='rate', hue='stroke', data=rate_data, palette='cubehelix')

# Adding title and labels with enhanced formatting
plt.title("Stroke Rate by Age Category", fontsize=16, fontweight='bold', color='darkred')
plt.xlabel('Age Category', fontsize=14, fontweight='bold', color='black')
plt.ylabel('Rate', fontsize=14, fontweight='bold', color='black')

# Customizing the ticks for better readability
plt.xticks(fontsize=12, fontweight='bold', color='black')
plt.yticks(fontsize=12, fontweight='bold', color='black')

# Adjusting the legend for minimalism
plt.legend(title='Stroke Status', loc='upper right', fontsize='medium', title_fontsize='13')

sns.despine()  # Remove the top and right spines for a cleaner look
plt.tight_layout()  # Adjust the layout
plt.show()

# %%
# Calculate the stroke rate per BMI category
rate_data = df.groupby(['bmi_category', 'stroke']).size() / df.groupby('bmi_category').size()
rate_data = rate_data.reset_index(name='rate')

# Filter for stroke cases only
stroke_rate_data = rate_data[rate_data['stroke'] == 1]

# Setting up the plot style
sns.set_style("whitegrid")
plt.figure(figsize=(10, 6))

# Plotting the stroke rate by BMI category
sns.barplot(x='bmi_category', y='rate', data=stroke_rate_data, palette='cubehelix')

# Adding title and labels
plt.title('Stroke Rate by BMI Category', fontsize=16, fontweight='bold')
plt.xlabel('BMI Category', fontsize=14, fontweight='bold')
plt.ylabel('Stroke Rate', fontsize=14, fontweight='bold')

# Customizing the ticks for better readability
plt.xticks(fontsize=12, fontweight='bold')
plt.yticks(fontsize=12, fontweight='bold')

sns.despine()  # Remove the top and right spines for a cleaner look
plt.show()

# %%
# Calculate the rate
rate_data = df.groupby(['bmi_category', 'stroke'])['stroke'].count() / df.groupby('bmi_category')['stroke'].count()

# Unstack and sort the data
sorted_data = rate_data.unstack().sort_values(by=1)[[1, 0]]

# Setting up the plot style and palette
plt.figure(figsize=(12, 8))  # Adjust the size as needed
sns.set_style("whitegrid")  # Set the style of the plot
palette = sns.cubehelix_palette(2, start=.5, rot=-.75)  # Advanced color palette

# Plotting
sorted_data.plot(kind='barh', stacked=True, color=palette, ax=plt.gca())

# Adding title and labels with enhanced formatting
plt.title("Stroke Rate per BMI Category", fontsize=16, fontweight='bold', color='darkred')
plt.xlabel('Rate', fontsize=14, fontweight='bold')
plt.ylabel('BMI Category', fontsize=14, fontweight='bold')

# Customizing the legend
plt.legend(title='Stroke Status', labels=['Stroke', 'No Stroke'], loc='lower right', fontsize='large', title_fontsize='13')

# Customizing the ticks for better readability
plt.xticks(fontsize=12, fontweight='bold')
plt.yticks(fontsize=12, fontweight='bold')

sns.despine()  # Remove the top and right spines
plt.tight_layout()  # Adjust the layout
plt.show()

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21  28.1     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke  missing bmi age_category glucose_category bmi_category
# 0       1        False       Senior        Very High        Obese
# 1       1         True       Senior        Very High   Overweight
# 2       1        False       Senior           Normal        Obese
# 3       1        False        Adult             High        Obese
# 4       1        False       Senior             High       Normal

# %% [markdown]
# ##### now for numeric data

# %%
#  visaalization for columns with category data type
for col in df.select_dtypes('category').columns:
    rate_data = df.groupby([col,'stroke'])['stroke'].count() / df.groupby(col)['stroke'].count()
    
    rate_data.unstack()[[1,0]].sort_values(1).plot(kind='barh',stacked=True)
    plt.title(f"stroke rate per {col} type")
    sns.despine()
    plt.show()

# %% [markdown]
# Does marriage and glucose result in a higher incidence of stroke? Considering that children are typically unmarried, we will demonstrate analysis on adults and seniors to examine the stroke ratio in relation to marital status

# %%
# Filter the DataFrame for seniors and adults
senior_df = df[df['age_category'].isin(['Senior', 'Adult'])]

# Calculate the rate
rate_data = senior_df.groupby(['ever_married', 'stroke'])['stroke'].count() / senior_df.groupby('ever_married')['stroke'].count()

# Unstack, sort, and plot
rate_data.unstack().sort_values(by=1)[[1, 0]].plot(kind='barh', stacked=True)
plt.title("Stroke Rate per Marital Status for Seniors and adults")
sns.despine()
plt.show()

# %% [markdown]
# As the visual analysis indicates, the ratio of stroke incidence among adults and seniors appears to be similar for both married and unmarried groups.

# %%
#visualization with numeric data type (heart disease)
rate_data = df.groupby(['heart_disease','stroke'])['stroke'].count() / df.groupby('heart_disease')['stroke'].count()
    
rate_data.unstack()[[1,0]].sort_values(1).plot(kind='barh',stacked=True)
plt.title(f"stroke rate per heart_disease")
sns.despine()
plt.show()

# %%
#visualization with numeric data type (hypertension)
rate_data = df.groupby(['hypertension','stroke'])['stroke'].count() / df.groupby('hypertension')['stroke'].count()
    
rate_data.unstack()[[1,0]].sort_values(1).plot(kind='barh',stacked=True)
plt.title(f"stroke rate per hypertension")
sns.despine()
plt.show()

# %% [markdown]
# ###### Let's examine the relationship between glucose levels and the incidence of stroke. Does a higher glucose level correlate with an increased risk of stroke?

# %%
# Plotting the data
# 'No Stroke' group
sns.kdeplot(data=df[df['stroke'] == 0], x='avg_glucose_level', alpha=1,label='No Stroke',fill=True)
# 'Stroke' group
sns.kdeplot(data=df[df['stroke'] == 1], x='avg_glucose_level',  alpha=0.8, label='Stroke',fill=True)

# Setting the title and labels
plt.title('Distribution of Average Glucose Levels by Stroke Status', fontsize=14)
plt.xlabel('Average Glucose Level', fontsize=12)
plt.ylabel('Density', fontsize=12)

# Adding a legend to show which color corresponds to which group
plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# Glucose level distribution is skewed towards left and most of the strokes can be seen people with regular glucose levels. we can NOT conclude Glucose does not have significant impact on strokes, and its unclear strokes are which group effected by strokes.
#
# avg_glucose_level : High blood glucose is found in stroke cases. A value of 126+ has been observed alot.

# %% [markdown]
# plt.figure()
# sns.pairplot(df,hue="stroke", corner=True)
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ### dive into machine learning

# %%
df_copy=df.copy()
df_copy
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# 1     Self-employed          Rural             202.21  28.1     never smoked
# 2           Private          Rural             105.92  32.5     never smoked
# 3           Private          Urban             171.23  34.4           smokes
# 4     Self-employed          Rural             174.12  24.0     never smoked
# ...             ...            ...                ...   ...              ...
# 5105        Private          Urban              83.75  28.1     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke  missing bmi age_category glucose_category bmi_category
# 0          1        False       Senior        Very High        Obese
# 1          1         True       Senior        Very High   Overweight
# 2          1        False       Senior           Normal        Obese
# 3          1        False        Adult             High        Obese
# 4          1        False       Senior             High       Normal
# ...      ...          ...          ...              ...          ...
# 5105       0         True       Senior              Low   Overweight
# 5106       0        False       Senior           Normal        Obese
# 5107       0        False  Young Adult              Low        Obese
# 5108       0        False        Adult             High   Overweight
# 5109       0        False        Adult              Low   Overweight
#
# [5110 rows x 16 columns]

# %%
from sklearn.preprocessing import (StandardScaler,
                                   LabelEncoder,
                                   OneHotEncoder)

# %%
df_copy.drop(columns = ['id'],inplace=True)

# %% [markdown]
# # preprocessing - label enconding and numerical value scaling
# ohe = OneHotEncoder()
# ss = StandardScaler()
# le = LabelEncoder()

# %% [markdown]
# ## label encoding of ordinal categorical features
# for col in df_copy.columns:
#     df_copy[col] = le.fit_transform(df_copy[col])

# %%
X = df_copy.drop(columns=['stroke'])
y = df_copy['stroke'].copy()

# %%
corr_df = X.corr()

mask = np.triu(corr_df)

plt.figure(figsize=(18, 18))
sns.heatmap(corr_df.round(2), mask=mask, cmap='coolwarm', annot=True)
plt.show()

# %% [markdown]
# ###### check same for standard scaler

# %% [markdown]
# cols = df_copy.columns
# ## normalizing with standard scaler of numerical features
# df_copy[cols] = ss.fit_transform(df_copy[cols])
#
# X = df_copy.drop(columns=['stroke'])
# y = df_copy['stroke'].copy()
#
# corr_df = X.corr()
#
# mask = np.triu(corr_df)
#
# plt.figure(figsize=(18, 18))
# sns.heatmap(corr_df.round(2), mask=mask, cmap='coolwarm', annot=True)
# plt.show()

# %%
df_copy.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  67.0             0              1          Yes        Private
# 1  Female  61.0             0              0          Yes  Self-employed
# 2    Male  80.0             0              1          Yes        Private
# 3  Female  49.0             0              0          Yes        Private
# 4  Female  79.0             1              0          Yes  Self-employed
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke  \
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             202.21  28.1     never smoked       1
# 2          Rural             105.92  32.5     never smoked       1
# 3          Urban             171.23  34.4           smokes       1
# 4          Rural             174.12  24.0     never smoked       1
#
#    missing bmi age_category glucose_category bmi_category
# 0        False       Senior        Very High        Obese
# 1         True       Senior        Very High   Overweight
# 2        False       Senior           Normal        Obese
# 3        False        Adult             High        Obese
# 4        False       Senior             High       Normal

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21  28.1     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke  missing bmi age_category glucose_category bmi_category
# 0       1        False       Senior        Very High        Obese
# 1       1         True       Senior        Very High   Overweight
# 2       1        False       Senior           Normal        Obese
# 3       1        False        Adult             High        Obese
# 4       1        False       Senior             High       Normal

# %%
df_copy1 = df.copy()

# %% [markdown]
# ### Now we can apply feature engineering on df_copy1

# %%
df_copy1.drop(columns = ['id'],inplace=True)

# %%
df_copy1.tail()
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 5105  Female  80.0             1              0          Yes        Private
# 5106  Female  81.0             0              0          Yes  Self-employed
# 5107  Female  35.0             0              0          Yes  Self-employed
# 5108    Male  51.0             0              0          Yes        Private
# 5109  Female  44.0             0              0          Yes       Govt_job
#
#      Residence_type  avg_glucose_level   bmi   smoking_status  stroke  \
# 5105          Urban              83.75  28.1     never smoked       0
# 5106          Urban             125.20  40.0     never smoked       0
# 5107          Rural              82.99  30.6     never smoked       0
# 5108          Rural             166.29  25.6  formerly smoked       0
# 5109          Urban              85.28  26.2          Unknown       0
#
#       missing bmi age_category glucose_category bmi_category
# 5105         True       Senior              Low   Overweight
# 5106        False       Senior           Normal        Obese
# 5107        False  Young Adult              Low        Obese
# 5108        False        Adult             High   Overweight
# 5109        False        Adult              Low   Overweight

# %%
df_copy1['gender'].value_counts()
# Out:
# Female    2994
# Male      2115
# Other        1
# Name: gender, dtype: int64

# %%
df_copy1['gender'] = df_copy1['gender'].map({'Male': 1, 'Female': 0, 'Other' : 0})

# %%
df_copy1['bmi_category'].value_counts()
# Out:
# Obese          1893
# Overweight     1610
# Normal         1258
# Underweight     349
# Name: bmi_category, dtype: int64

# %%
df_copy1['bmi_category'] = df_copy1['bmi_category'].map({
    'Underweight' : 1,
    'Normal' : 2,
    'Overweight' : 3,
    'Obese' : 4
            })

# %%
df_copy1['glucose_category'].value_counts()
# Out:
# Low          2405
# Normal       1884
# Very High     434
# High          387
# Name: glucose_category, dtype: int64

# %%
df_copy1['glucose_category'] = df_copy1['glucose_category'].map({
'Low' : 1,
'Normal' : 2,
'High' : 3,
'Very High' : 4
})

# %%
df_copy1['age_category'].value_counts()
# Out:
# Adult          1907
# Senior         1304
# Young Adult     983
# Child           916
# Name: age_category, dtype: int64

# %%
df_copy1['age_category'] = df_copy1['age_category'].map({
'Senior' : 4, 
'Adult' : 3,
'Young Adult' : 2,
'Child' : 1
})

# %%
df_copy1['smoking_status'].value_counts()
# Out:
# never smoked       1892
# Unknown            1544
# formerly smoked     885
# smokes              789
# Name: smoking_status, dtype: int64

# %%
df_copy1['smoking_status'] = df_copy1['smoking_status'].map({
'never smoked' : 3,
'Unknown' : 4,
'formerly smoked' :1,
'smokes' : 2
})

# %%
df_copy1['Residence_type'].value_counts()
# Out:
# Urban    2596
# Rural    2514
# Name: Residence_type, dtype: int64

# %%
df_copy1['Residence_type'] = df_copy1['Residence_type'].map({'Urban': 1, 'Rural': 0})

# %%
df_copy1['work_type'].value_counts()
# Out:
# Private          2925
# Self-employed     819
# children          687
# Govt_job          657
# Never_worked       22
# Name: work_type, dtype: int64

# %% [markdown]
# 5 category in work type, never worked and child better to be a category

# %%
df_copy1['work_type'] = df_copy1['work_type'].map({
'Private' : 1,
'Self-employed' : 2,
'children' : 3,
'Govt_job' : 4,
'Never_worked' : 3
})

# %%
df_copy1['ever_married'].value_counts()
# Out:
# Yes    3353
# No     1757
# Name: ever_married, dtype: int64

# %%
df_copy1['ever_married'] = df_copy1['ever_married'].map({'Yes': 1, 'No': 0})

# %%
...
# Out:
# Ellipsis

# %%
df_copy1.isna().sum()
# Out:
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# missing bmi          0
# age_category         0
# glucose_category     0
# bmi_category         0
# dtype: int64

# %%
"""plt.figure()
sns.pairplot(df_copy1,hue="stroke", corner=True)
plt.show()"""
# Out:
# 'plt.figure()\nsns.pairplot(df_copy1,hue="stroke", corner=True)\nplt.show()'

# %%
X = df_copy1.drop(columns=['heart_disease'])
y = df_copy1['heart_disease'].copy()

# %%
corr_df = X.corr()

mask = np.triu(corr_df)

plt.figure(figsize=(18, 18))
sns.heatmap(corr_df.round(2), mask=mask, cmap='coolwarm', annot=True)
plt.show()

# %%
# Splitting our data
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    test_size=0.2,
                                                    random_state=12345,
                                                    stratify=y)

# Check
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (4088, 14) (1022, 14) (4088,) (1022,)

# %%
cat_indices=['age_category','glucose_category','bmi_category']

# %%
cat_indices = ['age_category', 'glucose_category', 'bmi_category']
cat_indices = [X_train.columns.get_loc(col) for col in cat_indices]
print(cat_indices)
# Out:
# [11, 12, 13]

# %%
from imblearn.over_sampling import SMOTENC

# Assuming 'cat_indices' is the list of categorical feature indices
smote_nc = SMOTENC(categorical_features=cat_indices, random_state=0)
X_train, y_train = smote_nc.fit_resample(X_train, y_train)

# %%
# Print the shape of X_train to see the number of features
print(X_train.shape)
# Out:
# (7734, 14)

# %%
# Check
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (7734, 14) (1022, 14) (7734,) (1022,)

# %%
X_train.drop(columns=['age_category','glucose_category','bmi_category'],inplace=True)
X_test.drop(columns=['age_category','glucose_category','bmi_category'],inplace=True)

# %%
X_train.isna().sum()
# Out:
# gender               0
# age                  0
# hypertension         0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# missing bmi          0
# dtype: int64

# %%
X_train.head()
# Out:
#    gender   age  hypertension  ever_married  work_type  Residence_type  \
# 0       1  32.0             0             1          1               1
# 1       0  49.0             0             1          1               0
# 2       1  73.0             1             1          2               1
# 3       1  26.0             0             1          2               1
# 4       1  46.0             0             1          1               1
#
#    avg_glucose_level   bmi  smoking_status  stroke  missing bmi
# 0              97.95  40.2               2       0        False
# 1             107.40  26.7               2       0        False
# 2             194.99  32.8               3       1        False
# 3              73.72  25.9               2       0        False
# 4              58.42  24.7               1       0        False

# %%
#X_train.drop(columns=['age','avg_glucose_level','bmi'],inplace=True)
#X_test.drop(columns=['age','avg_glucose_level','bmi'],inplace=True)

# %%
corr_df = X_train.corr()

mask = np.triu(corr_df)

plt.figure(figsize=(18, 18))
sns.heatmap(corr_df.round(2), mask=mask, cmap='coolwarm', annot=True)
plt.tight_layout()
plt.show()

# %%
# Instantiate the scaler
SS = StandardScaler()

# Fit the scaler and transform both data subsets
X_train = SS.fit_transform(X_train)
X_test = SS.transform(X_test)

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (7734, 11) (1022, 11) (7734,) (1022,)

# %%
import time

# %%
start = time.time()

# Empty lists to append the training and test accuracy scores to
train_acc_ss = []
test_acc_ss = []

# The C_values to try
C_values = [0.00001, 0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 1000, 10000]
# Loop through the same C values
for C in C_values:

    # Instantiate the model
    logit=LogisticRegression(C=C, max_iter=1000, random_state=42)

    # Fit the model
    logit.fit(X_train, y_train)

    # Score the model
    train_acc_ss.append(logit.score(X_train, y_train))
    test_acc_ss.append(logit.score(X_test, y_test))

stop = time.time()
runtime_logit_ss = stop-start
print(f"Runtime: {round(runtime_logit_ss,2)} seconds")
# Out:
# Runtime: 0.12 seconds

# %%
# Plotting the train and test scores for every C value
plt.figure()
plt.plot(C_values, train_acc_ss, c='red', label='train')
plt.plot(C_values, test_acc_ss, c='blue', label='test')
plt.xscale('log')
plt.xlabel('C-values')
plt.ylabel('Accuracy score')
plt.legend()
plt.show()

# %% [markdown]
# In this instance, our best Logistic Regression model was at C equal to 0.001 We can see clearly the tell-tale elbow which indicates the bulk of learning has been completed and a point beyond which overfitting might be a concern. Let's take a look at the model's performance:

# %%
# The Logistic Regression that performed the best on the standardized data
# Instantiate the model
logit_ss = LogisticRegression(C=0.001, random_state=42)

# Fit the model
logit_ss.fit(X_train, y_train)

# Store accuracy scores
logit_ss_train = logit_ss.score(X_train, y_train)
logit_ss_test = logit_ss.score(X_test, y_test)

# Score the model
print(f"Train Accuracy: {logit_ss_train}")
print(f"Test Accuracy: {logit_ss_test}")
# Out:
# Train Accuracy: 0.8262218774243599
# Test Accuracy: 0.7925636007827789

# %%
from sklearn.metrics import classification_report
y_test_pred_logit_ss = logit_ss.predict(X_test) 

report_initial = classification_report(y_test, y_test_pred_logit_ss)
print(report_initial)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.80      0.88       967
#            1       0.16      0.69      0.26        55
#
#     accuracy                           0.79      1022
#    macro avg       0.57      0.74      0.57      1022
# weighted avg       0.93      0.79      0.85      1022

# %% [markdown]
# ##### Roc curve

# %%
from sklearn.metrics import roc_curve

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# %%
def false_positive_rate(y_true, y_pred):
    
    false_positives = (y_true == 0) & (y_pred == 1) # find all values where y is negative
                                                    # but we predicted positive
    false_positive_number = false_positives.sum()

    true_negatives = (y_true == 0) & (y_pred == 0)  # find all values where y is negative
                                                    # and we predicted negative
    true_negative_number = true_negatives.sum()

    # Finally, find the ratio of (FP) to (TN + FP)
    FPR = false_positive_number/(true_negative_number + false_positive_number)
    
    return FPR

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
y_pred_proba = model.predict_proba(X_test)
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba[:,1])

plt.plot(fpr, tpr)
plt.plot([0, 1], [0, 1], linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('1 - specificity')
plt.ylabel('sensitivity')
plt.show()

# %%
# Regenerate scores
y_proba = logit_ss.predict_proba(X_test)[:,1]
fprs, tprs, thresholds = roc_curve(y_test, y_proba)
roc_auc = roc_auc_score(y_test, y_proba)

# %%
#Get the probability for each point in the train set.
y_proba_train = logit_ss.predict_proba(X_train)[:,1]

# Compute ROC curve and AUC for for the one class
fprs_train, tprs_train, thresholds_train = roc_curve(y_train, y_proba_train)
roc_auc_train = roc_auc_score(y_train, y_proba_train)

# Plot the ROC curve.
plt.figure()
plt.plot(fprs_train, tprs_train, color='darkorange', lw=2, label='train')
plt.plot(fprs, tprs, lw=2, label='test')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC and AUC')
plt.legend(loc="best")
plt.show()
print(f"Test AUC score: {roc_auc}")
print(f"Train AUC score: {roc_auc_train}")
# Out:
# Test AUC score: 0.836156811130958
# Train AUC score: 0.908321217593866

# %%
# Assuming logistic_regression_model is your trained logistic regression model
coefficients = logit_ss.coef_[0]  # Extracting the coefficients

# Creating an index for each coefficient
feature_index = np.arange(len(coefficients))

# Plotting
plt.figure(figsize=(10, 6))
plt.scatter(feature_index, coefficients, color='blue')
plt.title('Scatter Plot of Logistic Regression Coefficients')
plt.xlabel('Feature Index')
plt.ylabel('Coefficient Value')
plt.grid(True)
plt.show()

# %% [markdown]
# ### as above we can see the most effective feature is age

# %%
coefficients
# Out:
# array([-0.03332434,  0.75375189, -0.17607367, -0.06494743, -0.11078592,
#        -0.25093543,  0.23109854,  0.04083887, -0.3087833 , -0.08931127,
#         0.35534347])

# %%
logit_ss.coef_
# Out:
# array([[-0.03332434,  0.75375189, -0.17607367, -0.06494743, -0.11078592,
#         -0.25093543,  0.23109854,  0.04083887, -0.3087833 , -0.08931127,
#          0.35534347]])

# %%
df_copy1.columns
# Out:
# Index(['gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke', 'missing bmi', 'age_category',
#        'glucose_category', 'bmi_category'],
#       dtype='object')

# %%
X_columns = ['gender', 'age', 'hypertension', 'ever_married',
       'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
       'smoking_status', 'stroke', 'missing bmi']

# %%
coefficients = logit_ss.coef_[0]  # Extracting the coefficients

coef_df = pd.DataFrame(coefficients, X_columns, columns=['Coefficient'])

# %%
coef_df = coef_df.sort_values(by='Coefficient', ascending=False)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.barh(coef_df.index, coef_df['Coefficient'])
plt.xlabel('Coefficient Value')
plt.ylabel('Features')
plt.title('Feature Coefficients(heart)')
plt.show()

# %%
# class distribution
display(y_test.value_counts())

# predict classification
y_test_pred_logit_ss = logit_ss.predict(X_test) # USING THE UNSAMPLED BUT SCALED TEST DATA



report_initial = classification_report(y_test, y_test_pred_logit_ss)
print(report_initial)
# Out:
# 0    967
# 1     55
# Name: heart_disease, dtype: int64
#               precision    recall  f1-score   support
#
#            0       0.98      0.80      0.88       967
#            1       0.16      0.69      0.26        55
#
#     accuracy                           0.79      1022
#    macro avg       0.57      0.74      0.57      1022
# weighted avg       0.93      0.79      0.85      1022

# %%
# Compute confusion matrix
conf_matrix_logit_ss = confusion_matrix(y_test, y_test_pred_logit_ss)

# Plot confusion matrix
sns.heatmap(conf_matrix_logit_ss, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
df_copy1.head()
# Out:
#    gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0       1  67.0             0              1             1          1
# 1       0  61.0             0              0             1          2
# 2       1  80.0             0              1             1          1
# 3       0  49.0             0              0             1          1
# 4       0  79.0             1              0             1          2
#
#    Residence_type  avg_glucose_level   bmi  smoking_status  stroke  \
# 0               1             228.69  36.6               1       1
# 1               0             202.21  28.1               3       1
# 2               0             105.92  32.5               3       1
# 3               1             171.23  34.4               2       1
# 4               0             174.12  24.0               3       1
#
#    missing bmi age_category glucose_category bmi_category
# 0        False            4                4            4
# 1         True            4                4            3
# 2        False            4                2            4
# 3        False            3                3            4
# 4        False            4                3            2

# %% [markdown]
# ### KNN

# %%
start = time.time()

# The different K values to try out and save to 'neighbors'
neighbors = range(1, 55, 2)

# Empty lists to append the accuracies to
train_acc_mm = []
test_acc_mm = []

# Loop through neighbors
for K in neighbors:

    # Instantiate the model
    knn = KNeighborsClassifier(n_neighbors=K)

    # Fit the model
    knn.fit(X_train, y_train)

    # Score the model
    train_acc_mm.append(knn.score(X_train, y_train))
    test_acc_mm.append(knn.score(X_test, y_test))

stop = time.time()
runtime_knn_mm = stop-start
print(f"Runtime: {round(runtime_knn_mm,2)} seconds")
# Out:
# Runtime: 27.73 seconds

# %%
# Plot the accuracies
plt.figure(figsize=(16,8))
plt.plot(neighbors, train_acc_mm, c='red', label='train')
plt.plot(neighbors, test_acc_mm, c='blue', label='test')
plt.xlabel("n_neighbors")
plt.ylabel("Accuracy score")
plt.legend()
plt.show()

# %% [markdown]
# These plots are quite choppy so conclusions will be somewhat subjective. However, the gap between the two plots is at its narrowest at around n_neighbors = 7 and 19

# %%
# KNN with n_neighbors=13
# Instantiate the model
knn_mm = KNeighborsClassifier(n_neighbors=13)

# Fit the model
knn_mm.fit(X_train, y_train)

# Store accuracy scores
knn_mm_train = knn_mm.score(X_train, y_train)
knn_mm_test = knn_mm.score(X_test, y_test)

# Score the model
print(f"Train Accuracy: {knn_mm_train}")
print(f"Test Accuracy: {knn_mm_test}")
# Out:
# Train Accuracy: 0.8910007757951901
# Test Accuracy: 0.7974559686888454

# %%
# class distribution
display(y_test.value_counts())

# predict classification
y_test_pred_knn_mmk7 = knn_mm.predict(X_test) # USING THE UNSAMPLED BUT SCALED TEST DATA



print(f'Recall score: {recall_score(y_test, y_test_pred_knn_mmk7)*100:0.1f}%')
print(f'Precision score: {precision_score(y_test, y_test_pred_knn_mmk7)*100:0.1f}%')
print(f'F1 score: {f1_score(y_test, y_test_pred_knn_mmk7)*100:0.1f}%')
# Out:
# 0    967
# 1     55
# Name: heart_disease, dtype: int64
# Recall score: 45.5%
# Precision score: 12.4%
# F1 score: 19.5%

# %%
# predict classificatin
report_initial = classification_report(y_test, y_test_pred_knn_mmk7)
print(report_initial)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.82      0.88       967
#            1       0.12      0.45      0.19        55
#
#     accuracy                           0.80      1022
#    macro avg       0.54      0.64      0.54      1022
# weighted avg       0.92      0.80      0.85      1022

# %%
# Compute confusion matrix
conf_matrix_knn_mmk7 = confusion_matrix(y_test, y_test_pred_knn_mmk7)

# Plot confusion matrix
sns.heatmap(conf_matrix_knn_mmk7, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
# KNN with n_neighbors=19
# Instantiate the model
knn_mm = KNeighborsClassifier(n_neighbors=19)

# Fit the model
knn_mm.fit(X_train, y_train)

# Store accuracy scores
knn_mm_train = knn_mm.score(X_train, y_train)
knn_mm_test = knn_mm.score(X_test, y_test)

# Score the model
print(f"Train Accuracy: {knn_mm_train}")
print(f"Test Accuracy: {knn_mm_test}")
# Out:
# Train Accuracy: 0.8787173519524178
# Test Accuracy: 0.7915851272015656

# %%
# class distribution
display(y_test.value_counts())

# predict classification
y_test_pred_knn_mm19 = knn_mm.predict(X_test) # USING THE UNSAMPLED BUT SCALED TEST DATA



print(f'Recall score: {recall_score(y_test, y_test_pred_knn_mm19)*100:0.1f}%')
print(f'Precision score: {precision_score(y_test, y_test_pred_knn_mm19)*100:0.1f}%')
print(f'F1 score: {f1_score(y_test, y_test_pred_knn_mm19)*100:0.1f}%')
# Out:
# 0    967
# 1     55
# Name: heart_disease, dtype: int64
# Recall score: 49.1%
# Precision score: 12.7%
# F1 score: 20.2%

# %%
# predict classification
y_test_pred_knn_mm19 = knn_mm.predict(X_test) # USING THE UNSAMPLED BUT SCALED TEST DATA



report_initial = classification_report(y_test, y_test_pred_knn_mm19)
print(report_initial)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.81      0.88       967
#            1       0.13      0.49      0.20        55
#
#     accuracy                           0.79      1022
#    macro avg       0.55      0.65      0.54      1022
# weighted avg       0.92      0.79      0.84      1022

# %%
# Compute confusion matrix
conf_matrix_knn_mmk19 = confusion_matrix(y_test, y_test_pred_knn_mm19)

# Plot confusion matrix
sns.heatmap(conf_matrix_knn_mmk19, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %% [markdown]
# ### Decision Tree

# %%
# number of rows
X_train.shape[0]
# Out:
# 7734

# %%
# indicating range of max_depth values
range(1, int(np.sqrt(X_train.shape[0])))
# Out:
# range(1, 87)

# %%
start = time.time()

# A list of the maximum depths to try out and save to 'depths'
depths = range(1, int(np.sqrt(X_train.shape[0])))

# Empty lists to append to
train_acc_ss = []
test_acc_ss = []

# Loop through the depths
for max_depth in depths:

    # Instantiate the model
    dt = DecisionTreeClassifier(max_depth=max_depth, random_state=42)

    # Fit the model
    dt.fit(X_train, y_train)

    # Score the model
    train_acc_ss.append(dt.score(X_train, y_train))
    test_acc_ss.append(dt.score(X_test, y_test))

stop = time.time()
runtime_dt_mm = stop-start
print(f"Runtime: {round(runtime_dt_mm,2)} seconds")
# Out:
# Runtime: 2.47 seconds

# %%
# Plot the accuracies
plt.figure(figsize=(16,8))
plt.plot(depths, train_acc_ss, c='red', label='train')
plt.plot(depths, test_acc_ss, c='blue', label='test')
plt.xlabel("max_depth")
plt.ylabel("Accuracy score")
plt.title("DecisionTreeClassifier")
plt.legend()
plt.show()

# %% [markdown]
# max_depth=4 and 6 appears to be optimal.

# %%
# Best Decision Tree Classifier on standardized data and max_depth=3
# Instantiate the model
dt_ss = DecisionTreeClassifier(max_depth=4, random_state=42)

# Fit the model
dt_ss.fit(X_train, y_train)

# Store accuracy scores
dt_ss_train = dt_ss.score(X_train, y_train)
dt_ss_test = dt_ss.score(X_test, y_test)

# Score the model
print(f"Train Accuracy: {dt_ss_train}")
print(f"Test Accuracy: {dt_ss_test}")
# Out:
# Train Accuracy: 0.813291957589863
# Test Accuracy: 0.6653620352250489

# %%
# class distribution
display(y_test.value_counts())

# predict classification
y_test_pred_dt_ss = dt_ss.predict(X_test) # USING THE UNSAMPLED BUT SCALED TEST DATA


print(f'Recall score: {recall_score(y_test, y_test_pred_dt_ss)*100:0.1f}%')
print(f'Precision score: {precision_score(y_test, y_test_pred_dt_ss)*100:0.1f}%')
print(f'F1 score: {f1_score(y_test, y_test_pred_dt_ss)*100:0.1f}%')
# Out:
# 0    967
# 1     55
# Name: heart_disease, dtype: int64
# Recall score: 94.5%
# Precision score: 13.3%
# F1 score: 23.3%

# %%
report_initial = classification_report(y_test, y_test_pred_dt_ss)
print(report_initial)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.65      0.79       967
#            1       0.13      0.95      0.23        55
#
#     accuracy                           0.67      1022
#    macro avg       0.56      0.80      0.51      1022
# weighted avg       0.95      0.67      0.76      1022

# %%
# Compute confusion matrix
conf_matrix_dt_ss = confusion_matrix(y_test, y_test_pred_dt_ss)

# Plot confusion matrix
sns.heatmap(conf_matrix_dt_ss, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
# Best Decision Tree Classifier on standardized data 
# Instantiate the model
dt_ssn = DecisionTreeClassifier(max_depth=2, random_state=42)

# Fit the model
dt_ssn.fit(X_train, y_train)

# Store accuracy scores
dt_ss_train = dt_ssn.score(X_train, y_train)
dt_ss_test = dt_ssn.score(X_test, y_test)

# Score the model
print(f"Train Accuracy: {dt_ss_train}")
print(f"Test Accuracy: {dt_ss_test}")
# Out:
# Train Accuracy: 0.7750193948797518
# Test Accuracy: 0.6095890410958904

# %%
# class distribution
display(y_test.value_counts())

# predict classification
y_test_pred_dt_ssn = dt_ssn.predict(X_test) # USING THE UNSAMPLED BUT SCALED TEST DATA


print(f'Recall score: {recall_score(y_test, y_test_pred_dt_ssn)*100:0.1f}%')
print(f'Precision score: {precision_score(y_test, y_test_pred_dt_ssn)*100:0.1f}%')
print(f'F1 score: {f1_score(y_test, y_test_pred_dt_ssn)*100:0.1f}%')
# Out:
# 0    967
# 1     55
# Name: heart_disease, dtype: int64
# Recall score: 98.2%
# Precision score: 11.9%
# F1 score: 21.3%

# %%
report_initial = classification_report(y_test, y_test_pred_dt_ssn)
print(report_initial)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.59      0.74       967
#            1       0.12      0.98      0.21        55
#
#     accuracy                           0.61      1022
#    macro avg       0.56      0.79      0.48      1022
# weighted avg       0.95      0.61      0.71      1022

# %%
# Compute confusion matrix
conf_matrix_dt_ssn = confusion_matrix(y_test, y_test_pred_dt_ssn)

# Plot confusion matrix
sns.heatmap(conf_matrix_dt_ssn, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
# to do checkk for optimize one factor

# %%
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# #### Pipe line for decision Tree

# %%
# Define the model
dt = DecisionTreeClassifier()

# Define the parameter grid
param_grid = {
    'criterion': ['gini', 'entropy'],
    'max_depth': [2, 3, 4, 6, 10 ,12],
    'min_samples_split': [1, 2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_leaf_nodes': [10, 20, 30, None]  # 'None' means unlimited
}

# %%
# Initialize GridSearchCV
gs = GridSearchCV(dt, param_grid, scoring='recall', cv=5)

# %%
# Fit GridSearchCV
gs.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 3, 4, 6, 10, 12],
#                          'max_leaf_nodes': [10, 20, 30, None],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [1, 2, 5, 10]},
#              scoring='recall')

# %%
# Best parameters
print("Best Parameters:", gs.best_params_)

# Best F1 score
print("Best F1 Score:", gs.best_score_)

# Best model
best_model = gs.best_estimator_

# Predictions with the best model
y_pred_dt_best = best_model.predict(X_test)

# Classification report
print(classification_report(y_test, y_pred_dt_best))
# Out:
# Best Parameters: {'criterion': 'gini', 'max_depth': 4, 'max_leaf_nodes': 20, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Best F1 Score: 0.9702554897025248
#               precision    recall  f1-score   support
#
#            0       1.00      0.65      0.79       967
#            1       0.13      0.95      0.23        55
#
#     accuracy                           0.67      1022
#    macro avg       0.56      0.80      0.51      1022
# weighted avg       0.95      0.67      0.76      1022

# %%
# Compute confusion matrix
conf_matrix_dt_ss_best = confusion_matrix(y_test, y_pred_dt_best)

# Plot confusion matrix
sns.heatmap(conf_matrix_dt_ss_best, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %% [markdown]
# ### Support Vector Machines

# %%
from sklearn.svm import LinearSVC

# %%
C_values = [0.00001,0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 1000,10000]
training_scores = []
test_scores = []

for c in C_values:
    SVM_model = LinearSVC(C=c, max_iter=1000,dual=False)
    SVM_model.fit(X_train, y_train)
    training_scores.append(SVM_model.score(X_train, y_train))
    test_scores.append(SVM_model.score(X_test, y_test))

# Plotting the training scores
plt.plot(C_values, training_scores, marker='o',label='train')
plt.plot(C_values, test_scores, marker='.',label="test")
plt.xscale('log')  # Since C_values vary on a logarithmic scale
plt.xlabel('C value')
plt.ylabel('Training Accuracy')
plt.title('Training Accuracy for different C values in LinearSVC')
plt.legend()
plt.show()
training_scores
# Out:
# [0.808249288854409,
#  0.8281613653995346,
#  0.825833979829325,
#  0.8240237910524955,
#  0.8235065942591155,
#  0.8235065942591155,
#  0.8233772950607706,
#  0.8233772950607706,
#  0.8233772950607706,
#  0.8233772950607706]

# %%
# Instantiate the model
SVM_model = LinearSVC(C=0.01,max_iter=100000,dual=False)

# Fit the model
SVM_model.fit(X_train, y_train)

# Store accuracy scores
SVM_model_train = SVM_model.score(X_train, y_train)
SVM_model_test = SVM_model.score(X_test, y_test)

# Score the model
print(f"Train Accuracy: {SVM_model_train}")
print(f"Test Accuracy: {SVM_model_test}")
# Out:
# Train Accuracy: 0.8240237910524955
# Test Accuracy: 0.8091976516634051

# %%
# class distribution
display(y_test.value_counts())

# predict classification
y_test_pred_SVM_model = SVM_model.predict(X_test) # USING THE UNSAMPLED BUT SCALED TEST DATA



print(f'Recall score: {recall_score(y_test, y_test_pred_SVM_model)*100:0.1f}%')
print(f'Precision score: {precision_score(y_test, y_test_pred_SVM_model)*100:0.1f}%')
print(f'F1 score: {f1_score(y_test, y_test_pred_SVM_model)*100:0.1f}%')
# Out:
# 0    967
# 1     55
# Name: heart_disease, dtype: int64
# Recall score: 65.5%
# Precision score: 17.0%
# F1 score: 27.0%

# %%
report_initial = classification_report(y_test, y_test_pred_SVM_model)
print(report_initial)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.82      0.89       967
#            1       0.17      0.65      0.27        55
#
#     accuracy                           0.81      1022
#    macro avg       0.57      0.74      0.58      1022
# weighted avg       0.93      0.81      0.86      1022

# %%
# Compute confusion matrix
conf_matrix_SVM_model = confusion_matrix(y_test, y_test_pred_SVM_model)

# Plot confusion matrix
sns.heatmap(conf_matrix_SVM_model, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
from sklearn.decomposition import PCA

# %%
my_PCA = PCA()
my_PCA.fit(X_train)

# transform data 
X_train_PCA = my_PCA.transform(X_train)
X_test_PCA = my_PCA.transform(X_test)

# %%
print(f"Variance captured by PC1: {my_PCA.explained_variance_[0]: 0.3f}")
print(f"Variance captured by PC2: {my_PCA.explained_variance_[1]: 0.3f}")

print(f"Proportion of variance captured by PC1: {my_PCA.explained_variance_ratio_[0]: 0.3f}")
print(f"Proportion of variance captured by PC2: {my_PCA.explained_variance_ratio_[1]: 0.3f}")
# Out:
# Variance captured by PC1:  2.243
# Variance captured by PC2:  1.168
# Proportion of variance captured by PC1:  0.204
# Proportion of variance captured by PC2:  0.106

# %%
my_PCA.explained_variance_ratio_
# Out:
# array([0.20389581, 0.10618535, 0.10271168, 0.09312576, 0.08738986,
#        0.08050777, 0.08007906, 0.07529133, 0.07088757, 0.06169817,
#        0.03822763])

# %%
expl_var = my_PCA.explained_variance_ratio_

# %%
plt.figure()
plt.plot(range(1,12),expl_var,marker='.')
plt.xlabel('Number of PCs')
plt.ylabel('Proportion of Variance Explained')
plt.xticks(range(1,12,2))
plt.show()

# %%
# Pull out the explained variance ratio
expl_var = my_PCA.explained_variance_ratio_

# Calculate the cumulative sum of this array using the 
cumulative_sum = np.cumsum(expl_var)

cumulative_sum
# Out:
# array([0.20389581, 0.31008116, 0.41279284, 0.5059186 , 0.59330846,
#        0.67381624, 0.75389529, 0.82918663, 0.90007419, 0.96177237,
#        1.        ])

# %%
# Plot out the cumulative sum graph

plt.figure()
plt.plot(range(1,12), cumulative_sum, marker='.')
plt.axhline(0.9, c='r', linestyle='--')
plt.xlabel('Number of PCs')
plt.ylabel('Cumulative Sum of Explained Variance')
plt.xticks(range(1,12,2))
plt.show()

# %%
# Instantiate and fit
my_PCA = PCA(n_components = 9)
my_PCA.fit(X_train)

# Transform train and test
X_train_PCA = my_PCA.transform(X_train)
X_test_PCA = my_PCA.transform(X_test)

# %%
print(f'Original: {X_train.shape}')
print(f'PCA Transformed: {X_train_PCA.shape}')
# Out:
# Original: (7734, 11)
# PCA Transformed: (7734, 9)

# %%
# Instantiate and fit
my_PCA = PCA(n_components = 0.90)
my_PCA.fit(X_train)

# Transform train and test
X_train_PCA = my_PCA.transform(X_train)
X_test_PCA = my_PCA.transform(X_test)

# %%
print(f'Original: {X_train.shape}')
print(f'PCA Transformed: {X_train_PCA.shape}')
# Out:
# Original: (7734, 11)
# PCA Transformed: (7734, 9)

# %%
# Do the same but fit on the PCA transformed data
my_logreg_PCA = LogisticRegression(C=1, random_state=42,max_iter=100000)

# Fitting to PCA data
my_logreg_PCA.fit(X_train_PCA,y_train)

# Scoring on PCA train and test sets
print(f'Train Score: {my_logreg_PCA.score(X_train_PCA, y_train)}')
print(f'Test Score: {my_logreg_PCA.score(X_test_PCA, y_test)}')
# Out:
# Train Score: 0.8017843289371606
# Test Score: 0.7749510763209393

# %%
# class distribution
display(y_test.value_counts())

# predict classification
y_test_pred_PCA = my_logreg_PCA.predict(X_test_PCA) # USING THE UNSAMPLED BUT SCALED TEST DATA


print(f'Recall score: {recall_score(y_test, y_test_pred_PCA)*100:0.1f}%')
print(f'Precision score: {precision_score(y_test, y_test_pred_PCA)*100:0.1f}%')
print(f'F1 score: {f1_score(y_test, y_test_pred_PCA)*100:0.1f}%')
# Out:
# 0    967
# 1     55
# Name: heart_disease, dtype: int64
# Recall score: 56.4%
# Precision score: 13.1%
# F1 score: 21.2%

# %% [markdown]
# Since the number of columns are not significant, PCA is not a good method for feature enginering

# %%
from sklearn.metrics import classification_report

report_initial = classification_report(y_test, y_test_pred_PCA)
print(report_initial)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.79      0.87       967
#            1       0.13      0.56      0.21        55
#
#     accuracy                           0.77      1022
#    macro avg       0.55      0.68      0.54      1022
# weighted avg       0.92      0.77      0.83      1022

# %%
# Compute confusion matrix
conf_matrix_PCA = confusion_matrix(y_test, y_test_pred_PCA)

# Plot confusion matrix
sns.heatmap(conf_matrix_PCA, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %% [markdown]
# 💡 Recommendation: The goal should be to minimize false negatives as much as possible to avoid under-predicting the 'Stroke' class, while also reducing false positives to avoid over-predicting the 'Stroke' class. This could potentially be achieved by further tuning the model's parameters, exploring different algorithms, or engineering new features.

# %%
# check the Logestic model performance with Statsmodels 
import statsmodels.api as sm

# Add a constant to the predictor variable set to include an intercept in the model
X_with_cons = sm.add_constant(X_train)

# Fit the logistic regression model
model = sm.Logit(y_train, X_with_cons).fit()

# Get the summary of the model
summary = model.summary2().tables[1] 

# Convert summary to DataFrame
summary_df = pd.DataFrame(summary)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.367874
#          Iterations 7

# %%
model.summary2()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                          Results: Logit
# ================================================================
# Model:              Logit            Pseudo R-squared: 0.469
# Dependent Variable: heart_disease    AIC:              5714.2796
# Date:               2024-02-02 02:46 BIC:              5797.7202
# No. Observations:   7734             Log-Likelihood:   -2845.1
# Df Model:           11               LL-Null:          -5360.8
# Df Residuals:       7722             LLR p-value:      0.0000
# Converged:          1.0000           Scale:            1.0000
# No. Iterations:     7.0000
# ------------------------------------------------------------------
#          Coef.    Std.Err.      z       P>|z|     [0.025    0.975]
# ------------------------------------------------------------------
# const   -0.1680     0.0379    -4.4358   0.0000   -0.2423   -0.0938
# x1      -0.0305     0.0335    -0.9093   0.3632   -0.0961    0.0352
# x2       2.1022     0.0565    37.2134   0.0000    1.9915    2.2130
# x3      -0.4649     0.0320   -14.5272   0.0000   -0.5276   -0.4021
# x4      -0.5586     0.0431   -12.9515   0.0000   -0.6431   -0.4741
# x5      -0.1849     0.0342    -5.4001   0.0000   -0.2520   -0.1178
# x6      -0.4280     0.0335   -12.7761   0.0000   -0.4936   -0.3623
# x7       0.3700     0.0360    10.2862   0.0000    0.2995    0.4405
# x8       0.2134     0.0369     5.7802   0.0000    0.1411    0.2858
# x9      -0.5564     0.0357   -15.5680   0.0000   -0.6265   -0.4864
# x10     -0.3014     0.0294   -10.2451   0.0000   -0.3590   -0.2437
# x11      0.7593     0.0437    17.3927   0.0000    0.6738    0.8449
# ================================================================
#
# """

# %%
# get accuracies for model
X_test_const = sm.add_constant(X_test)
# Predict probabilities
y_pred_prob = model.predict(X_test_const)

# Convert probabilities to class labels (0 or 1) based on a threshold (e.g., 0.5)
y_pred_sm = (y_pred_prob > 0.3).astype(int)

# %%
# Calculate F1 score
f1 = f1_score(y_test, y_pred_sm)
print("F1 Score:", f1)

# Calculate recall
recall = recall_score(y_test, y_pred_sm)
print("Recall:", recall)

# Calculate precision
precision = precision_score(y_test, y_pred_sm)
print("Precision:", precision)
# Out:
# F1 Score: 0.24289405684754523
# Recall: 0.8545454545454545
# Precision: 0.14156626506024098

# %%
# Compute confusion matrix
conf_matrix_sm = confusion_matrix(y_test, y_pred_sm)

# Plot confusion matrix
sns.heatmap(conf_matrix_sm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

random_forest_model = RandomForestClassifier(n_estimators=50) # setting max features is not needed here as our dataset only has 2 features.
random_forest_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=50)

# %%
# Instantiate lists to save scores in
decision_tree_train_scores = []
decision_tree_test_scores = []

# For each tree, score on train and test
for sub_tree in random_forest_model.estimators_:
    decision_tree_train_scores.append(sub_tree.score(X_train, y_train))
    decision_tree_test_scores.append(sub_tree.score(X_test, y_test))

# Rather than many separate print() statements, we can combine them into one using triple quotes.
print(f"""
Performance on fitted data:
best Decision Tree: {np.max(decision_tree_train_scores)}
Random Forest: {random_forest_model.score(X_train, y_train)}
----------------
Performance on test data:
best Decision Tree: {np.max(decision_tree_test_scores)}
Random Forest: {random_forest_model.score(X_test, y_test)}
""")
# Out:
# Performance on fitted data:
# best Decision Tree: 0.9672873028187225
# Random Forest: 0.9998707008016551
# ----------------
# Performance on test data:
# best Decision Tree: 0.87279843444227
# Random Forest: 0.910958904109589

# %%
# Q1
train_scores = []
test_scores = []
n_range = range(1, 50,2)

for n in n_range:
    RF_model = RandomForestClassifier(n_estimators=n)
    RF_model.fit(X_train, y_train)
    train_scores.append(RF_model.score(X_train, y_train))
    test_scores.append(RF_model.score(X_test, y_test))
    
plt.plot(n_range, train_scores, label = 'Train')
plt.plot(n_range, test_scores, label = 'Test')
plt.xlabel("Number of estimators")
plt.ylabel("Accuracy")
plt.title("RandomForestClassifier")
plt.legend();

# %%
RF_model = RandomForestClassifier(n_estimators=19)
RF_model.fit(X_train, y_train)
print(RF_model.score(X_train, y_train))
print(RF_model.score(X_test, y_test))
# Out:
# 0.9992242048099301
# 0.8943248532289628

# %%
# class distribution
display(y_test.value_counts())

# predict classification
y_pred_RF_model = RF_model.predict(X_test)


print(f'Recall score: {recall_score(y_test, y_pred_RF_model)*100:0.1f}%')
print(f'Precision score: {precision_score(y_test, y_pred_RF_model)*100:0.1f}%')
print(f'F1 score: {f1_score(y_test, y_pred_RF_model)*100:0.1f}%')


report_initial_dt_ss = classification_report(y_test, y_pred_RF_model)
print(report_initial_dt_ss)
# Out:
# 0    967
# 1     55
# Name: heart_disease, dtype: int64
# Recall score: 20.0%
# Precision score: 14.7%
# F1 score: 16.9%
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94       967
#            1       0.15      0.20      0.17        55
#
#     accuracy                           0.89      1022
#    macro avg       0.55      0.57      0.56      1022
# weighted avg       0.91      0.89      0.90      1022

# %%
# Compute confusion matrix
conf_matrix_RF_model = confusion_matrix(y_test, y_pred_RF_model)

# Plot confusion matrix
sns.heatmap(conf_matrix_RF_model, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
confusion_matrix
# Out:
# <function sklearn.metrics._classification.confusion_matrix(y_true, y_pred, *, labels=None, sample_weight=None, normalize=None)>

# %% [markdown]
# #### GradientBoostingClassifier

# %%
from sklearn.ensemble import GradientBoostingClassifier

g_b_model = GradientBoostingClassifier(random_state=42)

g_b_model.fit(X_train, y_train)

y_pred_g_b_model = g_b_model.predict(X_test)

# %%
g_b_model.score(X_test, y_test)
# Out:
# 0.8463796477495108

# %%
report_initial_g_b_model= classification_report(y_test, y_pred_g_b_model)
print(report_initial_g_b_model)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.87      0.91       967
#            1       0.16      0.45      0.24        55
#
#     accuracy                           0.85      1022
#    macro avg       0.56      0.66      0.58      1022
# weighted avg       0.92      0.85      0.88      1022

# %%
# Compute confusion matrix
conf_matrix_g_b_model = confusion_matrix(y_test, y_pred_g_b_model)

# Plot confusion matrix
sns.heatmap(conf_matrix_g_b_model, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %% [markdown]
# #### NN tensorflow

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
# Define the model
model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(X_train.shape[1],)))

model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))  # Sigmoid for binary classification

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the model
history = model.fit(X_train, y_train, epochs=1000, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/1000
# 194/194 [==============================] - 0s 2ms/step - loss: 0.4121 - accuracy: 0.7994 - val_loss: 0.3956 - val_accuracy: 0.8132
# Epoch 2/1000
# 194/194 [==============================] - 0s 2ms/step - loss: 0.3339 - accuracy: 0.8426 - val_loss: 0.4065 - val_accuracy: 0.8177
# Epoch 3/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.3208 - accuracy: 0.8510 - val_loss: 0.3662 - val_accuracy: 0.8416
# Epoch 4/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.3126 - accuracy: 0.8568 - val_loss: 0.3439 - val_accuracy: 0.8597
# Epoch 5/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.3043 - accuracy: 0.8618 - val_loss: 0.3355 - val_accuracy: 0.8565
# Epoch 6/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.2995 - accuracy: 0.8623 - val_loss: 0.3050 - val_accuracy: 0.8772
# Epoch 7/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.2942 - accuracy: 0.8665 - val_loss: 0.3163 - val_accuracy: 0.8681
# Epoch 8/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.2882 - accuracy: 0.8723 - val_loss: 0.3544 - val_accuracy: 0.8449
# Epoch 9/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.2852 - accuracy: 0.8705 - val_loss: 0.2565 - val_accuracy: 0.9108
# Epoch 10/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.2812 - accuracy: 0.8744 - val_loss: 0.3195 - val_accuracy: 0.8643
# Epoch 11/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.2761 - accuracy: 0.8759 - val_loss: 0.2678 - val_accuracy: 0.9011
# Epoch 12/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.2733 - accuracy: 0.8830 - val_loss: 0.3236 - val_accuracy: 0.8617
# Epoch 13/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.2712 - accuracy: 0.8812 - val_loss: 0.3153 - val_accuracy: 0.8727
# Epoch 14/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.2656 - accuracy: 0.8875 - val_loss: 0.3315 - val_accuracy: 0.8675
# Epoch 15/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.2630 - accuracy: 0.8899 - val_loss: 0.2959 - val_accuracy: 0.8778
# Epoch 16/1000
# 194/194 [==============================] - 0s 2ms/step - loss: 0.2611 - accuracy: 0.8878 - val_loss: 0.3208 - val_accuracy: 0.8720
# Epoch 17/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.2578 - accuracy: 0.8906 - val_loss: 0.3789 - val_accuracy: 0.8390
# Epoch 18/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.2549 - accuracy: 0.8911 - val_loss: 0.2798 - val_accuracy: 0.9037
# Epoch 19/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.2510 - accuracy: 0.8930 - val_loss: 0.2699 - val_accuracy: 0.9173
# Epoch 20/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.2475 - accuracy: 0.8953 - val_loss: 0.3408 - val_accuracy: 0.8707
# Epoch 21/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.2462 - accuracy: 0.8948 - val_loss: 0.2755 - val_accuracy: 0.8998
# Epoch 22/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.2441 - accuracy: 0.8962 - val_loss: 0.2407 - val_accuracy: 0.9198
# Epoch 23/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.2424 - accuracy: 0.8974 - val_loss: 0.2706 - val_accuracy: 0.9043
# Epoch 24/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.2404 - accuracy: 0.8979 - val_loss: 0.2994 - val_accuracy: 0.8875
# Epoch 25/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.2368 - accuracy: 0.9016 - val_loss: 0.3156 - val_accuracy: 0.8752
# Epoch 26/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.2344 - accuracy: 0.9014 - val_loss: 0.2570 - val_accuracy: 0.9153
# Epoch 27/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.2327 - accuracy: 0.8996 - val_loss: 0.2867 - val_accuracy: 0.8992
# Epoch 28/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.2321 - accuracy: 0.9021 - val_loss: 0.2363 - val_accuracy: 0.9263
# Epoch 29/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.2292 - accuracy: 0.9064 - val_loss: 0.2940 - val_accuracy: 0.8933
# Epoch 30/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.2266 - accuracy: 0.9050 - val_loss: 0.2192 - val_accuracy: 0.9237
# Epoch 31/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.2253 - accuracy: 0.9058 - val_loss: 0.2238 - val_accuracy: 0.9257
# Epoch 32/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.2231 - accuracy: 0.9077 - val_loss: 0.2671 - val_accuracy: 0.9056
# Epoch 33/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.2218 - accuracy: 0.9066 - val_loss: 0.2759 - val_accuracy: 0.9017
# Epoch 34/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.2209 - accuracy: 0.9095 - val_loss: 0.2694 - val_accuracy: 0.9095
# Epoch 35/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.2193 - accuracy: 0.9085 - val_loss: 0.2499 - val_accuracy: 0.9160
# Epoch 36/1000
# 194/194 [==============================] - 0s 2ms/step - loss: 0.2173 - accuracy: 0.9095 - val_loss: 0.2334 - val_accuracy: 0.9237
# Epoch 37/1000
# 194/194 [==============================] - 0s 2ms/step - loss: 0.2148 - accuracy: 0.9121 - val_loss: 0.1982 - val_accuracy: 0.9334
# Epoch 38/1000
# 194/194 [==============================] - 0s 2ms/step - loss: 0.2159 - accuracy: 0.9100 - val_loss: 0.2686 - val_accuracy: 0.9082
# Epoch 39/1000
# 194/194 [==============================] - 0s 2ms/step - loss: 0.2119 - accuracy: 0.9156 - val_loss: 0.2572 - val_accuracy: 0.9082
# Epoch 40/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.2126 - accuracy: 0.9087 - val_loss: 0.2790 - val_accuracy: 0.9030
# Epoch 41/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.2099 - accuracy: 0.9124 - val_loss: 0.2096 - val_accuracy: 0.9373
# Epoch 42/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.2094 - accuracy: 0.9130 - val_loss: 0.2211 - val_accuracy: 0.9282
# Epoch 43/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.2073 - accuracy: 0.9137 - val_loss: 0.2357 - val_accuracy: 0.9244
# Epoch 44/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.2048 - accuracy: 0.9148 - val_loss: 0.2194 - val_accuracy: 0.9263
# Epoch 45/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.2047 - accuracy: 0.9142 - val_loss: 0.1939 - val_accuracy: 0.9379
# Epoch 46/1000
# 194/194 [==============================] - 0s 2ms/step - loss: 0.2050 - accuracy: 0.9147 - val_loss: 0.2317 - val_accuracy: 0.9211
# Epoch 47/1000
# 194/194 [==============================] - 0s 2ms/step - loss: 0.2021 - accuracy: 0.9189 - val_loss: 0.2231 - val_accuracy: 0.9192
# Epoch 48/1000
# 194/194 [==============================] - 0s 2ms/step - loss: 0.1991 - accuracy: 0.9189 - val_loss: 0.2802 - val_accuracy: 0.9024
# Epoch 49/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1993 - accuracy: 0.9184 - val_loss: 0.2686 - val_accuracy: 0.8998
# Epoch 50/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1984 - accuracy: 0.9174 - val_loss: 0.2209 - val_accuracy: 0.9211
# Epoch 51/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1961 - accuracy: 0.9214 - val_loss: 0.1997 - val_accuracy: 0.9321
# Epoch 52/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1979 - accuracy: 0.9181 - val_loss: 0.1757 - val_accuracy: 0.9425
# Epoch 53/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1961 - accuracy: 0.9193 - val_loss: 0.1805 - val_accuracy: 0.9399
# Epoch 54/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1933 - accuracy: 0.9200 - val_loss: 0.2252 - val_accuracy: 0.9160
# Epoch 55/1000
# 194/194 [==============================] - 0s 2ms/step - loss: 0.1916 - accuracy: 0.9206 - val_loss: 0.1932 - val_accuracy: 0.9334
# Epoch 56/1000
# 194/194 [==============================] - 0s 2ms/step - loss: 0.1892 - accuracy: 0.9224 - val_loss: 0.2110 - val_accuracy: 0.9257
# Epoch 57/1000
# 194/194 [==============================] - 0s 2ms/step - loss: 0.1902 - accuracy: 0.9197 - val_loss: 0.1980 - val_accuracy: 0.9321
# Epoch 58/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1895 - accuracy: 0.9210 - val_loss: 0.2182 - val_accuracy: 0.9270
# Epoch 59/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1876 - accuracy: 0.9226 - val_loss: 0.2188 - val_accuracy: 0.9302
# Epoch 60/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1850 - accuracy: 0.9250 - val_loss: 0.1653 - val_accuracy: 0.9438
# Epoch 61/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1861 - accuracy: 0.9232 - val_loss: 0.2214 - val_accuracy: 0.9160
# Epoch 62/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1860 - accuracy: 0.9211 - val_loss: 0.2109 - val_accuracy: 0.9289
# Epoch 63/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1827 - accuracy: 0.9231 - val_loss: 0.2295 - val_accuracy: 0.9173
# Epoch 64/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1818 - accuracy: 0.9226 - val_loss: 0.2473 - val_accuracy: 0.9095
# Epoch 65/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1831 - accuracy: 0.9242 - val_loss: 0.2324 - val_accuracy: 0.9218
# Epoch 66/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1833 - accuracy: 0.9239 - val_loss: 0.2723 - val_accuracy: 0.8992
# Epoch 67/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1803 - accuracy: 0.9265 - val_loss: 0.2144 - val_accuracy: 0.9270
# Epoch 68/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1779 - accuracy: 0.9266 - val_loss: 0.2325 - val_accuracy: 0.9127
# Epoch 69/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1776 - accuracy: 0.9287 - val_loss: 0.1924 - val_accuracy: 0.9334
# Epoch 70/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1763 - accuracy: 0.9274 - val_loss: 0.2203 - val_accuracy: 0.9179
# Epoch 71/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1763 - accuracy: 0.9279 - val_loss: 0.2438 - val_accuracy: 0.9037
# Epoch 72/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1727 - accuracy: 0.9281 - val_loss: 0.2335 - val_accuracy: 0.9153
# Epoch 73/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1723 - accuracy: 0.9268 - val_loss: 0.2440 - val_accuracy: 0.9134
# Epoch 74/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1731 - accuracy: 0.9266 - val_loss: 0.2294 - val_accuracy: 0.9063
# Epoch 75/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1736 - accuracy: 0.9260 - val_loss: 0.1903 - val_accuracy: 0.9367
# Epoch 76/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1717 - accuracy: 0.9294 - val_loss: 0.2046 - val_accuracy: 0.9302
# Epoch 77/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1685 - accuracy: 0.9295 - val_loss: 0.2545 - val_accuracy: 0.9024
# Epoch 78/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1701 - accuracy: 0.9289 - val_loss: 0.1876 - val_accuracy: 0.9373
# Epoch 79/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1687 - accuracy: 0.9318 - val_loss: 0.3163 - val_accuracy: 0.8643
# Epoch 80/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1658 - accuracy: 0.9324 - val_loss: 0.1877 - val_accuracy: 0.9308
# Epoch 81/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1667 - accuracy: 0.9292 - val_loss: 0.2114 - val_accuracy: 0.9224
# Epoch 82/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1667 - accuracy: 0.9316 - val_loss: 0.2427 - val_accuracy: 0.9095
# Epoch 83/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1635 - accuracy: 0.9323 - val_loss: 0.1701 - val_accuracy: 0.9412
# Epoch 84/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1654 - accuracy: 0.9315 - val_loss: 0.2654 - val_accuracy: 0.9005
# Epoch 85/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1662 - accuracy: 0.9307 - val_loss: 0.2275 - val_accuracy: 0.9192
# Epoch 86/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1608 - accuracy: 0.9376 - val_loss: 0.2106 - val_accuracy: 0.9205
# Epoch 87/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1612 - accuracy: 0.9337 - val_loss: 0.1969 - val_accuracy: 0.9289
# Epoch 88/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1613 - accuracy: 0.9332 - val_loss: 0.2554 - val_accuracy: 0.9095
# Epoch 89/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1588 - accuracy: 0.9352 - val_loss: 0.2434 - val_accuracy: 0.9101
# Epoch 90/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1592 - accuracy: 0.9344 - val_loss: 0.1606 - val_accuracy: 0.9373
# Epoch 91/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1598 - accuracy: 0.9323 - val_loss: 0.2298 - val_accuracy: 0.9192
# Epoch 92/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1577 - accuracy: 0.9334 - val_loss: 0.1816 - val_accuracy: 0.9379
# Epoch 93/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1579 - accuracy: 0.9341 - val_loss: 0.1765 - val_accuracy: 0.9425
# Epoch 94/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1568 - accuracy: 0.9337 - val_loss: 0.1792 - val_accuracy: 0.9386
# Epoch 95/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1526 - accuracy: 0.9371 - val_loss: 0.1322 - val_accuracy: 0.9496
# Epoch 96/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1554 - accuracy: 0.9350 - val_loss: 0.1949 - val_accuracy: 0.9276
# Epoch 97/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1525 - accuracy: 0.9341 - val_loss: 0.1787 - val_accuracy: 0.9334
# Epoch 98/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1527 - accuracy: 0.9378 - val_loss: 0.2064 - val_accuracy: 0.9250
# Epoch 99/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1535 - accuracy: 0.9344 - val_loss: 0.2323 - val_accuracy: 0.9101
# Epoch 100/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1537 - accuracy: 0.9355 - val_loss: 0.2044 - val_accuracy: 0.9231
# Epoch 101/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1528 - accuracy: 0.9352 - val_loss: 0.2684 - val_accuracy: 0.8959
# Epoch 102/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1496 - accuracy: 0.9373 - val_loss: 0.1796 - val_accuracy: 0.9315
# Epoch 103/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1512 - accuracy: 0.9363 - val_loss: 0.2435 - val_accuracy: 0.9095
# Epoch 104/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1486 - accuracy: 0.9371 - val_loss: 0.2693 - val_accuracy: 0.8933
# Epoch 105/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1482 - accuracy: 0.9363 - val_loss: 0.2750 - val_accuracy: 0.8940
# Epoch 106/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1500 - accuracy: 0.9368 - val_loss: 0.2130 - val_accuracy: 0.9218
# Epoch 107/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1476 - accuracy: 0.9392 - val_loss: 0.2117 - val_accuracy: 0.9218
# Epoch 108/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1457 - accuracy: 0.9389 - val_loss: 0.2433 - val_accuracy: 0.9037
# Epoch 109/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1472 - accuracy: 0.9384 - val_loss: 0.2016 - val_accuracy: 0.9328
# Epoch 110/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1501 - accuracy: 0.9363 - val_loss: 0.1781 - val_accuracy: 0.9412
# Epoch 111/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1481 - accuracy: 0.9405 - val_loss: 0.2524 - val_accuracy: 0.9063
# Epoch 112/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1440 - accuracy: 0.9418 - val_loss: 0.2304 - val_accuracy: 0.9134
# Epoch 113/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1439 - accuracy: 0.9400 - val_loss: 0.2131 - val_accuracy: 0.9153
# Epoch 114/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1453 - accuracy: 0.9408 - val_loss: 0.2287 - val_accuracy: 0.9127
# Epoch 115/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1409 - accuracy: 0.9420 - val_loss: 0.2811 - val_accuracy: 0.8959
# Epoch 116/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1457 - accuracy: 0.9383 - val_loss: 0.1969 - val_accuracy: 0.9328
# Epoch 117/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1454 - accuracy: 0.9391 - val_loss: 0.2150 - val_accuracy: 0.9237
# Epoch 118/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1396 - accuracy: 0.9407 - val_loss: 0.2649 - val_accuracy: 0.8869
# Epoch 119/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1414 - accuracy: 0.9387 - val_loss: 0.2119 - val_accuracy: 0.9224
# Epoch 120/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1396 - accuracy: 0.9431 - val_loss: 0.2558 - val_accuracy: 0.9063
# Epoch 121/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1398 - accuracy: 0.9408 - val_loss: 0.2202 - val_accuracy: 0.9237
# Epoch 122/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1385 - accuracy: 0.9418 - val_loss: 0.2123 - val_accuracy: 0.9218
# Epoch 123/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1374 - accuracy: 0.9415 - val_loss: 0.2216 - val_accuracy: 0.9160
# Epoch 124/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1383 - accuracy: 0.9421 - val_loss: 0.2037 - val_accuracy: 0.9244
# Epoch 125/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1390 - accuracy: 0.9404 - val_loss: 0.1889 - val_accuracy: 0.9354
# Epoch 126/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1369 - accuracy: 0.9439 - val_loss: 0.1412 - val_accuracy: 0.9541
# Epoch 127/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1356 - accuracy: 0.9429 - val_loss: 0.1991 - val_accuracy: 0.9328
# Epoch 128/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1362 - accuracy: 0.9442 - val_loss: 0.2444 - val_accuracy: 0.9108
# Epoch 129/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1348 - accuracy: 0.9429 - val_loss: 0.2717 - val_accuracy: 0.8966
# Epoch 130/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1374 - accuracy: 0.9429 - val_loss: 0.2183 - val_accuracy: 0.9276
# Epoch 131/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1326 - accuracy: 0.9444 - val_loss: 0.1721 - val_accuracy: 0.9405
# Epoch 132/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1325 - accuracy: 0.9452 - val_loss: 0.1443 - val_accuracy: 0.9560
# Epoch 133/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1314 - accuracy: 0.9455 - val_loss: 0.1452 - val_accuracy: 0.9573
# Epoch 134/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1318 - accuracy: 0.9449 - val_loss: 0.1983 - val_accuracy: 0.9347
# Epoch 135/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1323 - accuracy: 0.9452 - val_loss: 0.2432 - val_accuracy: 0.9186
# Epoch 136/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1359 - accuracy: 0.9434 - val_loss: 0.2303 - val_accuracy: 0.9173
# Epoch 137/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1301 - accuracy: 0.9473 - val_loss: 0.2275 - val_accuracy: 0.9198
# Epoch 138/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1320 - accuracy: 0.9447 - val_loss: 0.2330 - val_accuracy: 0.9140
# Epoch 139/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1308 - accuracy: 0.9455 - val_loss: 0.2115 - val_accuracy: 0.9295
# Epoch 140/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1336 - accuracy: 0.9417 - val_loss: 0.2291 - val_accuracy: 0.9211
# Epoch 141/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1311 - accuracy: 0.9455 - val_loss: 0.2255 - val_accuracy: 0.9224
# Epoch 142/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1290 - accuracy: 0.9483 - val_loss: 0.2117 - val_accuracy: 0.9224
# Epoch 143/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1302 - accuracy: 0.9462 - val_loss: 0.2121 - val_accuracy: 0.9270
# Epoch 144/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1275 - accuracy: 0.9449 - val_loss: 0.1975 - val_accuracy: 0.9302
# Epoch 145/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1294 - accuracy: 0.9471 - val_loss: 0.2466 - val_accuracy: 0.9089
# Epoch 146/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1247 - accuracy: 0.9502 - val_loss: 0.1833 - val_accuracy: 0.9347
# Epoch 147/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1268 - accuracy: 0.9489 - val_loss: 0.1891 - val_accuracy: 0.9379
# Epoch 148/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1260 - accuracy: 0.9476 - val_loss: 0.2249 - val_accuracy: 0.9237
# Epoch 149/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1263 - accuracy: 0.9491 - val_loss: 0.1927 - val_accuracy: 0.9334
# Epoch 150/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1282 - accuracy: 0.9455 - val_loss: 0.1992 - val_accuracy: 0.9270
# Epoch 151/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1246 - accuracy: 0.9470 - val_loss: 0.1659 - val_accuracy: 0.9463
# Epoch 152/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1235 - accuracy: 0.9497 - val_loss: 0.2115 - val_accuracy: 0.9347
# Epoch 153/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1238 - accuracy: 0.9515 - val_loss: 0.2222 - val_accuracy: 0.9250
# Epoch 154/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1241 - accuracy: 0.9476 - val_loss: 0.1827 - val_accuracy: 0.9451
# Epoch 155/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1228 - accuracy: 0.9491 - val_loss: 0.1421 - val_accuracy: 0.9580
# Epoch 156/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1215 - accuracy: 0.9510 - val_loss: 0.2078 - val_accuracy: 0.9289
# Epoch 157/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1233 - accuracy: 0.9499 - val_loss: 0.1816 - val_accuracy: 0.9386
# Epoch 158/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1212 - accuracy: 0.9513 - val_loss: 0.1844 - val_accuracy: 0.9451
# Epoch 159/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1197 - accuracy: 0.9510 - val_loss: 0.1572 - val_accuracy: 0.9535
# Epoch 160/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1219 - accuracy: 0.9496 - val_loss: 0.2032 - val_accuracy: 0.9315
# Epoch 161/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1190 - accuracy: 0.9505 - val_loss: 0.1974 - val_accuracy: 0.9315
# Epoch 162/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1202 - accuracy: 0.9525 - val_loss: 0.1998 - val_accuracy: 0.9354
# Epoch 163/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1192 - accuracy: 0.9520 - val_loss: 0.2442 - val_accuracy: 0.9160
# Epoch 164/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1201 - accuracy: 0.9533 - val_loss: 0.2547 - val_accuracy: 0.9166
# Epoch 165/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1210 - accuracy: 0.9546 - val_loss: 0.2392 - val_accuracy: 0.9179
# Epoch 166/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1211 - accuracy: 0.9525 - val_loss: 0.2918 - val_accuracy: 0.8895
# Epoch 167/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1191 - accuracy: 0.9507 - val_loss: 0.2513 - val_accuracy: 0.9050
# Epoch 168/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1170 - accuracy: 0.9518 - val_loss: 0.1967 - val_accuracy: 0.9379
# Epoch 169/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1181 - accuracy: 0.9533 - val_loss: 0.2152 - val_accuracy: 0.9282
# Epoch 170/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1149 - accuracy: 0.9515 - val_loss: 0.2387 - val_accuracy: 0.9198
# Epoch 171/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1160 - accuracy: 0.9539 - val_loss: 0.1695 - val_accuracy: 0.9483
# Epoch 172/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1163 - accuracy: 0.9517 - val_loss: 0.1904 - val_accuracy: 0.9438
# Epoch 173/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1160 - accuracy: 0.9538 - val_loss: 0.1963 - val_accuracy: 0.9328
# Epoch 174/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1144 - accuracy: 0.9552 - val_loss: 0.1693 - val_accuracy: 0.9451
# Epoch 175/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1157 - accuracy: 0.9528 - val_loss: 0.1695 - val_accuracy: 0.9476
# Epoch 176/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1138 - accuracy: 0.9547 - val_loss: 0.2201 - val_accuracy: 0.9270
# Epoch 177/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1129 - accuracy: 0.9556 - val_loss: 0.1738 - val_accuracy: 0.9451
# Epoch 178/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1123 - accuracy: 0.9547 - val_loss: 0.2370 - val_accuracy: 0.9218
# Epoch 179/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1124 - accuracy: 0.9536 - val_loss: 0.1674 - val_accuracy: 0.9509
# Epoch 180/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1124 - accuracy: 0.9547 - val_loss: 0.1402 - val_accuracy: 0.9606
# Epoch 181/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1121 - accuracy: 0.9528 - val_loss: 0.1934 - val_accuracy: 0.9354
# Epoch 182/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1115 - accuracy: 0.9544 - val_loss: 0.1352 - val_accuracy: 0.9625
# Epoch 183/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1136 - accuracy: 0.9531 - val_loss: 0.2379 - val_accuracy: 0.9218
# Epoch 184/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1128 - accuracy: 0.9530 - val_loss: 0.2223 - val_accuracy: 0.9289
# Epoch 185/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1108 - accuracy: 0.9572 - val_loss: 0.2190 - val_accuracy: 0.9257
# Epoch 186/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1084 - accuracy: 0.9551 - val_loss: 0.2319 - val_accuracy: 0.9270
# Epoch 187/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1120 - accuracy: 0.9557 - val_loss: 0.1924 - val_accuracy: 0.9418
# Epoch 188/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1095 - accuracy: 0.9556 - val_loss: 0.2370 - val_accuracy: 0.9205
# Epoch 189/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1092 - accuracy: 0.9565 - val_loss: 0.1892 - val_accuracy: 0.9412
# Epoch 190/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1077 - accuracy: 0.9572 - val_loss: 0.2129 - val_accuracy: 0.9282
# Epoch 191/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1075 - accuracy: 0.9560 - val_loss: 0.1993 - val_accuracy: 0.9379
# Epoch 192/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1108 - accuracy: 0.9546 - val_loss: 0.1952 - val_accuracy: 0.9379
# Epoch 193/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1095 - accuracy: 0.9578 - val_loss: 0.1724 - val_accuracy: 0.9483
# Epoch 194/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1094 - accuracy: 0.9565 - val_loss: 0.2371 - val_accuracy: 0.9244
# Epoch 195/1000
# 194/194 [==============================] - 0s 2ms/step - loss: 0.1068 - accuracy: 0.9598 - val_loss: 0.1721 - val_accuracy: 0.9463
# Epoch 196/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1093 - accuracy: 0.9578 - val_loss: 0.2050 - val_accuracy: 0.9431
# Epoch 197/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1082 - accuracy: 0.9568 - val_loss: 0.2651 - val_accuracy: 0.9056
# Epoch 198/1000
# 194/194 [==============================] - 0s 2ms/step - loss: 0.1075 - accuracy: 0.9554 - val_loss: 0.2604 - val_accuracy: 0.9160
# Epoch 199/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1061 - accuracy: 0.9599 - val_loss: 0.2170 - val_accuracy: 0.9341
# Epoch 200/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1088 - accuracy: 0.9517 - val_loss: 0.2057 - val_accuracy: 0.9328
# Epoch 201/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1052 - accuracy: 0.9591 - val_loss: 0.1845 - val_accuracy: 0.9463
# Epoch 202/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1059 - accuracy: 0.9581 - val_loss: 0.1482 - val_accuracy: 0.9535
# Epoch 203/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1055 - accuracy: 0.9589 - val_loss: 0.1988 - val_accuracy: 0.9334
# Epoch 204/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1067 - accuracy: 0.9570 - val_loss: 0.1703 - val_accuracy: 0.9457
# Epoch 205/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1028 - accuracy: 0.9596 - val_loss: 0.1372 - val_accuracy: 0.9599
# Epoch 206/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1045 - accuracy: 0.9575 - val_loss: 0.1641 - val_accuracy: 0.9515
# Epoch 207/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1068 - accuracy: 0.9586 - val_loss: 0.2111 - val_accuracy: 0.9347
# Epoch 208/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1051 - accuracy: 0.9573 - val_loss: 0.3214 - val_accuracy: 0.8914
# Epoch 209/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1036 - accuracy: 0.9572 - val_loss: 0.1567 - val_accuracy: 0.9528
# Epoch 210/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1011 - accuracy: 0.9602 - val_loss: 0.2820 - val_accuracy: 0.9089
# Epoch 211/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1038 - accuracy: 0.9588 - val_loss: 0.1905 - val_accuracy: 0.9431
# Epoch 212/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1035 - accuracy: 0.9578 - val_loss: 0.2025 - val_accuracy: 0.9321
# Epoch 213/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1034 - accuracy: 0.9575 - val_loss: 0.1850 - val_accuracy: 0.9476
# Epoch 214/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1024 - accuracy: 0.9591 - val_loss: 0.1430 - val_accuracy: 0.9573
# Epoch 215/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1034 - accuracy: 0.9570 - val_loss: 0.1823 - val_accuracy: 0.9463
# Epoch 216/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0998 - accuracy: 0.9609 - val_loss: 0.2418 - val_accuracy: 0.9192
# Epoch 217/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1004 - accuracy: 0.9586 - val_loss: 0.1859 - val_accuracy: 0.9431
# Epoch 218/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1007 - accuracy: 0.9622 - val_loss: 0.2357 - val_accuracy: 0.9218
# Epoch 219/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1002 - accuracy: 0.9607 - val_loss: 0.1943 - val_accuracy: 0.9470
# Epoch 220/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1003 - accuracy: 0.9599 - val_loss: 0.2502 - val_accuracy: 0.9218
# Epoch 221/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1028 - accuracy: 0.9581 - val_loss: 0.2348 - val_accuracy: 0.9205
# Epoch 222/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0995 - accuracy: 0.9627 - val_loss: 0.1792 - val_accuracy: 0.9463
# Epoch 223/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1026 - accuracy: 0.9581 - val_loss: 0.1834 - val_accuracy: 0.9431
# Epoch 224/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1001 - accuracy: 0.9594 - val_loss: 0.2208 - val_accuracy: 0.9276
# Epoch 225/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0972 - accuracy: 0.9612 - val_loss: 0.2328 - val_accuracy: 0.9308
# Epoch 226/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0976 - accuracy: 0.9599 - val_loss: 0.3652 - val_accuracy: 0.8655
# Epoch 227/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1007 - accuracy: 0.9598 - val_loss: 0.2001 - val_accuracy: 0.9354
# Epoch 228/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0997 - accuracy: 0.9604 - val_loss: 0.1812 - val_accuracy: 0.9496
# Epoch 229/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1013 - accuracy: 0.9606 - val_loss: 0.2019 - val_accuracy: 0.9308
# Epoch 230/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0959 - accuracy: 0.9631 - val_loss: 0.1762 - val_accuracy: 0.9425
# Epoch 231/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1000 - accuracy: 0.9577 - val_loss: 0.1909 - val_accuracy: 0.9412
# Epoch 232/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0987 - accuracy: 0.9589 - val_loss: 0.2559 - val_accuracy: 0.9192
# Epoch 233/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0965 - accuracy: 0.9622 - val_loss: 0.2219 - val_accuracy: 0.9386
# Epoch 234/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0988 - accuracy: 0.9606 - val_loss: 0.1616 - val_accuracy: 0.9535
# Epoch 235/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0956 - accuracy: 0.9622 - val_loss: 0.1896 - val_accuracy: 0.9425
# Epoch 236/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0974 - accuracy: 0.9609 - val_loss: 0.2339 - val_accuracy: 0.9295
# Epoch 237/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0968 - accuracy: 0.9623 - val_loss: 0.1951 - val_accuracy: 0.9463
# Epoch 238/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0978 - accuracy: 0.9598 - val_loss: 0.2610 - val_accuracy: 0.9147
# Epoch 239/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0928 - accuracy: 0.9623 - val_loss: 0.1938 - val_accuracy: 0.9412
# Epoch 240/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0964 - accuracy: 0.9635 - val_loss: 0.1992 - val_accuracy: 0.9451
# Epoch 241/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0919 - accuracy: 0.9643 - val_loss: 0.3239 - val_accuracy: 0.8875
# Epoch 242/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0954 - accuracy: 0.9623 - val_loss: 0.2673 - val_accuracy: 0.9050
# Epoch 243/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0936 - accuracy: 0.9627 - val_loss: 0.3463 - val_accuracy: 0.8882
# Epoch 244/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0927 - accuracy: 0.9635 - val_loss: 0.2094 - val_accuracy: 0.9354
# Epoch 245/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0935 - accuracy: 0.9640 - val_loss: 0.1992 - val_accuracy: 0.9457
# Epoch 246/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0939 - accuracy: 0.9615 - val_loss: 0.2403 - val_accuracy: 0.9237
# Epoch 247/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.1001 - accuracy: 0.9577 - val_loss: 0.1885 - val_accuracy: 0.9457
# Epoch 248/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0932 - accuracy: 0.9609 - val_loss: 0.1770 - val_accuracy: 0.9515
# Epoch 249/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0920 - accuracy: 0.9641 - val_loss: 0.1775 - val_accuracy: 0.9522
# Epoch 250/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0941 - accuracy: 0.9604 - val_loss: 0.1875 - val_accuracy: 0.9483
# Epoch 251/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0913 - accuracy: 0.9638 - val_loss: 0.2051 - val_accuracy: 0.9373
# Epoch 252/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0911 - accuracy: 0.9651 - val_loss: 0.1912 - val_accuracy: 0.9451
# Epoch 253/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0932 - accuracy: 0.9633 - val_loss: 0.2390 - val_accuracy: 0.9315
# Epoch 254/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0920 - accuracy: 0.9607 - val_loss: 0.2617 - val_accuracy: 0.9153
# Epoch 255/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0911 - accuracy: 0.9633 - val_loss: 0.2858 - val_accuracy: 0.9063
# Epoch 256/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0926 - accuracy: 0.9615 - val_loss: 0.2458 - val_accuracy: 0.9140
# Epoch 257/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0893 - accuracy: 0.9648 - val_loss: 0.2103 - val_accuracy: 0.9315
# Epoch 258/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0890 - accuracy: 0.9646 - val_loss: 0.2849 - val_accuracy: 0.9127
# Epoch 259/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0898 - accuracy: 0.9661 - val_loss: 0.2097 - val_accuracy: 0.9263
# Epoch 260/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0924 - accuracy: 0.9648 - val_loss: 0.1920 - val_accuracy: 0.9425
# Epoch 261/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0921 - accuracy: 0.9640 - val_loss: 0.2215 - val_accuracy: 0.9373
# Epoch 262/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0914 - accuracy: 0.9646 - val_loss: 0.2482 - val_accuracy: 0.9224
# Epoch 263/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0920 - accuracy: 0.9649 - val_loss: 0.1737 - val_accuracy: 0.9470
# Epoch 264/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0923 - accuracy: 0.9625 - val_loss: 0.1737 - val_accuracy: 0.9463
# Epoch 265/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0898 - accuracy: 0.9675 - val_loss: 0.2033 - val_accuracy: 0.9315
# Epoch 266/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0908 - accuracy: 0.9654 - val_loss: 0.1934 - val_accuracy: 0.9476
# Epoch 267/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0904 - accuracy: 0.9623 - val_loss: 0.2221 - val_accuracy: 0.9347
# Epoch 268/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0862 - accuracy: 0.9662 - val_loss: 0.2238 - val_accuracy: 0.9282
# Epoch 269/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0887 - accuracy: 0.9661 - val_loss: 0.2104 - val_accuracy: 0.9373
# Epoch 270/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0865 - accuracy: 0.9670 - val_loss: 0.1766 - val_accuracy: 0.9489
# Epoch 271/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0875 - accuracy: 0.9651 - val_loss: 0.1867 - val_accuracy: 0.9476
# Epoch 272/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0890 - accuracy: 0.9648 - val_loss: 0.2114 - val_accuracy: 0.9354
# Epoch 273/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0869 - accuracy: 0.9656 - val_loss: 0.2015 - val_accuracy: 0.9386
# Epoch 274/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0828 - accuracy: 0.9659 - val_loss: 0.2169 - val_accuracy: 0.9334
# Epoch 275/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0866 - accuracy: 0.9665 - val_loss: 0.2115 - val_accuracy: 0.9379
# Epoch 276/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0842 - accuracy: 0.9665 - val_loss: 0.1959 - val_accuracy: 0.9418
# Epoch 277/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0880 - accuracy: 0.9662 - val_loss: 0.2120 - val_accuracy: 0.9386
# Epoch 278/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0862 - accuracy: 0.9664 - val_loss: 0.2102 - val_accuracy: 0.9438
# Epoch 279/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0865 - accuracy: 0.9656 - val_loss: 0.2283 - val_accuracy: 0.9334
# Epoch 280/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0827 - accuracy: 0.9674 - val_loss: 0.2359 - val_accuracy: 0.9321
# Epoch 281/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0848 - accuracy: 0.9664 - val_loss: 0.1752 - val_accuracy: 0.9483
# Epoch 282/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0861 - accuracy: 0.9662 - val_loss: 0.2062 - val_accuracy: 0.9418
# Epoch 283/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0855 - accuracy: 0.9661 - val_loss: 0.2215 - val_accuracy: 0.9295
# Epoch 284/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0827 - accuracy: 0.9696 - val_loss: 0.2182 - val_accuracy: 0.9347
# Epoch 285/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0828 - accuracy: 0.9670 - val_loss: 0.2511 - val_accuracy: 0.9263
# Epoch 286/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0875 - accuracy: 0.9690 - val_loss: 0.1930 - val_accuracy: 0.9399
# Epoch 287/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0869 - accuracy: 0.9659 - val_loss: 0.2243 - val_accuracy: 0.9392
# Epoch 288/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0828 - accuracy: 0.9690 - val_loss: 0.2198 - val_accuracy: 0.9354
# Epoch 289/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0842 - accuracy: 0.9686 - val_loss: 0.1786 - val_accuracy: 0.9463
# Epoch 290/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0865 - accuracy: 0.9664 - val_loss: 0.2432 - val_accuracy: 0.9224
# Epoch 291/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0822 - accuracy: 0.9690 - val_loss: 0.2152 - val_accuracy: 0.9328
# Epoch 292/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0829 - accuracy: 0.9670 - val_loss: 0.1865 - val_accuracy: 0.9483
# Epoch 293/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0848 - accuracy: 0.9654 - val_loss: 0.2072 - val_accuracy: 0.9418
# Epoch 294/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0811 - accuracy: 0.9683 - val_loss: 0.1713 - val_accuracy: 0.9515
# Epoch 295/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0810 - accuracy: 0.9685 - val_loss: 0.2122 - val_accuracy: 0.9367
# Epoch 296/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0817 - accuracy: 0.9686 - val_loss: 0.2315 - val_accuracy: 0.9328
# Epoch 297/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0804 - accuracy: 0.9690 - val_loss: 0.1939 - val_accuracy: 0.9386
# Epoch 298/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0803 - accuracy: 0.9682 - val_loss: 0.2991 - val_accuracy: 0.8985
# Epoch 299/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0786 - accuracy: 0.9703 - val_loss: 0.2128 - val_accuracy: 0.9399
# Epoch 300/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0807 - accuracy: 0.9682 - val_loss: 0.2194 - val_accuracy: 0.9379
# Epoch 301/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0812 - accuracy: 0.9685 - val_loss: 0.2636 - val_accuracy: 0.9231
# Epoch 302/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0796 - accuracy: 0.9693 - val_loss: 0.2580 - val_accuracy: 0.9205
# Epoch 303/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0794 - accuracy: 0.9678 - val_loss: 0.2207 - val_accuracy: 0.9276
# Epoch 304/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0791 - accuracy: 0.9686 - val_loss: 0.2212 - val_accuracy: 0.9431
# Epoch 305/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0828 - accuracy: 0.9680 - val_loss: 0.1993 - val_accuracy: 0.9399
# Epoch 306/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0829 - accuracy: 0.9677 - val_loss: 0.2064 - val_accuracy: 0.9489
# Epoch 307/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0810 - accuracy: 0.9672 - val_loss: 0.1752 - val_accuracy: 0.9483
# Epoch 308/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0800 - accuracy: 0.9688 - val_loss: 0.1963 - val_accuracy: 0.9476
# Epoch 309/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0804 - accuracy: 0.9709 - val_loss: 0.3322 - val_accuracy: 0.8856
# Epoch 310/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0812 - accuracy: 0.9685 - val_loss: 0.2002 - val_accuracy: 0.9451
# Epoch 311/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0784 - accuracy: 0.9709 - val_loss: 0.2015 - val_accuracy: 0.9457
# Epoch 312/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0770 - accuracy: 0.9714 - val_loss: 0.2263 - val_accuracy: 0.9321
# Epoch 313/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0756 - accuracy: 0.9712 - val_loss: 0.2298 - val_accuracy: 0.9321
# Epoch 314/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0805 - accuracy: 0.9704 - val_loss: 0.2459 - val_accuracy: 0.9276
# Epoch 315/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0798 - accuracy: 0.9677 - val_loss: 0.2403 - val_accuracy: 0.9270
# Epoch 316/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0791 - accuracy: 0.9678 - val_loss: 0.2185 - val_accuracy: 0.9295
# Epoch 317/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0753 - accuracy: 0.9720 - val_loss: 0.3002 - val_accuracy: 0.9076
# Epoch 318/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0788 - accuracy: 0.9698 - val_loss: 0.2423 - val_accuracy: 0.9237
# Epoch 319/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0772 - accuracy: 0.9695 - val_loss: 0.2125 - val_accuracy: 0.9444
# Epoch 320/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0768 - accuracy: 0.9714 - val_loss: 0.2266 - val_accuracy: 0.9386
# Epoch 321/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0794 - accuracy: 0.9672 - val_loss: 0.2588 - val_accuracy: 0.9237
# Epoch 322/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0762 - accuracy: 0.9703 - val_loss: 0.2209 - val_accuracy: 0.9367
# Epoch 323/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0765 - accuracy: 0.9712 - val_loss: 0.1969 - val_accuracy: 0.9470
# Epoch 324/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0755 - accuracy: 0.9714 - val_loss: 0.2019 - val_accuracy: 0.9444
# Epoch 325/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0776 - accuracy: 0.9698 - val_loss: 0.1736 - val_accuracy: 0.9535
# Epoch 326/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0785 - accuracy: 0.9711 - val_loss: 0.1721 - val_accuracy: 0.9522
# Epoch 327/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0740 - accuracy: 0.9698 - val_loss: 0.1989 - val_accuracy: 0.9470
# Epoch 328/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0734 - accuracy: 0.9727 - val_loss: 0.2879 - val_accuracy: 0.9218
# Epoch 329/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0753 - accuracy: 0.9699 - val_loss: 0.3142 - val_accuracy: 0.8998
# Epoch 330/1000
# ...
# Epoch 892/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0363 - accuracy: 0.9884 - val_loss: 0.3289 - val_accuracy: 0.9457
# Epoch 893/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0319 - accuracy: 0.9887 - val_loss: 0.3570 - val_accuracy: 0.9412
# Epoch 894/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0304 - accuracy: 0.9911 - val_loss: 0.3169 - val_accuracy: 0.9489
# Epoch 895/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0366 - accuracy: 0.9871 - val_loss: 0.3137 - val_accuracy: 0.9425
# Epoch 896/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0308 - accuracy: 0.9888 - val_loss: 0.3058 - val_accuracy: 0.9528
# Epoch 897/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0412 - accuracy: 0.9846 - val_loss: 0.4608 - val_accuracy: 0.9257
# Epoch 898/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0332 - accuracy: 0.9880 - val_loss: 0.3844 - val_accuracy: 0.9341
# Epoch 899/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0338 - accuracy: 0.9885 - val_loss: 0.3738 - val_accuracy: 0.9360
# Epoch 900/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0331 - accuracy: 0.9879 - val_loss: 0.3010 - val_accuracy: 0.9496
# Epoch 901/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0297 - accuracy: 0.9893 - val_loss: 0.2767 - val_accuracy: 0.9541
# Epoch 902/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0309 - accuracy: 0.9893 - val_loss: 0.3345 - val_accuracy: 0.9412
# Epoch 903/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0299 - accuracy: 0.9892 - val_loss: 0.3280 - val_accuracy: 0.9438
# Epoch 904/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0406 - accuracy: 0.9846 - val_loss: 0.4633 - val_accuracy: 0.9224
# Epoch 905/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0296 - accuracy: 0.9898 - val_loss: 0.4208 - val_accuracy: 0.9250
# Epoch 906/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0284 - accuracy: 0.9906 - val_loss: 0.2910 - val_accuracy: 0.9554
# Epoch 907/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0327 - accuracy: 0.9887 - val_loss: 0.3508 - val_accuracy: 0.9405
# Epoch 908/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0350 - accuracy: 0.9874 - val_loss: 0.3978 - val_accuracy: 0.9224
# Epoch 909/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0535 - accuracy: 0.9796 - val_loss: 0.2838 - val_accuracy: 0.9586
# Epoch 910/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0342 - accuracy: 0.9869 - val_loss: 0.4616 - val_accuracy: 0.9063
# Epoch 911/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0357 - accuracy: 0.9877 - val_loss: 0.3564 - val_accuracy: 0.9367
# Epoch 912/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0294 - accuracy: 0.9893 - val_loss: 0.3472 - val_accuracy: 0.9418
# Epoch 913/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0305 - accuracy: 0.9900 - val_loss: 0.4562 - val_accuracy: 0.9166
# Epoch 914/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0305 - accuracy: 0.9901 - val_loss: 0.3464 - val_accuracy: 0.9457
# Epoch 915/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0337 - accuracy: 0.9882 - val_loss: 0.4073 - val_accuracy: 0.9308
# Epoch 916/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0338 - accuracy: 0.9892 - val_loss: 0.3506 - val_accuracy: 0.9457
# Epoch 917/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0368 - accuracy: 0.9876 - val_loss: 0.3057 - val_accuracy: 0.9489
# Epoch 918/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0271 - accuracy: 0.9897 - val_loss: 0.3418 - val_accuracy: 0.9354
# Epoch 919/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0360 - accuracy: 0.9888 - val_loss: 0.2464 - val_accuracy: 0.9586
# Epoch 920/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0365 - accuracy: 0.9871 - val_loss: 0.4354 - val_accuracy: 0.9237
# Epoch 921/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0347 - accuracy: 0.9863 - val_loss: 0.3672 - val_accuracy: 0.9431
# Epoch 922/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0297 - accuracy: 0.9900 - val_loss: 0.3308 - val_accuracy: 0.9418
# Epoch 923/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0267 - accuracy: 0.9903 - val_loss: 0.3887 - val_accuracy: 0.9386
# Epoch 924/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0322 - accuracy: 0.9866 - val_loss: 0.3919 - val_accuracy: 0.9328
# Epoch 925/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0315 - accuracy: 0.9888 - val_loss: 0.2714 - val_accuracy: 0.9612
# Epoch 926/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0303 - accuracy: 0.9895 - val_loss: 0.3775 - val_accuracy: 0.9341
# Epoch 927/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0295 - accuracy: 0.9905 - val_loss: 0.3927 - val_accuracy: 0.9270
# Epoch 928/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0285 - accuracy: 0.9901 - val_loss: 0.3690 - val_accuracy: 0.9334
# Epoch 929/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0320 - accuracy: 0.9901 - val_loss: 0.3564 - val_accuracy: 0.9418
# Epoch 930/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0323 - accuracy: 0.9879 - val_loss: 0.3786 - val_accuracy: 0.9379
# Epoch 931/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0329 - accuracy: 0.9897 - val_loss: 0.5118 - val_accuracy: 0.9147
# Epoch 932/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0280 - accuracy: 0.9897 - val_loss: 0.4042 - val_accuracy: 0.9354
# Epoch 933/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0351 - accuracy: 0.9897 - val_loss: 0.2454 - val_accuracy: 0.9586
# Epoch 934/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0340 - accuracy: 0.9882 - val_loss: 0.2999 - val_accuracy: 0.9489
# Epoch 935/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0341 - accuracy: 0.9874 - val_loss: 0.3083 - val_accuracy: 0.9509
# Epoch 936/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0306 - accuracy: 0.9893 - val_loss: 0.3108 - val_accuracy: 0.9528
# Epoch 937/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0358 - accuracy: 0.9872 - val_loss: 0.3246 - val_accuracy: 0.9463
# Epoch 938/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0392 - accuracy: 0.9846 - val_loss: 0.3223 - val_accuracy: 0.9457
# Epoch 939/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0335 - accuracy: 0.9890 - val_loss: 0.4291 - val_accuracy: 0.9308
# Epoch 940/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0295 - accuracy: 0.9903 - val_loss: 0.4256 - val_accuracy: 0.9257
# Epoch 941/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0312 - accuracy: 0.9890 - val_loss: 0.4598 - val_accuracy: 0.9121
# Epoch 942/1000
# 194/194 [==============================] - 0s 996us/step - loss: 0.0287 - accuracy: 0.9892 - val_loss: 0.3407 - val_accuracy: 0.9418
# Epoch 943/1000
# 194/194 [==============================] - 0s 998us/step - loss: 0.0308 - accuracy: 0.9888 - val_loss: 0.3665 - val_accuracy: 0.9328
# Epoch 944/1000
# 194/194 [==============================] - 0s 998us/step - loss: 0.0303 - accuracy: 0.9887 - val_loss: 0.3229 - val_accuracy: 0.9444
# Epoch 945/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0269 - accuracy: 0.9909 - val_loss: 0.4711 - val_accuracy: 0.9121
# Epoch 946/1000
# 194/194 [==============================] - 0s 996us/step - loss: 0.0307 - accuracy: 0.9893 - val_loss: 0.4086 - val_accuracy: 0.9237
# Epoch 947/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0290 - accuracy: 0.9898 - val_loss: 0.3534 - val_accuracy: 0.9354
# Epoch 948/1000
# 194/194 [==============================] - 0s 997us/step - loss: 0.0321 - accuracy: 0.9877 - val_loss: 0.4810 - val_accuracy: 0.9095
# Epoch 949/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0331 - accuracy: 0.9888 - val_loss: 0.3915 - val_accuracy: 0.9302
# Epoch 950/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0304 - accuracy: 0.9876 - val_loss: 0.3591 - val_accuracy: 0.9399
# Epoch 951/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0373 - accuracy: 0.9864 - val_loss: 0.3063 - val_accuracy: 0.9541
# Epoch 952/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0347 - accuracy: 0.9863 - val_loss: 0.4487 - val_accuracy: 0.9192
# Epoch 953/1000
# 194/194 [==============================] - 0s 992us/step - loss: 0.0395 - accuracy: 0.9861 - val_loss: 0.4719 - val_accuracy: 0.9082
# Epoch 954/1000
# 194/194 [==============================] - 0s 946us/step - loss: 0.0373 - accuracy: 0.9869 - val_loss: 0.3998 - val_accuracy: 0.9360
# Epoch 955/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0326 - accuracy: 0.9880 - val_loss: 0.2495 - val_accuracy: 0.9612
# Epoch 956/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0320 - accuracy: 0.9897 - val_loss: 0.3161 - val_accuracy: 0.9502
# Epoch 957/1000
# 194/194 [==============================] - 0s 997us/step - loss: 0.0309 - accuracy: 0.9895 - val_loss: 0.3780 - val_accuracy: 0.9418
# Epoch 958/1000
# 194/194 [==============================] - 0s 996us/step - loss: 0.0363 - accuracy: 0.9871 - val_loss: 0.3814 - val_accuracy: 0.9470
# Epoch 959/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0384 - accuracy: 0.9876 - val_loss: 0.5655 - val_accuracy: 0.8869
# Epoch 960/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0285 - accuracy: 0.9898 - val_loss: 0.4242 - val_accuracy: 0.9257
# Epoch 961/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0281 - accuracy: 0.9901 - val_loss: 0.5139 - val_accuracy: 0.9076
# Epoch 962/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0332 - accuracy: 0.9900 - val_loss: 0.3074 - val_accuracy: 0.9476
# Epoch 963/1000
# 194/194 [==============================] - 0s 995us/step - loss: 0.0274 - accuracy: 0.9901 - val_loss: 0.4248 - val_accuracy: 0.9315
# Epoch 964/1000
# 194/194 [==============================] - 0s 992us/step - loss: 0.0312 - accuracy: 0.9905 - val_loss: 0.4219 - val_accuracy: 0.9276
# Epoch 965/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0312 - accuracy: 0.9888 - val_loss: 0.3103 - val_accuracy: 0.9412
# Epoch 966/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0273 - accuracy: 0.9909 - val_loss: 0.3855 - val_accuracy: 0.9289
# Epoch 967/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0279 - accuracy: 0.9906 - val_loss: 0.2898 - val_accuracy: 0.9470
# Epoch 968/1000
# 194/194 [==============================] - 0s 997us/step - loss: 0.0332 - accuracy: 0.9871 - val_loss: 0.2912 - val_accuracy: 0.9502
# Epoch 969/1000
# 194/194 [==============================] - 0s 987us/step - loss: 0.0313 - accuracy: 0.9879 - val_loss: 0.3755 - val_accuracy: 0.9373
# Epoch 970/1000
# 194/194 [==============================] - 0s 994us/step - loss: 0.0297 - accuracy: 0.9895 - val_loss: 0.3025 - val_accuracy: 0.9541
# Epoch 971/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0306 - accuracy: 0.9895 - val_loss: 0.4384 - val_accuracy: 0.9315
# Epoch 972/1000
# 194/194 [==============================] - 0s 955us/step - loss: 0.0378 - accuracy: 0.9867 - val_loss: 0.3446 - val_accuracy: 0.9509
# Epoch 973/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0352 - accuracy: 0.9871 - val_loss: 0.4220 - val_accuracy: 0.9347
# Epoch 974/1000
# 194/194 [==============================] - 0s 993us/step - loss: 0.0325 - accuracy: 0.9900 - val_loss: 0.5079 - val_accuracy: 0.9134
# Epoch 975/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0298 - accuracy: 0.9897 - val_loss: 0.3141 - val_accuracy: 0.9451
# Epoch 976/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0298 - accuracy: 0.9900 - val_loss: 0.3760 - val_accuracy: 0.9412
# Epoch 977/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0307 - accuracy: 0.9884 - val_loss: 0.3548 - val_accuracy: 0.9341
# Epoch 978/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0361 - accuracy: 0.9863 - val_loss: 0.3548 - val_accuracy: 0.9444
# Epoch 979/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0284 - accuracy: 0.9919 - val_loss: 0.3136 - val_accuracy: 0.9470
# Epoch 980/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0302 - accuracy: 0.9905 - val_loss: 0.3541 - val_accuracy: 0.9496
# Epoch 981/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0269 - accuracy: 0.9911 - val_loss: 0.4464 - val_accuracy: 0.9334
# Epoch 982/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0282 - accuracy: 0.9901 - val_loss: 0.4224 - val_accuracy: 0.9321
# Epoch 983/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0299 - accuracy: 0.9900 - val_loss: 0.3571 - val_accuracy: 0.9373
# Epoch 984/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0383 - accuracy: 0.9864 - val_loss: 0.3944 - val_accuracy: 0.9334
# Epoch 985/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0340 - accuracy: 0.9882 - val_loss: 0.4735 - val_accuracy: 0.9140
# Epoch 986/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0360 - accuracy: 0.9874 - val_loss: 0.3281 - val_accuracy: 0.9502
# Epoch 987/1000
# 194/194 [==============================] - 0s 988us/step - loss: 0.0309 - accuracy: 0.9893 - val_loss: 0.4079 - val_accuracy: 0.9367
# Epoch 988/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0276 - accuracy: 0.9901 - val_loss: 0.3398 - val_accuracy: 0.9425
# Epoch 989/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0266 - accuracy: 0.9914 - val_loss: 0.4183 - val_accuracy: 0.9308
# Epoch 990/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0359 - accuracy: 0.9887 - val_loss: 0.3425 - val_accuracy: 0.9476
# Epoch 991/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0289 - accuracy: 0.9905 - val_loss: 0.4478 - val_accuracy: 0.9289
# Epoch 992/1000
# 194/194 [==============================] - 0s 1000us/step - loss: 0.0297 - accuracy: 0.9900 - val_loss: 0.3360 - val_accuracy: 0.9463
# Epoch 993/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0318 - accuracy: 0.9893 - val_loss: 0.4663 - val_accuracy: 0.9276
# Epoch 994/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0254 - accuracy: 0.9901 - val_loss: 0.3667 - val_accuracy: 0.9392
# Epoch 995/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0301 - accuracy: 0.9898 - val_loss: 0.3713 - val_accuracy: 0.9438
# Epoch 996/1000
# 194/194 [==============================] - 0s 999us/step - loss: 0.0289 - accuracy: 0.9895 - val_loss: 0.3277 - val_accuracy: 0.9509
# Epoch 997/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0303 - accuracy: 0.9884 - val_loss: 0.3319 - val_accuracy: 0.9528
# Epoch 998/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0314 - accuracy: 0.9887 - val_loss: 0.3133 - val_accuracy: 0.9541
# Epoch 999/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0270 - accuracy: 0.9898 - val_loss: 0.3834 - val_accuracy: 0.9373
# Epoch 1000/1000
# 194/194 [==============================] - 0s 1ms/step - loss: 0.0249 - accuracy: 0.9916 - val_loss: 0.4037 - val_accuracy: 0.9367

# %%
# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy*100:.2f}%")
# Out:
# 32/32 [==============================] - 0s 647us/step - loss: 1.1788 - accuracy: 0.8777
# Test Accuracy: 87.77%

# %%
# Make predictions
y_pred_NN = model.predict(X_test)
y_pred_NN = (y_pred_NN > 0.5).astype("int32")  # Convert probabilities to binary outputs

# Calculate precision, recall, and F1 score
precision = precision_score(y_test, y_pred_NN)
recall = recall_score(y_test, y_pred_NN)
f1 = f1_score(y_test, y_pred_NN)

print(f"Precision: {precision}, Recall: {recall}, F1 Score: {f1}")
# Out:
# Precision: 0.1111111111111111, Recall: 0.18181818181818182, F1 Score: 0.13793103448275862

# %%
report_initial_NN_model = classification_report(y_test, y_pred_NN)
print(report_initial_NN_model)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.93       967
#            1       0.11      0.18      0.14        55
#
#     accuracy                           0.88      1022
#    macro avg       0.53      0.55      0.54      1022
# weighted avg       0.91      0.88      0.89      1022

# %%
# Compute confusion matrix
conf_matrix_NN_model = confusion_matrix(y_test, y_pred_NN)

# Plot confusion matrix
sns.heatmap(conf_matrix_NN_model, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
#### plot confusion matrices for all models

# %%
#  actual confusion matrix objects
confusion_matrices = [conf_matrix_sm,
conf_matrix_logit_ss,
conf_matrix_knn_mmk7,
conf_matrix_knn_mmk19,
conf_matrix_dt_ssn,
conf_matrix_SVM_model,
conf_matrix_PCA,
conf_matrix_RF_model,
conf_matrix_g_b_model,
conf_matrix_NN_model]
titles = ['Logistic Regression (SM)', 
'Logistic Regression (SS)', 
'KNN with 13N',
'KNN with 19N',
'Decision Tree',
'SVM',
'PCA',
'Random Forest', 
'Gradient Boosting', 
'Neural Network']

# %%
# Create a figure and a set of subplots
fig, axes = plt.subplots(2, 5, figsize=(16, 9))  # Adjust the figure size as needed
axes = axes.flatten()  # Flatten the array of axes

# Loop through each confusion matrix
for i, (model, title) in enumerate(zip(confusion_matrices, titles)):
    ax = axes[i]
    sns.heatmap(model, annot=True, fmt='d', ax=ax, cmap='Blues')  # Using 'Blues' colormap
    ax.set_title(title)
    ax.set_xlabel('Predicted')
    ax.set_ylabel('True')

plt.tight_layout()
plt.show()

# %%
# List of predictions from different models
predictions = [y_pred_sm, y_test_pred_logit_ss, y_test_pred_knn_mmk7, y_test_pred_knn_mm19, y_test_pred_dt_ssn,
               y_test_pred_SVM_model, y_test_pred_PCA, y_pred_RF_model, y_pred_g_b_model, y_pred_NN]
titles = ['Logistic Regression (SM)', 
'Logistic Regression (SS)', 
'KNN with 13N',
'KNN with 19N',
'Decision Tree',
'SVM',
'PCA',
'Random Forest', 
'Gradient Boosting', 
'Neural Network']
# Loop through each model's predictions and print the classification report
for y_pred, name in zip(predictions, titles):
    print(f"Classification Report for {name}:")
    print(classification_report(y_test, y_pred))
    print("\n")
# Out:
# Classification Report for Logistic Regression (SM):
#               precision    recall  f1-score   support
#
#            0       0.99      0.71      0.82       967
#            1       0.14      0.85      0.24        55
#
#     accuracy                           0.71      1022
#    macro avg       0.56      0.78      0.53      1022
# weighted avg       0.94      0.71      0.79      1022
#
#
#
# Classification Report for Logistic Regression (SS):
#               precision    recall  f1-score   support
#
#            0       0.98      0.80      0.88       967
#            1       0.16      0.69      0.26        55
#
#     accuracy                           0.79      1022
#    macro avg       0.57      0.74      0.57      1022
# weighted avg       0.93      0.79      0.85      1022
#
#
#
# Classification Report for KNN with 13N:
#               precision    recall  f1-score   support
#
#            0       0.96      0.82      0.88       967
#            1       0.12      0.45      0.19        55
#
#     accuracy                           0.80      1022
#    macro avg       0.54      0.64      0.54      1022
# weighted avg       0.92      0.80      0.85      1022
#
#
#
# Classification Report for KNN with 19N:
#               precision    recall  f1-score   support
#
#            0       0.97      0.81      0.88       967
#            1       0.13      0.49      0.20        55
#
#     accuracy                           0.79      1022
#    macro avg       0.55      0.65      0.54      1022
# weighted avg       0.92      0.79      0.84      1022
#
#
#
# Classification Report for Decision Tree:
#               precision    recall  f1-score   support
#
#            0       1.00      0.59      0.74       967
#            1       0.12      0.98      0.21        55
#
#     accuracy                           0.61      1022
#    macro avg       0.56      0.79      0.48      1022
# weighted avg       0.95      0.61      0.71      1022
#
#
#
# Classification Report for SVM:
#               precision    recall  f1-score   support
#
#            0       0.98      0.82      0.89       967
#            1       0.17      0.65      0.27        55
#
#     accuracy                           0.81      1022
#    macro avg       0.57      0.74      0.58      1022
# weighted avg       0.93      0.81      0.86      1022
#
#
#
# Classification Report for PCA:
#               precision    recall  f1-score   support
#
#            0       0.97      0.79      0.87       967
#            1       0.13      0.56      0.21        55
#
#     accuracy                           0.77      1022
#    macro avg       0.55      0.68      0.54      1022
# weighted avg       0.92      0.77      0.83      1022
#
#
#
# Classification Report for Random Forest:
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94       967
#            1       0.15      0.20      0.17        55
#
#     accuracy                           0.89      1022
#    macro avg       0.55      0.57      0.56      1022
# weighted avg       0.91      0.89      0.90      1022
#
#
#
# Classification Report for Gradient Boosting:
#               precision    recall  f1-score   support
#
#            0       0.97      0.87      0.91       967
#            1       0.16      0.45      0.24        55
#
#     accuracy                           0.85      1022
#    macro avg       0.56      0.66      0.58      1022
# weighted avg       0.92      0.85      0.88      1022
#
#
#
# Classification Report for Neural Network:
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.93       967
#            1       0.11      0.18      0.14        55
#
#     accuracy                           0.88      1022
#    macro avg       0.53      0.55      0.54      1022
# weighted avg       0.91      0.88      0.89      1022

# %%
# Initialize lists to store metrics
accuracies = []
precisions = []
recalls = []
f1_scores = []

# Loop through each model's predictions and calculate metrics
for y_pred in predictions:
    accuracies.append(accuracy_score(y_test, y_pred))
    precisions.append(precision_score(y_test, y_pred))
    recalls.append(recall_score(y_test, y_pred))
    f1_scores.append(f1_score(y_test, y_pred))

# %%
# Create a DataFrame with the metrics
metrics_df = pd.DataFrame({
    'Model': titles,
    'Accuracy': accuracies,
    'Precision': precisions,
    'Recall': recalls,
    'F1 Score': f1_scores
})

# %%
plt.figure(figsize=(24, 16))  
ax = metrics_df.set_index('Model').plot(kind='bar', rot=75)
plt.title('Classification Metrics for Different Models')
plt.ylabel('Score')
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))  # Move legend to the side

plt.show()
